# %%
import re
import json
import pickle

import pandas as pd

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
with open("/Utilisateurs/umushtaq/am_reasoning/saved_models/pe_pipeline_prompt2_Qwen2.5-14B-Instruct-bnb-4bit/pe_pipeline_results_5.pickle", 'rb') as f:
    
    results = pickle.load(f)

# %%
grounds = results['grounds']
predictions = results['predictions']

# %%
grounds
# Out:
# ['### Output:\n{"argument_types": [\'M\', \'M\', \'C\', \'C\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\']}\n{"relation_types": [((8, 4), \'S\'), ((7, 4), \'S\'), ((6, 4), \'S\'), ((10, 11), \'S\'), ((9, 5), \'S\'), ((11, 5), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'M\', \'C\', \'C\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\']}\n{"relation_types": [((6, 3), \'S\'), ((7, 4), \'A\'), ((8, 7), \'A\'), ((9, 4), \'S\'), ((10, 5), \'S\'), ((11, 5), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'M\', \'C\', \'C\', \'C\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\']}\n{"relation_types": [((7, 4), \'S\'), ((8, 9), \'S\'), ((10, 9), \'S\'), ((9, 4), \'S\'), ((11, 5), \'S\'), ((12, 5), \'S\'), ((13, 6), \'S\'), ((14, 6), \'S\'), ((15, 6), \'S\'), ((16, 6), \'S\'), ((17, 16), \'S\'), ((18, 16), \'S\'), ((19, 16), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'M\', \'C\', \'P\', \'P\', \'C\', \'C\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\']}\n{"relation_types": [((5, 3), \'S\'), ((4, 3), \'S\'), ((9, 6), \'S\'), ((11, 13), \'S\'), ((12, 13), \'S\'), ((10, 6), \'S\'), ((13, 6), \'S\'), ((14, 7), \'S\'), ((15, 7), \'S\'), ((18, 8), \'S\'), ((17, 16), \'A\'), ((16, 8), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'M\', \'C\', \'C\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\']}\n{"relation_types": [((6, 4), \'S\'), ((7, 4), \'S\'), ((8, 7), \'S\'), ((9, 7), \'S\'), ((10, 5), \'S\'), ((11, 5), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'C\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\']}\n{"relation_types": [((5, 2), \'S\'), ((6, 2), \'S\'), ((7, 2), \'S\'), ((8, 2), \'S\'), ((9, 2), \'S\'), ((10, 2), \'S\'), ((11, 4), \'S\'), ((4, 3), \'S\'), ((12, 13), \'S\'), ((13, 3), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'C\', \'M\', \'C\', \'C\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\']}\n{"relation_types": [((11, 10), \'S\'), ((12, 10), \'S\'), ((7, 4), \'S\'), ((8, 4), \'S\'), ((9, 4), \'S\'), ((10, 4), \'S\'), ((13, 5), \'S\'), ((14, 5), \'S\'), ((15, 5), \'S\'), ((16, 5), \'S\'), ((17, 6), \'S\'), ((18, 6), \'S\'), ((19, 6), \'S\'), ((20, 6), \'S\'), ((21, 6), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'M\', \'C\', \'C\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\']}\n{"relation_types": [((6, 4), \'S\'), ((8, 9), \'S\'), ((7, 9), \'S\'), ((9, 5), \'A\'), ((10, 5), \'S\'), ((11, 5), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'M\', \'C\', \'C\', \'C\', \'P\', \'P\', \'P\', \'P\']}\n{"relation_types": [((6, 3), \'S\'), ((7, 4), \'S\'), ((8, 4), \'S\'), ((9, 5), \'A\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'C\', \'M\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'C\']}\n{"relation_types": [((5, 4), \'S\'), ((6, 4), \'S\'), ((7, 4), \'S\'), ((8, 4), \'S\'), ((11, 9), \'S\'), ((12, 13), \'S\'), ((9, 13), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'M\', \'C\', \'C\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\']}\n{"relation_types": [((8, 3), \'S\'), ((9, 3), \'S\'), ((10, 3), \'S\'), ((11, 3), \'S\'), ((12, 13), \'S\'), ((13, 4), \'S\'), ((14, 4), \'S\'), ((6, 5), \'S\'), ((7, 5), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'C\', \'M\', \'C\', \'P\', \'C\', \'P\', \'P\', \'C\', \'P\', \'C\']}\n{"relation_types": [((4, 3), \'S\'), ((6, 7), \'S\'), ((7, 5), \'S\'), ((9, 10), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'M\', \'C\', \'C\', \'C\', \'C\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\']}\n{"relation_types": [((9, 3), \'S\'), ((8, 3), \'S\'), ((10, 4), \'S\'), ((11, 4), \'S\'), ((12, 4), \'S\'), ((13, 4), \'S\'), ((14, 5), \'S\'), ((15, 6), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'P\', \'C\', \'P\', \'P\', \'C\', \'P\', \'P\', \'M\', \'C\', \'C\', \'P\', \'P\', \'P\']}\n{"relation_types": [((5, 3), \'S\'), ((4, 3), \'S\'), ((2, 3), \'S\'), ((8, 7), \'S\'), ((7, 6), \'S\'), ((14, 13), \'S\'), ((13, 12), \'S\'), ((12, 11), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'M\', \'C\', \'C\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\']}\n{"relation_types": [((6, 3), \'S\'), ((7, 8), \'S\'), ((8, 4), \'S\'), ((9, 4), \'S\'), ((10, 5), \'S\'), ((11, 5), \'S\'), ((12, 5), \'S\'), ((13, 5), \'S\'), ((18, 17), \'A\'), ((17, 13), \'A\'), ((14, 13), \'S\'), ((15, 13), \'S\'), ((16, 13), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'M\', \'C\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'C\', \'P\']}\n{"relation_types": [((4, 3), \'S\'), ((5, 3), \'S\'), ((9, 8), \'S\'), ((7, 6), \'S\'), ((8, 6), \'S\'), ((11, 10), \'A\')]}\n',
#  '### Output:\n{"argument_types": [\'C\', \'P\', \'P\', \'C\', \'P\', \'P\', \'C\', \'M\']}\n{"relation_types": [((2, 1), \'S\'), ((3, 1), \'S\'), ((5, 4), \'S\'), ((6, 4), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'M\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'C\', \'P\', \'P\']}\n{"relation_types": [((4, 5), \'S\'), ((7, 6), \'S\'), ((9, 8), \'S\'), ((5, 3), \'S\'), ((6, 3), \'S\'), ((8, 3), \'S\'), ((12, 10), \'S\'), ((11, 10), \'S\'), ((14, 15), \'S\'), ((15, 13), \'A\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'P\', \'P\', \'P\', \'P\', \'C\', \'C\', \'P\', \'P\', \'C\', \'P\', \'P\']}\n{"relation_types": [((5, 4), \'S\'), ((2, 3), \'S\'), ((3, 6), \'S\'), ((4, 6), \'S\'), ((11, 10), \'S\'), ((12, 11), \'S\'), ((9, 8), \'S\'), ((8, 10), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'C\', \'P\', \'P\', \'C\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\']}\n{"relation_types": [((3, 2), \'S\'), ((4, 2), \'S\'), ((6, 5), \'S\'), ((7, 5), \'S\'), ((10, 9), \'S\'), ((9, 8), \'S\'), ((11, 8), \'S\'), ((12, 8), \'S\'), ((13, 8), \'S\'), ((14, 13), \'S\'), ((15, 13), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'C\', \'C\', \'P\', \'P\', \'C\', \'P\', \'C\', \'P\', \'P\']}\n{"relation_types": [((4, 3), \'S\'), ((5, 6), \'S\'), ((7, 8), \'A\'), ((9, 8), \'S\'), ((10, 8), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'C\', \'M\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\', \'M\']}\n{"relation_types": [((7, 1), \'S\'), ((8, 1), \'S\'), ((3, 1), \'S\'), ((4, 3), \'S\'), ((5, 3), \'S\'), ((10, 9), \'S\'), ((11, 9), \'S\'), ((12, 9), \'S\'), ((13, 9), \'S\'), ((14, 17), \'S\'), ((15, 17), \'S\'), ((16, 17), \'S\'), ((6, 3), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'M\', \'C\', \'M\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\', \'C\', \'P\', \'P\', \'P\']}\n{"relation_types": [((8, 7), \'S\'), ((7, 5), \'S\'), ((5, 6), \'S\'), ((11, 10), \'S\'), ((10, 12), \'S\'), ((9, 12), \'S\'), ((16, 15), \'A\'), ((15, 13), \'A\'), ((14, 13), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'C\', \'M\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'M\']}\n{"relation_types": [((4, 3), \'S\'), ((5, 3), \'S\'), ((6, 3), \'S\'), ((7, 3), \'S\'), ((8, 3), \'S\'), ((11, 9), \'S\'), ((10, 9), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'M\', \'P\', \'P\', \'C\', \'C\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\']}\n{"relation_types": [((4, 5), \'S\'), ((3, 5), \'S\'), ((9, 8), \'S\'), ((7, 6), \'S\'), ((8, 6), \'S\'), ((10, 6), \'S\'), ((13, 11), \'S\'), ((12, 11), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'C\', \'C\', \'M\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'M\', \'C\']}\n{"relation_types": [((7, 8), \'S\'), ((5, 4), \'S\'), ((6, 5), \'S\'), ((8, 4), \'S\'), ((10, 2), \'S\'), ((9, 2), \'S\'), ((12, 11), \'S\'), ((13, 14), \'S\'), ((14, 11), \'A\'), ((15, 14), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'M\', \'M\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\']}\n{"relation_types": [((6, 7), \'S\'), ((9, 4), \'S\'), ((5, 7), \'S\'), ((8, 7), \'S\'), ((14, 13), \'S\'), ((10, 7), \'S\'), ((11, 7), \'S\'), ((12, 7), \'S\'), ((4, 7), \'S\'), ((18, 19), \'S\'), ((16, 15), \'S\'), ((17, 15), \'S\'), ((19, 15), \'S\'), ((20, 15), \'S\'), ((21, 15), \'S\'), ((13, 12), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'C\', \'M\', \'C\', \'C\', \'C\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\']}\n{"relation_types": [((7, 6), \'S\'), ((8, 6), \'S\'), ((9, 6), \'S\'), ((10, 6), \'S\'), ((12, 11), \'S\'), ((13, 11), \'S\'), ((14, 11), \'S\'), ((15, 11), \'S\'), ((16, 11), \'S\'), ((17, 11), \'S\'), ((18, 11), \'S\'), ((20, 19), \'S\'), ((21, 19), \'S\'), ((22, 19), \'S\'), ((23, 19), \'S\'), ((24, 19), \'S\'), ((25, 19), \'S\'), ((26, 19), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'M\', \'C\', \'P\', \'P\', \'C\', \'P\', \'C\', \'P\', \'P\', \'C\', \'P\']}\n{"relation_types": [((4, 3), \'S\'), ((5, 6), \'S\'), ((12, 6), \'S\'), ((7, 6), \'S\'), ((9, 8), \'S\'), ((10, 11), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'C\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'M\']}\n{"relation_types": [((3, 2), \'S\'), ((4, 2), \'S\'), ((6, 5), \'S\'), ((7, 5), \'S\'), ((8, 5), \'S\'), ((10, 9), \'S\'), ((11, 9), \'S\'), ((12, 9), \'S\'), ((14, 15), \'S\'), ((15, 13), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'C\', \'P\', \'P\', \'C\', \'P\', \'M\', \'P\', \'C\', \'C\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\']}\n{"relation_types": [((15, 11), \'S\'), ((14, 11), \'S\'), ((13, 11), \'S\'), ((8, 11), \'S\'), ((12, 11), \'S\'), ((6, 5), \'A\'), ((17, 20), \'S\'), ((18, 20), \'S\'), ((16, 20), \'S\'), ((28, 20), \'S\'), ((19, 28), \'S\'), ((21, 9), \'S\'), ((22, 9), \'S\'), ((23, 22), \'S\'), ((24, 22), \'S\'), ((25, 22), \'S\'), ((26, 10), \'S\'), ((27, 10), \'S\'), ((4, 3), \'A\'), ((3, 2), \'A\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'M\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\']}\n{"relation_types": [((7, 6), \'S\'), ((4, 3), \'S\'), ((5, 3), \'S\'), ((6, 3), \'S\'), ((8, 3), \'S\'), ((10, 9), \'A\'), ((11, 9), \'S\'), ((12, 9), \'S\'), ((13, 9), \'S\'), ((18, 19), \'S\'), ((19, 17), \'S\'), ((17, 14), \'S\'), ((16, 14), \'S\'), ((15, 14), \'S\'), ((20, 14), \'S\'), ((21, 14), \'S\'), ((22, 14), \'A\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'M\', \'C\', \'C\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\']}\n{"relation_types": [((3, 5), \'S\'), ((9, 4), \'S\'), ((8, 4), \'S\'), ((7, 4), \'S\'), ((6, 4), \'S\'), ((12, 11), \'S\'), ((13, 11), \'S\'), ((14, 11), \'S\'), ((11, 10), \'S\'), ((18, 20), \'S\'), ((19, 20), \'S\'), ((20, 15), \'S\'), ((21, 15), \'S\'), ((16, 15), \'S\'), ((17, 15), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'C\', \'M\', \'C\', \'P\', \'C\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\']}\n{"relation_types": [((7, 6), \'S\'), ((9, 5), \'S\'), ((5, 6), \'S\'), ((8, 6), \'S\'), ((13, 10), \'S\'), ((12, 10), \'S\'), ((11, 10), \'S\'), ((15, 14), \'S\'), ((16, 14), \'S\'), ((17, 14), \'S\'), ((18, 14), \'S\'), ((19, 14), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'M\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\']}\n{"relation_types": [((12, 10), \'S\'), ((14, 13), \'S\'), ((10, 11), \'S\'), ((13, 11), \'S\'), ((6, 3), \'S\'), ((7, 3), \'S\'), ((5, 3), \'S\'), ((4, 3), \'S\'), ((8, 9), \'S\'), ((15, 9), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'M\', \'C\', \'P\', \'C\', \'P\', \'C\', \'P\', \'C\', \'P\', \'P\']}\n{"relation_types": [((4, 3), \'S\'), ((10, 9), \'S\'), ((11, 9), \'S\'), ((6, 5), \'S\'), ((8, 7), \'A\')]}\n',
#  '### Output:\n{"argument_types": [\'C\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'M\', \'M\', \'C\']}\n{"relation_types": [((3, 2), \'S\'), ((4, 2), \'S\'), ((5, 2), \'S\'), ((7, 6), \'S\'), ((8, 6), \'S\'), ((9, 6), \'S\'), ((10, 6), \'S\'), ((11, 6), \'S\'), ((13, 12), \'S\'), ((14, 12), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'C\', \'M\', \'C\', \'C\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\']}\n{"relation_types": [((6, 5), \'S\'), ((7, 5), \'S\'), ((8, 5), \'S\'), ((9, 5), \'S\'), ((11, 10), \'S\'), ((12, 10), \'S\'), ((13, 10), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'C\', \'P\', \'P\', \'P\', \'M\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\']}\n{"relation_types": [((11, 10), \'S\'), ((6, 16), \'S\'), ((8, 16), \'S\'), ((10, 16), \'S\'), ((12, 16), \'S\'), ((13, 16), \'S\'), ((14, 16), \'S\'), ((15, 16), \'S\'), ((9, 7), \'S\'), ((17, 7), \'S\'), ((18, 7), \'S\'), ((19, 7), \'S\'), ((20, 7), \'S\'), ((21, 7), \'S\'), ((2, 1), \'S\'), ((3, 1), \'S\'), ((4, 1), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'C\', \'M\', \'C\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\']}\n{"relation_types": [((5, 6), \'S\'), ((6, 4), \'S\'), ((7, 4), \'S\'), ((9, 8), \'S\'), ((10, 8), \'S\'), ((11, 8), \'S\'), ((12, 8), \'S\'), ((13, 8), \'S\'), ((15, 14), \'S\'), ((16, 14), \'S\'), ((17, 14), \'S\'), ((18, 14), \'S\'), ((19, 14), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'C\', \'P\', \'P\', \'P\', \'C\', \'C\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'M\']}\n{"relation_types": [((3, 6), \'S\'), ((4, 6), \'S\'), ((5, 6), \'S\'), ((10, 7), \'S\'), ((11, 7), \'S\'), ((9, 7), \'S\'), ((8, 7), \'S\'), ((13, 12), \'A\'), ((14, 13), \'S\'), ((15, 12), \'A\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'M\', \'C\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\']}\n{"relation_types": [((6, 7), \'S\'), ((7, 3), \'S\'), ((4, 3), \'S\'), ((5, 3), \'S\'), ((9, 8), \'S\'), ((10, 8), \'S\'), ((11, 8), \'S\'), ((12, 8), \'S\'), ((13, 8), \'S\'), ((15, 8), \'S\'), ((14, 8), \'S\'), ((17, 8), \'S\'), ((16, 15), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'M\']}\n{"relation_types": [((4, 3), \'S\'), ((5, 3), \'S\'), ((6, 4), \'S\'), ((7, 3), \'S\'), ((2, 3), \'S\'), ((9, 8), \'S\'), ((10, 11), \'S\'), ((12, 11), \'S\'), ((13, 12), \'S\'), ((14, 12), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'M\', \'C\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\']}\n{"relation_types": [((9, 5), \'S\'), ((8, 5), \'S\'), ((7, 5), \'S\'), ((6, 5), \'S\'), ((4, 5), \'S\'), ((15, 10), \'S\'), ((14, 13), \'S\'), ((10, 13), \'S\'), ((11, 13), \'S\'), ((12, 13), \'S\'), ((19, 20), \'S\'), ((18, 20), \'S\'), ((17, 20), \'S\'), ((16, 20), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'C\', \'C\', \'C\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'C\', \'M\']}\n{"relation_types": [((11, 10), \'S\'), ((6, 5), \'S\'), ((7, 5), \'S\'), ((8, 5), \'S\'), ((9, 5), \'S\'), ((10, 5), \'S\'), ((13, 12), \'S\'), ((14, 12), \'S\'), ((15, 12), \'S\'), ((16, 19), \'S\'), ((17, 19), \'S\'), ((18, 19), \'S\'), ((20, 19), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'M\', \'C\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\']}\n{"relation_types": [((5, 4), \'A\'), ((4, 7), \'A\'), ((8, 7), \'S\'), ((6, 7), \'S\'), ((12, 10), \'S\'), ((9, 10), \'S\'), ((11, 10), \'S\'), ((13, 10), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\', \'M\', \'C\']}\n{"relation_types": [((7, 9), \'S\'), ((8, 9), \'S\'), ((5, 9), \'S\'), ((3, 9), \'S\'), ((4, 9), \'S\'), ((6, 9), \'S\'), ((10, 11), \'S\'), ((14, 15), \'S\'), ((13, 14), \'A\'), ((11, 15), \'S\'), ((12, 15), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'M\', \'C\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\']}\n{"relation_types": [((18, 17), \'S\'), ((15, 14), \'S\'), ((16, 14), \'S\'), ((17, 14), \'S\'), ((6, 10), \'S\'), ((10, 13), \'S\'), ((13, 12), \'S\'), ((11, 12), \'S\'), ((19, 5), \'S\'), ((7, 4), \'S\'), ((4, 5), \'S\'), ((8, 9), \'S\'), ((9, 5), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\', \'M\']}\n{"relation_types": [((4, 2), \'S\'), ((3, 2), \'S\'), ((6, 5), \'S\'), ((5, 9), \'S\'), ((8, 7), \'S\'), ((7, 9), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'C\', \'P\', \'C\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'C\', \'C\', \'P\', \'M\']}\n{"relation_types": [((3, 2), \'S\'), ((5, 4), \'S\'), ((7, 6), \'A\'), ((6, 4), \'A\'), ((9, 8), \'S\'), ((11, 12), \'S\'), ((10, 12), \'S\'), ((14, 13), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'M\', \'C\']}\n{"relation_types": [((6, 5), \'S\'), ((4, 3), \'S\'), ((3, 2), \'S\'), ((5, 2), \'S\'), ((7, 2), \'S\'), ((10, 9), \'S\'), ((8, 9), \'S\'), ((11, 10), \'S\'), ((12, 8), \'S\'), ((13, 8), \'S\'), ((14, 8), \'S\'), ((16, 17), \'S\'), ((19, 18), \'S\'), ((20, 18), \'S\'), ((21, 18), \'S\'), ((18, 15), \'S\'), ((17, 15), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'C\', \'C\', \'P\', \'M\']}\n{"relation_types": [((3, 2), \'S\'), ((5, 4), \'S\'), ((2, 4), \'S\'), ((9, 10), \'S\'), ((8, 10), \'S\'), ((6, 7), \'S\'), ((7, 10), \'S\'), ((11, 13), \'S\'), ((12, 13), \'S\'), ((15, 14), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'C\', \'M\', \'C\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\']}\n{"relation_types": [((10, 9), \'S\'), ((5, 6), \'S\'), ((8, 7), \'S\'), ((9, 7), \'S\'), ((6, 7), \'S\'), ((11, 7), \'S\'), ((14, 12), \'S\'), ((13, 12), \'S\'), ((15, 12), \'S\'), ((16, 12), \'S\'), ((18, 17), \'S\'), ((19, 17), \'A\'), ((20, 19), \'S\'), ((21, 22), \'S\'), ((22, 17), \'A\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'M\', \'P\', \'C\', \'P\', \'P\', \'C\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\']}\n{"relation_types": [((5, 6), \'S\'), ((6, 4), \'S\'), ((3, 4), \'S\'), ((8, 7), \'S\'), ((9, 7), \'S\'), ((11, 10), \'S\'), ((12, 10), \'S\'), ((14, 13), \'S\'), ((13, 10), \'S\'), ((15, 11), \'A\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'M\', \'P\', \'P\', \'P\', \'P\', \'C\', \'C\', \'P\', \'P\', \'P\', \'P\', \'C\']}\n{"relation_types": [((5, 8), \'S\'), ((4, 8), \'S\'), ((6, 8), \'S\'), ((7, 8), \'S\'), ((11, 10), \'S\'), ((10, 9), \'S\'), ((12, 9), \'S\'), ((13, 9), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'C\', \'M\', \'C\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\']}\n{"relation_types": [((8, 4), \'S\'), ((5, 4), \'S\'), ((7, 4), \'S\'), ((17, 4), \'S\'), ((6, 4), \'S\'), ((11, 12), \'S\'), ((12, 9), \'S\'), ((14, 15), \'S\'), ((15, 9), \'S\'), ((16, 9), \'S\'), ((10, 9), \'S\'), ((13, 9), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'M\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\', \'C\', \'P\', \'P\', \'P\', \'P\', \'C\']}\n{"relation_types": [((5, 11), \'S\'), ((6, 11), \'A\'), ((7, 6), \'S\'), ((8, 7), \'S\'), ((9, 11), \'S\'), ((10, 11), \'S\'), ((13, 12), \'S\'), ((14, 12), \'S\'), ((15, 12), \'S\'), ((16, 12), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'P\', \'P\', \'C\', \'P\', \'C\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'M\', \'C\']}\n{"relation_types": [((3, 4), \'S\'), ((2, 4), \'S\'), ((8, 5), \'S\'), ((5, 6), \'S\'), ((7, 6), \'S\'), ((12, 10), \'S\'), ((11, 10), \'S\'), ((9, 10), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'M\', \'C\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\']}\n{"relation_types": [((7, 5), \'S\'), ((6, 5), \'S\'), ((8, 4), \'S\'), ((5, 4), \'S\'), ((9, 4), \'S\'), ((14, 10), \'S\'), ((12, 10), \'S\'), ((13, 10), \'S\'), ((11, 10), \'S\'), ((16, 15), \'S\'), ((17, 15), \'S\'), ((18, 15), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'M\', \'C\', \'C\', \'M\', \'P\', \'P\', \'P\', \'C\', \'C\', \'P\', \'P\', \'P\', \'P\']}\n{"relation_types": [((6, 9), \'S\'), ((7, 9), \'S\'), ((8, 9), \'S\'), ((11, 10), \'S\'), ((12, 10), \'S\'), ((13, 10), \'S\'), ((14, 10), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'M\', \'C\', \'M\', \'C\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'C\', \'P\']}\n{"relation_types": [((11, 12), \'S\'), ((12, 8), \'S\'), ((10, 8), \'S\'), ((9, 8), \'S\'), ((15, 14), \'S\'), ((13, 16), \'S\'), ((17, 20), \'S\'), ((18, 20), \'S\'), ((14, 20), \'S\'), ((16, 20), \'S\'), ((21, 22), \'S\'), ((25, 24), \'S\'), ((22, 24), \'S\'), ((23, 24), \'S\'), ((6, 5), \'S\'), ((7, 5), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'M\', \'C\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'C\', \'C\', \'P\', \'P\', \'P\', \'P\', \'C\']}\n{"relation_types": [((4, 6), \'S\'), ((5, 6), \'S\'), ((9, 8), \'S\'), ((7, 11), \'S\'), ((8, 11), \'S\'), ((10, 11), \'S\'), ((16, 12), \'A\'), ((13, 12), \'S\'), ((15, 14), \'S\'), ((14, 12), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'C\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'C\', \'C\', \'M\']}\n{"relation_types": [((3, 5), \'S\'), ((4, 5), \'S\'), ((8, 7), \'S\'), ((6, 9), \'S\'), ((7, 9), \'S\'), ((10, 14), \'S\'), ((11, 14), \'S\'), ((12, 14), \'S\'), ((13, 14), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'C\', \'M\', \'M\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\']}\n{"relation_types": [((13, 14), \'S\'), ((7, 6), \'S\'), ((8, 6), \'S\'), ((9, 6), \'S\'), ((6, 10), \'S\'), ((5, 10), \'S\'), ((16, 15), \'S\'), ((12, 15), \'S\'), ((11, 15), \'S\'), ((17, 15), \'S\'), ((14, 15), \'S\'), ((18, 22), \'S\'), ((19, 22), \'S\'), ((20, 22), \'S\'), ((21, 22), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'M\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\']}\n{"relation_types": [((7, 6), \'S\'), ((9, 8), \'S\'), ((3, 8), \'S\'), ((4, 8), \'S\'), ((5, 8), \'S\'), ((6, 8), \'S\'), ((11, 10), \'S\'), ((12, 10), \'S\'), ((13, 10), \'S\'), ((14, 10), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'C\', \'C\', \'M\', \'C\', \'C\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'M\']}\n{"relation_types": [((8, 7), \'S\'), ((9, 7), \'S\'), ((10, 7), \'S\'), ((11, 7), \'S\'), ((12, 7), \'S\'), ((14, 13), \'S\'), ((16, 15), \'S\'), ((13, 15), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'C\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\', \'M\', \'C\', \'C\']}\n{"relation_types": [((10, 3), \'S\'), ((9, 8), \'S\'), ((4, 3), \'S\'), ((5, 3), \'S\'), ((6, 3), \'S\'), ((7, 3), \'A\'), ((8, 7), \'S\'), ((12, 11), \'S\'), ((13, 11), \'S\'), ((11, 14), \'S\'), ((14, 15), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'C\', \'M\', \'P\', \'C\', \'P\', \'P\']}\n{"relation_types": [((2, 7), \'S\'), ((3, 7), \'S\'), ((4, 7), \'S\'), ((6, 5), \'S\'), ((8, 5), \'S\'), ((5, 7), \'S\'), ((9, 12), \'S\'), ((10, 12), \'S\'), ((11, 12), \'S\'), ((13, 15), \'S\'), ((14, 15), \'S\'), ((19, 18), \'S\'), ((17, 18), \'S\'), ((20, 18), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'C\', \'P\', \'P\', \'C\', \'P\', \'C\', \'C\']}\n{"relation_types": [((6, 5), \'S\'), ((4, 5), \'S\'), ((3, 2), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'C\', \'M\']}\n{"relation_types": [((3, 2), \'A\'), ((2, 4), \'A\'), ((9, 8), \'S\'), ((6, 7), \'S\'), ((5, 4), \'S\'), ((7, 4), \'S\'), ((8, 4), \'S\'), ((10, 4), \'S\'), ((13, 12), \'A\'), ((12, 11), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\']}\n{"relation_types": [((3, 9), \'S\'), ((4, 5), \'S\'), ((5, 9), \'S\'), ((6, 9), \'S\'), ((7, 6), \'A\'), ((8, 7), \'A\'), ((11, 10), \'S\'), ((12, 11), \'A\'), ((13, 12), \'A\'), ((14, 10), \'S\'), ((16, 17), \'S\'), ((17, 10), \'S\'), ((15, 10), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'C\', \'M\', \'M\', \'C\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\']}\n{"relation_types": [((7, 4), \'S\'), ((8, 4), \'S\'), ((6, 5), \'S\'), ((5, 4), \'S\'), ((12, 9), \'S\'), ((11, 9), \'S\'), ((10, 9), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'M\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\']}\n{"relation_types": [((5, 6), \'S\'), ((3, 6), \'S\'), ((4, 6), \'S\'), ((7, 13), \'S\'), ((8, 13), \'A\'), ((9, 8), \'A\'), ((10, 8), \'A\'), ((11, 13), \'S\'), ((12, 13), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'C\', \'M\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'C\', \'P\']}\n{"relation_types": [((9, 8), \'S\'), ((8, 7), \'S\'), ((6, 5), \'S\'), ((7, 11), \'S\'), ((10, 7), \'S\'), ((5, 16), \'S\'), ((16, 11), \'S\'), ((12, 15), \'S\'), ((14, 13), \'S\'), ((13, 15), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\', \'C\', \'P\', \'P\']}\n{"relation_types": [((4, 5), \'S\'), ((5, 6), \'S\'), ((3, 8), \'S\'), ((6, 8), \'S\'), ((7, 8), \'S\'), ((13, 12), \'S\'), ((12, 11), \'S\'), ((10, 9), \'S\'), ((9, 14), \'S\'), ((11, 14), \'S\'), ((16, 15), \'S\'), ((17, 15), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\', \'M\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\']}\n{"relation_types": [((4, 22), \'S\'), ((22, 2), \'S\'), ((3, 2), \'S\'), ((5, 2), \'S\'), ((14, 15), \'S\'), ((12, 15), \'S\'), ((13, 15), \'S\'), ((21, 15), \'S\'), ((20, 15), \'S\'), ((19, 15), \'S\'), ((17, 18), \'S\'), ((7, 6), \'S\'), ((6, 9), \'S\'), ((8, 9), \'S\'), ((11, 9), \'S\'), ((10, 9), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'C\', \'M\', \'C\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\']}\n{"relation_types": [((5, 4), \'S\'), ((6, 4), \'S\'), ((8, 7), \'S\'), ((7, 10), \'S\'), ((9, 10), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'M\', \'C\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'C\']}\n{"relation_types": [((4, 6), \'S\'), ((5, 6), \'S\'), ((7, 10), \'S\'), ((8, 10), \'S\'), ((9, 10), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'M\', \'C\', \'P\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\', \'C\', \'M\', \'C\']}\n{"relation_types": [((4, 2), \'S\'), ((3, 2), \'S\'), ((6, 5), \'S\'), ((7, 5), \'S\'), ((8, 10), \'S\'), ((9, 10), \'S\')]}\n',
#  '### Output:\n{"argument_types": [\'C\', \'M\', \'P\', \'P\', \'P\', \'P\', \'P\', \'C\', \'P\', \'C\', \'P\', \'C\', \'P\', \'P\', \'P\', \'P\']}\n{"relation_types": [((3, 8), \'S\'), ((4, 8), \'S\'), ((5, 8), \'S\'), ((6, 8), \'S\'), ((7, 8), \'S\'), ((13, 12), \'S\'), ((14, 12), \'S\'), ((11, 10), \'S\'), ((9, 10), \'S\'), ((15, 10), \'S\'), ((16, 10), \'S\')]}\n']

# %%
def process_grounds(grounds):
    
    arg_types = []
    #rel_pairs = []
    rel_types = []
    
    for grounds in grounds:
        
        args = grounds.split("\n")[1].replace("'", '"')
        arg_types.append(json.loads(args)["argument_types"])
        
        rels = re.sub(r'\((\d+), (\d+)\)', r'[\1, \2]', grounds.split("\n")[2])
        rels = eval(rels)["relation_types"]
        rels = [(tuple(pair), label) for pair, label in rels]
        rel_types.append(rels)
        
    return arg_types, rel_types

# %%
grounds_acc, grounds_aric  = process_grounds(grounds)

# %%
def process_predictions(predictions):
    
    arg_types = []
    rel_types = []
    
    for pred in predictions:
        
        args = pred.split("\n")[1].replace("'", '"')
        arg_types.append(json.loads(args)["argument_types"])
        
        rels = re.sub(r'\((\d+), (\d+)\)', r'[\1, \2]', pred.split("\n")[2])
        rels = eval(rels)["relation_types"]
        rels = [(tuple(pair), label) for pair, label in rels]
        rel_types.append(rels)
        
    return arg_types, rel_types

# %%
predictions_acc, predictions_aric  = process_predictions(predictions)

# %%
for idx, (g, p) in enumerate(zip(grounds_acc, predictions_acc)):
    
    if len(p) > len(g):
        predictions_acc[idx] = p[:len(g)]

# %%
grounds = [elem for sublist in grounds_acc for elem in sublist]
predictions = [elem for sublist in predictions_acc for elem in sublist]

# %%
print(classification_report(grounds, predictions, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#            C      0.802     0.786     0.794       304
#            M      0.973     0.935     0.953       153
#            P      0.924     0.938     0.931       809
#
#     accuracy                          0.901      1266
#    macro avg      0.900     0.886     0.893      1266
# weighted avg      0.901     0.901     0.901      1266

# %%
print(confusion_matrix(grounds, predictions))
# Out:
# [[239   4  61]
#  [  9 143   1]
#  [ 50   0 759]]

# %%
c_wrong = [idx for idx, elem in enumerate(grounds) if (elem == "C" and predictions[idx] == "P")]

# %%
len(c_wrong)
# Out:
# 61

# %%
c_wrong
# Out:
# [27,
#  48,
#  62,
#  121,
#  135,
#  160,
#  167,
#  168,
#  180,
#  195,
#  250,
#  276,
#  278,
#  304,
#  343,
#  363,
#  410,
#  415,
#  437,
#  442,
#  486,
#  509,
#  523,
#  532,
#  534,
#  545,
#  594,
#  624,
#  705,
#  730,
#  736,
#  766,
#  779,
#  797,
#  815,
#  844,
#  909,
#  915,
#  940,
#  941,
#  970,
#  974,
#  987,
#  992,
#  1006,
#  1038,
#  1050,
#  1058,
#  1063,
#  1075,
#  1103,
#  1105,
#  1106,
#  1177,
#  1186,
#  1204,
#  1210,
#  1227,
#  1230,
#  1233,
#  1247]

# %%
df = pd.read_csv("/Utilisateurs/umushtaq/am_reasoning/data_files/pe_dataset_new.csv", index_col=0)

# %%
df
# Out:
#     ann_file_name                                       argument_ids  \
# 0    essay001.ann  ['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8...
# 1    essay002.ann  ['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8...
# 2    essay003.ann  ['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8...
# 3    essay004.ann  ['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8...
# 4    essay005.ann  ['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8...
# ..            ...                                                ...
# 397  essay398.ann  ['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8...
# 398  essay399.ann  ['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8...
# 399  essay400.ann  ['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8...
# 400  essay401.ann  ['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8...
# 401  essay402.ann  ['T1', 'T2', 'T3', 'T5', 'T6', 'T7', 'T8', 'T4...
#
#                                         argument_types  \
# 0    ['MajorClaim', 'MajorClaim', 'Claim', 'Premise...
# 1    ['MajorClaim', 'MajorClaim', 'Premise', 'Claim...
# 2    ['MajorClaim', 'MajorClaim', 'Claim', 'Premise...
# 3    ['MajorClaim', 'MajorClaim', 'Claim', 'Claim',...
# 4    ['MajorClaim', 'MajorClaim', 'Claim', 'Claim',...
# ..                                                 ...
# 397  ['Claim', 'MajorClaim', 'Premise', 'Premise', ...
# 398  ['MajorClaim', 'MajorClaim', 'Claim', 'Premise...
# 399  ['MajorClaim', 'MajorClaim', 'Claim', 'Premise...
# 400  ['MajorClaim', 'MajorClaim', 'Premise', 'Premi...
# 401  ['MajorClaim', 'MajorClaim', 'Premise', 'Premi...
#
#                                       arg_start_bounds  \
# 0    ['503', '2154', '591', '716', '853', '1088', '...
# 1    ['391', '1936', '500', '1089', '626', '841', '...
# 2    ['352', '1568', '955', '487', '615', '786', '1...
# 3    ['262', '1663', '179', '953', '1578', '417', '...
# 4    ['286', '1535', '388', '775', '1330', '566', '...
# ..                                                 ...
# 397  ['254', '1751', '409', '557', '647', '778', '9...
# 398  ['367', '1323', '527', '431', '661', '787', '9...
# 399  ['274', '1619', '736', '541', '805', '389', '1...
# 400  ['311', '1496', '502', '622', '386', '954', '1...
# 401  ['238', '1543', '379', '544', '725', '827', '3...
#
#                                         arg_end_bounds  \
# 0    ['575', '2231', '714', '851', '1086', '1191', ...
# 1    ['489', '2077', '624', '1156', '839', '946', '...
# 2    ['475', '1701', '1012', '613', '784', '943', '...
# 3    ['376', '1758', '239', '1031', '1624', '530', ...
# 4    ['359', '1652', '564', '883', '1425', '765', '...
# ..                                                 ...
# 397  ['318', '1951', '541', '645', '767', '897', '1...
# 398  ['429', '1390', '645', '525', '737', '951', '1...
# 399  ['387', '1812', '796', '723', '944', '524', '1...
# 400  ['384', '1667', '607', '815', '488', '1087', '...
# 401  ['307', '1620', '462', '723', '810', '896', '3...
#
#                                    argument_components  \
# 0    ['we should attach more importance to cooperat...
# 1    ['they are able to sustain their cultural iden...
# 2    ['it has contributed to the economic developme...
# 3    ['this industry has affected the cultural attr...
# 4    ['one who studies overseas will gain many skil...
# ..                                                 ...
# 397  ['many different characters exist between male...
# 398  ['this is a worrying tread which has negative ...
# 399  ['governments should devote a greater portion ...
# 400  ['fatherhood is a as vital part of a healty pa...
# 401  ['both of studying hard and playing sports are...
#
#                                            source_args  \
# 0                ['T4', 'T5', 'T6', 'T10', 'T9', 'T8']
# 1    ['T9', 'T11', 'T12', 'T13', 'T5', 'T6', 'T7', ...
# 2                ['T10', 'T9', 'T6', 'T5', 'T4', 'T7']
# 3               ['T8', 'T7', 'T6', 'T10', 'T9', 'T11']
# 4               ['T6', 'T7', 'T8', 'T9', 'T10', 'T11']
# ..                                                 ...
# 397  ['T3', 'T4', 'T5', 'T6', 'T7', 'T13', 'T14', '...
# 398                    ['T4', 'T5', 'T6', 'T8', 'T10']
# 399               ['T4', 'T5', 'T6', 'T7', 'T9', 'T8']
# 400              ['T3', 'T7', 'T10', 'T4', 'T9', 'T6']
# 401  ['T5', 'T3', 'T6', 'T11', 'T12', 'T4', 'T13', ...
#
#                                            target_args  \
# 0               ['T3', 'T3', 'T3', 'T11', 'T11', 'T7']
# 1    ['T8', 'T10', 'T10', 'T10', 'T4', 'T4', 'T4', ...
# 2                 ['T8', 'T8', 'T3', 'T3', 'T3', 'T8']
# 3                ['T4', 'T4', 'T4', 'T11', 'T5', 'T5']
# 4                 ['T3', 'T4', 'T7', 'T4', 'T5', 'T5']
# ..                                                 ...
# 397  ['T8', 'T8', 'T8', 'T8', 'T8', 'T12', 'T12', '...
# 398                     ['T3', 'T3', 'T7', 'T7', 'T9']
# 399              ['T3', 'T3', 'T3', 'T8', 'T8', 'T10']
# 400               ['T5', 'T6', 'T8', 'T3', 'T8', 'T8']
# 401  ['T8', 'T8', 'T5', 'T10', 'T13', 'T15', 'T4', ...
#
#                                         relation_types  \
# 0    ['supports', 'supports', 'supports', 'supports...
# 1    ['supports', 'supports', 'supports', 'supports...
# 2    ['supports', 'supports', 'supports', 'supports...
# 3    ['supports', 'supports', 'supports', 'supports...
# 4    ['supports', 'attacks', 'attacks', 'supports',...
# ..                                                 ...
# 397  ['supports', 'supports', 'supports', 'supports...
# 398  ['supports', 'supports', 'supports', 'supports...
# 399  ['supports', 'supports', 'supports', 'supports...
# 400  ['supports', 'supports', 'supports', 'supports...
# 401  ['supports', 'supports', 'supports', 'supports...
#
#                                            essay_title  \
# 0    Should students be taught to compete or to coo...
# 1    More people are migrating to other countries t...
# 2    International tourism is now more common than ...
# 3    International tourism is now more common than ...
# 4                         Living and studying overseas
# ..                                                 ...
# 397  We can not forcedly put the same numbers of ma...
# 398                 Drugs, alcohol and messy sex lives
# 399  A greater proportion of the budget should be a...
# 400  Fatherhood should be as present as motherhood ...
# 401  Children should studying hard or playing sport...
#
#                                             essay_text  split
# 0    It is always said that competition can effecti...  TRAIN
# 1    The last 50 years have seen an increasing numb...  TRAIN
# 2    The last decade has seen an increasing number ...  TRAIN
# 3    The last 50 years have seen a significant incr...   TEST
# 4    It is every student's desire to study at a goo...   TEST
# ..                                                 ...    ...
# 397  There is a view that universities and colleges...   TEST
# 398  Celebrities, for example movie stars, are usua...  TRAIN
# 399  In today's world, the concept of the welfare s...  TRAIN
# 400  In today's world, having and raising children ...  TRAIN
# 401  Some people believe that studying hard is esse...  TRAIN
#
# [402 rows x 12 columns]

# %%
df_test = df[df.split == "TEST"].reset_index(drop=True)

# %%
df_test
# Out:
#    ann_file_name                                       argument_ids  \
# 0   essay004.ann  ['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8...
# 1   essay005.ann  ['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8...
# 2   essay006.ann  ['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8...
# 3   essay021.ann  ['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8...
# 4   essay042.ann  ['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8...
# ..           ...                                                ...
# 75  essay373.ann  ['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8...
# 76  essay382.ann  ['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8...
# 77  essay386.ann  ['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8...
# 78  essay393.ann  ['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8...
# 79  essay398.ann  ['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8...
#
#                                        argument_types  \
# 0   ['MajorClaim', 'MajorClaim', 'Claim', 'Claim',...
# 1   ['MajorClaim', 'MajorClaim', 'Claim', 'Claim',...
# 2   ['MajorClaim', 'MajorClaim', 'Claim', 'Claim',...
# 3   ['MajorClaim', 'MajorClaim', 'Claim', 'Premise...
# 4   ['MajorClaim', 'MajorClaim', 'Claim', 'Claim',...
# ..                                                ...
# 75  ['MajorClaim', 'Claim', 'Premise', 'Premise', ...
# 76  ['MajorClaim', 'Claim', 'MajorClaim', 'Claim',...
# 77  ['MajorClaim', 'MajorClaim', 'Claim', 'Premise...
# 78  ['MajorClaim', 'Claim', 'Premise', 'Premise', ...
# 79  ['Claim', 'MajorClaim', 'Premise', 'Premise', ...
#
#                                      arg_start_bounds  \
# 0   ['262', '1663', '179', '953', '1578', '417', '...
# 1   ['286', '1535', '388', '775', '1330', '566', '...
# 2   ['174', '1667', '211', '309', '779', '1092', '...
# 3   ['325', '1701', '118', '218', '250', '479', '1...
# 4   ['1562', '1665', '1776', '346', '1055', '425',...
# ..                                                ...
# 75  ['607', '1063', '790', '950', '719', '1229', '...
# 76  ['274', '1429', '1369', '409', '534', '657', '...
# 77  ['324', '1574', '1629', '518', '748', '433', '...
# 78  ['249', '622', '341', '450', '1190', '1014', '...
# 79  ['254', '1751', '409', '557', '647', '778', '9...
#
#                                        arg_end_bounds  \
# 0   ['376', '1758', '239', '1031', '1624', '530', ...
# 1   ['359', '1652', '564', '883', '1425', '765', '...
# 2   ['209', '1759', '293', '407', '892', '1147', '...
# 3   ['384', '1769', '207', '248', '308', '569', '1...
# 4   ['1648', '1769', '1856', '423', '1203', '533',...
# ..                                                ...
# 75  ['684', '1146', '933', '986', '788', '1295', '...
# 76  ['386', '1502', '1424', '532', '655', '800', '...
# 77  ['416', '1625', '1756', '746', '977', '516', '...
# 78  ['315', '810', '448', '606', '1324', '1182', '...
# 79  ['318', '1951', '541', '645', '767', '897', '1...
#
#                                   argument_components  \
# 0   ['this industry has affected the cultural attr...
# 1   ['one who studies overseas will gain many skil...
# 2   ['studying abroad has many advantages', 'study...
# 3   ['advertising is the major reason for high sal...
# 4   ['a higher pay can be one of the incentive if ...
# ..                                                ...
# 75  ['it is no evidence about the reduction of cri...
# 76  ["the richness as well as convenience of techn...
# 77  ['the classmates should be regarded as the mos...
# 78  ['such details should be strictly censored, if...
# 79  ['many different characters exist between male...
#
#                                           source_args  \
# 0              ['T8', 'T7', 'T6', 'T10', 'T9', 'T11']
# 1              ['T6', 'T7', 'T8', 'T9', 'T10', 'T11']
# 2   ['T7', 'T8', 'T10', 'T9', 'T11', 'T12', 'T13',...
# 3   ['T5', 'T4', 'T9', 'T11', 'T12', 'T10', 'T13',...
# 4              ['T6', 'T7', 'T8', 'T9', 'T10', 'T11']
# ..                                                ...
# 75  ['T4', 'T22', 'T3', 'T5', 'T14', 'T12', 'T13',...
# 76                     ['T5', 'T6', 'T8', 'T7', 'T9']
# 77                     ['T4', 'T5', 'T7', 'T8', 'T9']
# 78               ['T4', 'T3', 'T6', 'T7', 'T8', 'T9']
# 79  ['T3', 'T4', 'T5', 'T6', 'T7', 'T13', 'T14', '...
#
#                                           target_args  \
# 0               ['T4', 'T4', 'T4', 'T11', 'T5', 'T5']
# 1                ['T3', 'T4', 'T7', 'T4', 'T5', 'T5']
# 2   ['T4', 'T9', 'T9', 'T4', 'T5', 'T5', 'T6', 'T6...
# 3   ['T3', 'T3', 'T6', 'T13', 'T13', 'T6', 'T6', '...
# 4                ['T4', 'T4', 'T7', 'T7', 'T5', 'T5']
# ..                                                ...
# 75  ['T22', 'T2', 'T2', 'T2', 'T15', 'T15', 'T15',...
# 76                   ['T4', 'T4', 'T7', 'T10', 'T10']
# 77                  ['T6', 'T6', 'T10', 'T10', 'T10']
# 78             ['T2', 'T2', 'T5', 'T5', 'T10', 'T10']
# 79  ['T8', 'T8', 'T8', 'T8', 'T8', 'T12', 'T12', '...
#
#                                        relation_types  \
# 0   ['supports', 'supports', 'supports', 'supports...
# 1   ['supports', 'attacks', 'attacks', 'supports',...
# 2   ['supports', 'supports', 'supports', 'supports...
# 3   ['supports', 'supports', 'supports', 'supports...
# 4   ['supports', 'supports', 'supports', 'supports...
# ..                                                ...
# 75  ['supports', 'supports', 'supports', 'supports...
# 76  ['supports', 'supports', 'supports', 'supports...
# 77  ['supports', 'supports', 'supports', 'supports...
# 78  ['supports', 'supports', 'supports', 'supports...
# 79  ['supports', 'supports', 'supports', 'supports...
#
#                                           essay_title  \
# 0   International tourism is now more common than ...
# 1                        Living and studying overseas
# 2   Studies abroad and the cultural aspect of the ...
# 3            Advertisements affects on consumer goods
# 4   Paying more money is the only motivation to ma...
# ..                                                ...
# 75  Capital punishment; 51% countries have polishe...
# 76  Technology helps student learn more informatio...
# 77  Classmates' impacts on children's performance ...
# 78  Detailed description of crimes on newspaper an...
# 79  We can not forcedly put the same numbers of ma...
#
#                                            essay_text split
# 0   The last 50 years have seen a significant incr...  TEST
# 1   It is every student's desire to study at a goo...  TEST
# 2   Studying abroad is one very common thing that ...  TEST
# 3   Everyday, companies offer a huge number of dif...  TEST
# 4   The purpose of this essay is to discuss whethe...  TEST
# ..                                                ...   ...
# 75  "Capital punishment or the death penalty is a ...  TEST
# 76  Nowadays, technology plays an indispensable ro...  TEST
# 77  It goes without saying that no pupil can succe...  TEST
# 78  Nowadays, the print as well as the electronic ...  TEST
# 79  There is a view that universities and colleges...  TEST
#
# [80 rows x 12 columns]

# %%
df_expanded = df_test.explode('argument_components').reset_index(drop=True)

# %%
df_expanded
# Out:
#    ann_file_name                                       argument_ids  \
# 0   essay004.ann  ['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8...
# 1   essay005.ann  ['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8...
# 2   essay006.ann  ['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8...
# 3   essay021.ann  ['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8...
# 4   essay042.ann  ['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8...
# ..           ...                                                ...
# 75  essay373.ann  ['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8...
# 76  essay382.ann  ['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8...
# 77  essay386.ann  ['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8...
# 78  essay393.ann  ['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8...
# 79  essay398.ann  ['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8...
#
#                                        argument_types  \
# 0   ['MajorClaim', 'MajorClaim', 'Claim', 'Claim',...
# 1   ['MajorClaim', 'MajorClaim', 'Claim', 'Claim',...
# 2   ['MajorClaim', 'MajorClaim', 'Claim', 'Claim',...
# 3   ['MajorClaim', 'MajorClaim', 'Claim', 'Premise...
# 4   ['MajorClaim', 'MajorClaim', 'Claim', 'Claim',...
# ..                                                ...
# 75  ['MajorClaim', 'Claim', 'Premise', 'Premise', ...
# 76  ['MajorClaim', 'Claim', 'MajorClaim', 'Claim',...
# 77  ['MajorClaim', 'MajorClaim', 'Claim', 'Premise...
# 78  ['MajorClaim', 'Claim', 'Premise', 'Premise', ...
# 79  ['Claim', 'MajorClaim', 'Premise', 'Premise', ...
#
#                                      arg_start_bounds  \
# 0   ['262', '1663', '179', '953', '1578', '417', '...
# 1   ['286', '1535', '388', '775', '1330', '566', '...
# 2   ['174', '1667', '211', '309', '779', '1092', '...
# 3   ['325', '1701', '118', '218', '250', '479', '1...
# 4   ['1562', '1665', '1776', '346', '1055', '425',...
# ..                                                ...
# 75  ['607', '1063', '790', '950', '719', '1229', '...
# 76  ['274', '1429', '1369', '409', '534', '657', '...
# 77  ['324', '1574', '1629', '518', '748', '433', '...
# 78  ['249', '622', '341', '450', '1190', '1014', '...
# 79  ['254', '1751', '409', '557', '647', '778', '9...
#
#                                        arg_end_bounds  \
# 0   ['376', '1758', '239', '1031', '1624', '530', ...
# 1   ['359', '1652', '564', '883', '1425', '765', '...
# 2   ['209', '1759', '293', '407', '892', '1147', '...
# 3   ['384', '1769', '207', '248', '308', '569', '1...
# 4   ['1648', '1769', '1856', '423', '1203', '533',...
# ..                                                ...
# 75  ['684', '1146', '933', '986', '788', '1295', '...
# 76  ['386', '1502', '1424', '532', '655', '800', '...
# 77  ['416', '1625', '1756', '746', '977', '516', '...
# 78  ['315', '810', '448', '606', '1324', '1182', '...
# 79  ['318', '1951', '541', '645', '767', '897', '1...
#
#                                   argument_components  \
# 0   ['this industry has affected the cultural attr...
# 1   ['one who studies overseas will gain many skil...
# 2   ['studying abroad has many advantages', 'study...
# 3   ['advertising is the major reason for high sal...
# 4   ['a higher pay can be one of the incentive if ...
# ..                                                ...
# 75  ['it is no evidence about the reduction of cri...
# 76  ["the richness as well as convenience of techn...
# 77  ['the classmates should be regarded as the mos...
# 78  ['such details should be strictly censored, if...
# 79  ['many different characters exist between male...
#
#                                           source_args  \
# 0              ['T8', 'T7', 'T6', 'T10', 'T9', 'T11']
# 1              ['T6', 'T7', 'T8', 'T9', 'T10', 'T11']
# 2   ['T7', 'T8', 'T10', 'T9', 'T11', 'T12', 'T13',...
# 3   ['T5', 'T4', 'T9', 'T11', 'T12', 'T10', 'T13',...
# 4              ['T6', 'T7', 'T8', 'T9', 'T10', 'T11']
# ..                                                ...
# 75  ['T4', 'T22', 'T3', 'T5', 'T14', 'T12', 'T13',...
# 76                     ['T5', 'T6', 'T8', 'T7', 'T9']
# 77                     ['T4', 'T5', 'T7', 'T8', 'T9']
# 78               ['T4', 'T3', 'T6', 'T7', 'T8', 'T9']
# 79  ['T3', 'T4', 'T5', 'T6', 'T7', 'T13', 'T14', '...
#
#                                           target_args  \
# 0               ['T4', 'T4', 'T4', 'T11', 'T5', 'T5']
# 1                ['T3', 'T4', 'T7', 'T4', 'T5', 'T5']
# 2   ['T4', 'T9', 'T9', 'T4', 'T5', 'T5', 'T6', 'T6...
# 3   ['T3', 'T3', 'T6', 'T13', 'T13', 'T6', 'T6', '...
# 4                ['T4', 'T4', 'T7', 'T7', 'T5', 'T5']
# ..                                                ...
# 75  ['T22', 'T2', 'T2', 'T2', 'T15', 'T15', 'T15',...
# 76                   ['T4', 'T4', 'T7', 'T10', 'T10']
# 77                  ['T6', 'T6', 'T10', 'T10', 'T10']
# 78             ['T2', 'T2', 'T5', 'T5', 'T10', 'T10']
# 79  ['T8', 'T8', 'T8', 'T8', 'T8', 'T12', 'T12', '...
#
#                                        relation_types  \
# 0   ['supports', 'supports', 'supports', 'supports...
# 1   ['supports', 'attacks', 'attacks', 'supports',...
# 2   ['supports', 'supports', 'supports', 'supports...
# 3   ['supports', 'supports', 'supports', 'supports...
# 4   ['supports', 'supports', 'supports', 'supports...
# ..                                                ...
# 75  ['supports', 'supports', 'supports', 'supports...
# 76  ['supports', 'supports', 'supports', 'supports...
# 77  ['supports', 'supports', 'supports', 'supports...
# 78  ['supports', 'supports', 'supports', 'supports...
# 79  ['supports', 'supports', 'supports', 'supports...
#
#                                           essay_title  \
# 0   International tourism is now more common than ...
# 1                        Living and studying overseas
# 2   Studies abroad and the cultural aspect of the ...
# 3            Advertisements affects on consumer goods
# 4   Paying more money is the only motivation to ma...
# ..                                                ...
# 75  Capital punishment; 51% countries have polishe...
# 76  Technology helps student learn more informatio...
# 77  Classmates' impacts on children's performance ...
# 78  Detailed description of crimes on newspaper an...
# 79  We can not forcedly put the same numbers of ma...
#
#                                            essay_text split
# 0   The last 50 years have seen a significant incr...  TEST
# 1   It is every student's desire to study at a goo...  TEST
# 2   Studying abroad is one very common thing that ...  TEST
# 3   Everyday, companies offer a huge number of dif...  TEST
# 4   The purpose of this essay is to discuss whethe...  TEST
# ..                                                ...   ...
# 75  "Capital punishment or the death penalty is a ...  TEST
# 76  Nowadays, technology plays an indispensable ro...  TEST
# 77  It goes without saying that no pupil can succe...  TEST
# 78  Nowadays, the print as well as the electronic ...  TEST
# 79  There is a view that universities and colleges...  TEST
#
# [80 rows x 12 columns]

# %%
arg_ids = df_test.argument_ids.tolist()
arg_comps = df_test.argument_components.tolist()
arg_types = df_test.argument_types.tolist()

# %%
import ast

# %%
len(arg_ids), len(arg_comps), len(arg_types)
# Out:
# (80, 1266, 1266)

# %%
arg_comps = [ast.literal_eval(elem) for elem in arg_comps]
arg_types = [ast.literal_eval(elem) for elem in arg_types]

# %%
arg_comps = [item for sublist in arg_comps for item in sublist]
arg_types = [item for sublist in arg_types for item in sublist]

# %%
args = {}

for idx, (i, j) in enumerate(zip(arg_comps, arg_types)):
        
    args[idx] = i + "|" + j

# %%
len(args)
# Out:
# 1266

# %%
args
# Out:
# {0: 'this industry has affected the cultural attributes and damaged the natural environment of the tourist destinations|MajorClaim',
#  1: 'the tourism has created threatening pressure on both the sociocultural and natural environments|MajorClaim',
#  2: 'the tourism bring large profit for the destination countries|Claim',
#  3: 'international tourism can create negative impacts on the destination countries|Claim',
#  4: 'tourism has threatened the nature environments|Claim',
#  5: 'tourists from different cultures will probably cause changes to the cultural identity of the tourist destinations|Premise',
#  6: 'Take Thailand for example, in the Vietnam War, many American soldiers came to Thailand for a break and involved in sexual and drug activities, these huge demands caused many local businesses opened and expanded, even illegally involved in under-age prostitutes to maximize their profits|Premise',
#  7: 'This was due to the lack of adequate controls by authorities and lead to a bad image of Thailand tourism|Premise',
#  8: 'tourism increasingly create harms to the natural habitats of the destination appeals|Premise',
#  9: 'As the Australia’s Great Barrier Reef has shown, the billion visitors per annum has generated immense destruction to this nature wonder, namely breaking the corals caused by walking or throwing boat’s anchors, dropping fuel and other sorts of pollutions|Premise',
#  10: 'many marine lives have been endangered, in the extremes part of the reef become uninhabitable for these marine species|Premise',
#  11: 'one who studies overseas will gain many skills throughout this experience|MajorClaim',
#  12: 'living and studying overseas gives the individual a new perspective on the subject that is studied or in general life|MajorClaim',
#  13: 'studying at an overseas university gives individuals the opportunity to improve social skills by interacting and communicating with students from different origins and cultures|Claim',
#  14: 'living and studying overseas is an irreplaceable experience when it comes to learn standing on your own feet|Claim',
#  15: 'one who has studied and lived overseas will become more eligible for the job than his/her peers|Claim',
#  16: 'Compared to the peers studying in the home country, it will be more likely for the one who is living overseas to be successful in adapting himself/herself into new environments and situations in life|Premise',
#  17: 'One who is living overseas will of course struggle with loneliness, living away from family and friends|Premise',
#  18: 'those difficulties will turn into valuable experiences in the following steps of life|Premise',
#  19: 'the one will learn living without depending on anyone else|Premise',
#  20: 'employers are mostly looking for people who have international and language skills|Premise',
#  21: 'Becoming successful in this study will give the student an edge in job market|Premise',
#  22: 'there are many difficulties a student might face when studying and living overseas|Claim',
#  23: 'studying abroad has many advantages|MajorClaim',
#  24: 'studying abroad does not only have advantages, but also can change us in a very positive way|MajorClaim',
#  25: 'Students gain a lot out of the experience personally, academically, and culturally|Claim',
#  26: 'students who study outside their countries can get a lot of experience living in a foreign country|Claim',
#  27: 'the new academic experience that the students can obtain at the institution where they are pursuing their studies|Claim',
#  28: 'Most important is the cultural aspect of the experience|Claim',
#  29: "Living in a new country requires a great amount of flexibility and adaptability in one's character|Premise",
#  30: 'students might face many challenges in the host country|Premise',
#  31: 'they should be able to deal with the obstacles that they may encounter|Premise',
#  32: 'Overcoming problems teaches the students how to be more mature and self-independence|Premise',
#  33: 'they will get exposed to a different educational system|Premise',
#  34: 'They will meet new professors and new classmates which makes the academic experience different from that in their home country|Premise',
#  35: 'While living in a foreign country, students can learn a lot about the culture of that country|Premise',
#  36: 'they can meet different people of the country|Premise',
#  37: 'They can learn about their way of thinking, their customs and traditions, and way of life|Premise',
#  38: "Learning about others' cultures is so important|Premise",
#  39: 'It contributes in building a new understanding in us of how we see the world|Premise',
#  40: 'It makes us more open, and willing to accept different ideas and thoughts|Premise',
#  41: 'it educates us about the world we are living in|Premise',
#  42: 'advertising is the major reason for high sales of a product|MajorClaim',
#  43: 'high sales are obviously a reflection of the powerful advertisements|MajorClaim',
#  44: 'The most effective way to convince consumers to purchase a product is through advertising|Claim',
#  45: 'it is not sufficient in itself|Premise',
#  46: 'The product also should satisfy the needs of the consumers|Premise',
#  47: 'advertisers push the limits of creativity to dispose the consumers to purchase the product|Claim',
#  48: 'Advertisement is the most effective way to create a well-known product|Claim',
#  49: 'They make the product preferable|Claim',
#  50: 'We are mainly introduced to products through advertisements|Premise',
#  51: 'When the consumers are impressed by the way a product is advertised, they can be convinced to consider that the product is a need in some cases|Premise',
#  52: 'Recently, there is a very creative advertisements of a soft drink product on TV|Premise',
#  53: 'The story delivers a desired call to drink that soft drink that people tend to drink when the weather is too hot|Premise',
#  54: 'the number of that product being sold will increases|Premise',
#  55: 'the more an advertisement of a product takes place in mass media, the more popular the product becomes|Premise',
#  56: 'Consumers tend to purchase the most known product when it comes to picking one out of two different brands of the same product|Premise',
#  57: 'When a product is commonly used, it becomes trustworthy for the society, no matter what quality it is|Premise',
#  58: 'it also has to be affordable for the consumer|Premise',
#  59: 'advertisements have undeniable affects on the society about the product being advertised|Premise',
#  60: 'a higher pay can be one of the incentive if were to encourage harder-working employees|MajorClaim',
#  61: 'providing a more secured and relaxing environment for workers can fundamentally boost their productivity|MajorClaim',
#  62: 'they will be feeling more cared for and therefore do their best for their bosses|Claim',
#  63: 'A raise or a promotion can no doubt increase the morale in the working places|Claim',
#  64: 'creating an enjoyable working environment is more realistic and essential if one wishes an increase in productivity and better employee performances|Claim',
#  65: "Workers understand they have to work harder to meet the boss' expectations and to make themselves worthwhile|Premise",
#  66: "junior high school teachers have great responsibility not only for students' private lives as they are going through adolescence but also their school work|Premise",
#  67: 'it is an important phase for them to study hard and get into the high school they want|Premise',
#  68: 'If the teachers receive higher salaries, they will be willing to spend more extra time mentoring the youngsters rather than hoping they learn in cram schools and so forth, as this is what is happening in Taiwan|Premise',
#  69: 'Take Google for example, the company offers recreation rooms and extra personal leaves for their workers to develop a more relaxing and supportive workforce|Premise',
#  70: 'the employers can make sure the employees can actually focus and concentrate on their projects instead of thinking about their children or feeling pressured|Premise',
#  71: 'English as an elegant language should be advocated in many fields to expand the global trade and communications|MajorClaim',
#  72: 'the prevalent of English brings a great number of benefits for people|Claim',
#  73: 'the dominated status of English has destroyed culture diversity and many less-used languages become extinct|Claim',
#  74: 'English is a sophisticated language|Premise',
#  75: 'it promotes the communication and interaction between different countries more conveniently and clearly|Premise',
#  76: 'In the ancient time, the different languages and geography set barriers for people to exchange their goods and ideas|Premise',
#  77: 'the innovation of plane and train solved the geographical barriers|Premise',
#  78: 'If we can popularize the use of English, the language hinder will disappear as well|Premise',
#  79: 'English is a beautiful language, which is more systematical and extensive than many other languages|Premise',
#  80: "Learning English can foster people's sentiment and nourish their literature and art|Premise",
#  81: 'it does not express every detail of life especially in Asia countries, which have totally different linguistic system|Premise',
#  82: "language contains many aspects of people's daily life, which is influenced by culture, environment as well as religious|Premise",
#  83: 'these languages have special significance for people who belong to them and using English to replace them is crudity|Premise',
#  84: 'we still need preserve other languages for sake of keeping the linguistic and cultural diversity|Claim',
#  85: 'dependence on computers is not a bad thing|MajorClaim',
#  86: 'computers have provided security and sophistication|Claim',
#  87: 'The whole world is dependent on computers, without which, the world will go back hundreds of years|MajorClaim',
#  88: 'Computers provide speed, increase efficiency, accuracy, precision, help to increase productivity and other countless benefits are provided by it|Claim',
#  89: 'future prospects of computers are very bright|Claim',
#  90: 'Computers have made humans over-dependent|Claim',
#  91: 'In the modern world, computers are used everywhere|Premise',
#  92: 'Right from flying planes to sending a small document, computers are needed|Premise',
#  93: 'They are used in space programs, wars, hospitals, schools and so on|Premise',
#  94: 'Computers have made human life more easy, convenient and lightning fast|Premise',
#  95: 'in earlier days, if one had to send a message to someone in other country, it used to take months|Premise',
#  96: 'today, it can be sent in few minutes by typing a email and few clicks|Premise',
#  97: 'From a computer as big as a room, it has now been minimized to the size of a palm|Premise',
#  98: 'Nanotechnology is working to make computers to the order of microscopic levels|Premise',
#  99: 'Research on making computerized drone soldiers (unmanned computer controlled) is going on|Premise',
#  100: 'There is no end to the evolution of computers|Premise',
#  101: 'Virus programs, privacy breach, leak of confidential documents, cyber attacks, identity theft, frauds etc. are some of its demerits, from a countless list|Premise',
#  102: 'Computers expose children to vulgar materials|Premise',
#  103: 'They have even invaded mental health of humans, for example, FAD (Facebook Addiction Disorder - excessive use of social networking website Facebook)|Premise',
#  104: 'Computers have intruded our lives to the effect that a satellite can peep into our homes and privates lives|Premise',
#  105: 'The recent case of Wikileaks, leaking confidential data is an example of how computers are harmful|Premise',
#  106: 'it is time for the government to take action to control the proliferation of violent scenes in media|MajorClaim',
#  107: 'What the government should do immediately is to strengthen censorship to control the amount of violence in media|MajorClaim',
#  108: 'our society is occupied with the violent scenes and plots at present|Claim',
#  109: 'This will definitely set a bad example for the immature audiences who, lacking correct parental guidance and abilities to differentiate the right from wrong, are prone to go astray by imitating the violent behaviors and committing real violent crimes|Claim',
#  110: 'excessive violence would offer misleading information to the public and exert detrimental influence to the society as well|Claim',
#  111: 'they regard the violence as reasonable and justifiable|Premise',
#  112: 'media, such as TV or film, is considered as the correct information source regulated by the government|Premise',
#  113: 'It should be reporting and reflecting true phenomenon in the society|Premise',
#  114: 'Violence, as one of the facts in the real world, certainly has to be reported|Premise',
#  115: 'It is recently reported in the news that a seventeen-year-old boy killed all his family members, one sister and two parents out of hatred and jealousy|Premise',
#  116: 'In the real world, we are inclined to take extreme approach to tackle a small problem due to excessive violence exposure|Premise',
#  117: 'while some of them are disturbing, we can not overlook other merits the advertisements bring|MajorClaim',
#  118: 'advertisements have its social responsibility and contribute to economic growth|MajorClaim',
#  119: 'it is unfair to restrict those public service advertisements which are creative and inspiring|Claim',
#  120: 'publicizing brand image or a particular product of mass media could boost sales for companies|Claim',
#  121: 'the advertising expenses lead to a higher product price and some of them express fake information, creating information asymmetry between consumers and companies|Claim',
#  122: 'they are not in the purpose of making profits but taking a role of disseminating valued culture, good moral traits and calling for helps for the disabled and the poor|Premise',
#  123: 'it could simulate household spending and therefore promote the economic development of the whole country|Premise',
#  124: 'A recent study shows that after launching an advertising campaign, the sales revenue would increase by 40%, which is the very fact to verify its positive influences on economic|Premise',
#  125: 'its merits still outweigh these downsides|Premise',
#  126: 'the most suitable method of reducing stress for modern people is by different kinds of exercise, which can not only improve health conditions but also bring positive emotions|MajorClaim',
#  127: 'many activities can let humans relax|Claim',
#  128: 'the best way of diminishing stress is by exercises, which can benefit everyone not only physically but also mentally|MajorClaim',
#  129: 'exercise play a crucial role in ameliorating physical health|Claim',
#  130: 'Any kinds of sports, such as jogging, swimming, or playing basketball, can effectively facilitate human respiration and circulation system|Premise',
#  131: 'these sports can also strengthen muscles and lessen surplus adipose tissues in human body|Premise',
#  132: 'The latter one is of particular importance because nowadays more and more people are suffer from obesity|Premise',
#  133: 'Many studies has points out that numbers of overweight people have increased in developed countries in recent years, which mainly results from insufficient exercises|Premise',
#  134: "good exercises can often successfully alleviating one's heavy burdens|Premise",
#  135: "rigorous exercise can also hone one's will, which enable people to be able to tackle stringent problems and arduous tasks|Claim",
#  136: "This hormone can delight one's mind, creating positive feelings|Premise",
#  137: 'When people exercise, the neuron cells in the brain release a chemical compound named Dopamine|Premise',
#  138: 'Sports activities can improve mental health|Claim',
#  139: 'zoos have irreplaceable benefits in terms of animal preservation and children education|MajorClaim',
#  140: 'zoos offer a good man-made environment which could prolong the life span of wild animals and cultivate the notion of protecting animals|MajorClaim',
#  141: 'zoo is a good alternative choice for protecting animals|Claim',
#  142: 'zoos afford a platform to education teenagers, helping to establish eco-friendly behavior towards animals|Claim',
#  143: 'complained about the drawbacks of zoos are often heard|Claim',
#  144: 'some zoos are lack of systematic management which attributes to numerous wild animals die because of food shortage|Premise',
#  145: 'being caged in the zoos for long render wildlife lost the ability to survive in nature where is full of cruel competition among various animals|Premise',
#  146: 'our environment is damaged day by day due to the fact that excessive pursuit of economic development at expense of eco-system, which pose a great threat to the survival of wild animals|Premise',
#  147: 'various animals could be better protected by specialized staff|Premise',
#  148: 'Once the animal got sick, professional vet will help them promptly|Premise',
#  149: 'Thanks to the considerate care, the diversity of wild animal could be guaranteed|Premise',
#  150: 'In the zoos, even though wild animals are caged, they have capability to walk in a limited area|Premise',
#  151: 'When children pay a visit to the zoos, they still could observe the eating behavior or leisure activities among animals, which would definitely enrich their knowledge associated with different animals|Premise',
#  152: 'children could acquire the information regarding how to protect wild animals according to guided tour or volunteers|Premise',
#  153: 'more good comes from advertising than bad|Claim',
#  154: 'the idea that advertising is a positive part of life can be more supported|MajorClaim',
#  155: 'Advertisements are, therefore, very important for many businesses to increase sales and hence profits|Claim',
#  156: 'advertising is carried out with the main purpose of promoting different products and services or encouraging people to consume more|Premise',
#  157: 'to consumers, advertising can bring them many benefits|Claim',
#  158: 'customers of telecommunication services will have an idea about the current offers of different companies|Premise',
#  159: 'they can compare them and then have a better decision in choosing their internet or mobile phone plans|Premise',
#  160: 'a huge amount of different advertisements could be sent automatically by a system to personal phones or email addresses, this is generally known as spam, and causes discomfort or even annoyance to many people|Claim',
#  161: 'advertising can be very expensive and not every advertising campaign can be done successfully and brings good results|Premise',
#  162: 'advertising is believed by many, a financial burden to businesses|Claim',
#  163: 'big cities can be a good place for bringing up children|MajorClaim',
#  164: "Today's children needs somethings to entertain them, and occupy their leisure time in the best way|MajorClaim",
#  165: 'it is a good idea for children to past their first earlier life in the cities|Claim',
#  166: 'Children who live in cities have a lot of entertainment|Claim',
#  167: 'they can learn a lot of things by watching television and surfing through the net|Claim',
#  168: 'they can exchange their knowledge, they can learn different cultures|Claim',
#  169: 'countrysides have some advantages such as fresh air, peace, and etc|Claim',
#  170: 'education is better in big cities in comparison with countrysides|Premise',
#  171: "in my country the best schools, universities and institutes are located in cities, and todays education is one of the most important parts of our children's life|Premise",
#  172: 'it is acknowledged that a large number of creational facilities are built in cities|Premise',
#  173: 'playgrounds, parks, science museums, cinemas etc|Premise',
#  174: 'in countrysides we hardly ever see creational facilities|Premise',
#  175: 'Children who live in countrysides most of the time pass their free time in farms|Premise',
#  176: 'in big cities children access to media easily|Premise',
#  177: 'Via internet they can have connection with the other children all around the world|Premise',
#  178: 'a universal language playing the dominant role in the international community is of vital significance to global people|MajorClaim',
#  179: 'a single international language plays a pivotal role in global economic cooperation|Premise',
#  180: 'a single international language serves an economic purpose|Claim',
#  181: 'As businessmen from different countries have access to the same language, they can communicate with each other more efficiently and deeply on trade, which can intensify the transnational cooperation|Premise',
#  182: 'without the availability of the same language, there might be a chance that misunderstanding and conflicts would ensue over business negotiations, impeding collaborations between them|Premise',
#  183: 'a universal language is an integral part of cultural communication and interactions|Claim',
#  184: "If people are equipped with a single international language, they can tell each other smoothly about their countries' specific cultures such as the traditional customs or the modern lifestyles, which enables people to expand their outlooks, viewing the world in new angles|Premise",
#  185: 'when people travel to foreign countries, the local people can introduce the tourist attractions to such people with the command of the universal language, helping foreign visitors have an enjoyable exotic experience|Premise',
#  186: 'a single international language contributes to global community in terms of economic and cultural communication|MajorClaim',
#  187: 'every country should by no means disregard the preservation of their own cultural heritage|Claim',
#  188: 'a single international language may, to some extent, erode the cultural identity of a nation|Claim',
#  189: 'people may be impressed by the cultural values brought with the universal language, eroding a sense of national belong|Premise',
#  190: 'some Asians are seeking individualism, previously denied by many Asian countries|Premise',
#  191: 'they have gradually identified with such values expressed in American movies, which are imported by the governments as a result of the proliferation of English|Premise',
#  192: 'popular sports events can help reduce international tensions remarkably and promote national prides safely|MajorClaim',
#  193: 'international sporting occasions are not only one of the effective solutions to tensions among nations but also a stimulant for releasing patriotic emotions safely|MajorClaim',
#  194: 'they can improve their results, break records and bring victories to their own countries|Claim',
#  195: 'sport events with the spirit of healthiness, honesty and fairness can help strengthen understanding, friendship and solidarity among nations|Claim',
#  196: 'sport events help to wake up love and responsibilities strongly in each citizen|Claim',
#  197: 'sports events are good chances for excellent athletes to meet and learn valuable experiences from one another|Premise',
#  198: 'a large number of people will gather in the host city for sport events|Premise',
#  199: 'there are many good opportunities for discovering different cultures|Premise',
#  200: 'After sharing competitive but interesting moments in each competition, the competitors often shake hands friendly and congratulate the winners, which can lead to an improvement in the relationships among nations|Premise',
#  201: 'sporting occasions play an essential role in raising patriotic emotions in both athletes and spectators|Premise',
#  202: 'Seeing national flags be honored may be the most emotional moments to each athlete|Premise',
#  203: 'The athlete also seems to be more aware of his responsibilities and he wants to contribute more to his beloved country|Premise',
#  204: 'When witnessing our national flags flying proudly among others, many of us can stop hiding our pride and happiness|Premise',
#  205: 'when Vietnam became the champion of SEAGAMES for the first time in 2008, a festival atmosphere permeated into the streets|Premise',
#  206: 'People from all ages turned out to the streets with flags, banners and they sang aloud songs of Ho Chi Minh President|Premise',
#  207: 'The eager atmosphere lasted many next days|Premise',
#  208: 'some hooligans were so excited that they took part in motor racing or using fireworks illegally|Premise',
#  209: 'the hooligans only took a minority of people|Premise',
#  210: 'the benefits of children engagement in paid work outweigh its drawbacks|MajorClaim',
#  211: "if children take part in some kind of paid work with their parents' permission, they can learn lively lessons and become mature and responsible|MajorClaim",
#  212: "they are likely to understand their parents' hardship, to respect values of money and to form a good habit of saving|Claim",
#  213: 'children can learn about the hardship of earning money|Premise',
#  214: 'When they take some kind of paid work such as looking after babies, doing housework and keeping shops, they will have some life experience and skills which make them mature and can deal with many different situations in real life|Premise',
#  215: 'when children take jobs, they tend to be more responsibl|Claim',
#  216: 'whether they can earn money or not will depend on their effectiveness and attitudes in working|Premise',
#  217: 'To keep their jobs, children will have to try their best to finish their duties|Premise',
#  218: 'if a child works as a shop assistant, he will have to keep an eye on good and products, calculate prices correctly and take responsibilities for any lost|Premise',
#  219: 'children will be more material, neglect their study for earning money or be exploited by the employers|Claim',
#  220: 'if children get good care and instructions from their parents, they can take advantages of the work to learn valuable things and avoid going in a wrong way|Premise',
#  221: 'past behaviour determines the future actions|Claim',
#  222: "complete data concerning the history of a sued person creates more opportunity for jury members to build an overall picture of defendant's personality|Premise",
#  223: 'past record might be useful to decide whether a person was able to perform a certain type of crime when it concerns serious crimes, such as kidnapping or a murder|Premise',
#  224: 'in order for the jury to come up with an objective decision not depending on the past experience, the court should provide with details relevant to a particular case only|Claim',
#  225: 'a defendant with number of past crimes has more chance to be found guilty compared to a person with no or lighter criminal record|Premise',
#  226: 'Innocent suspects, eventually, can face unfair juridical decision and pay twice for their previous inadequate actions|Premise',
#  227: "I am skeptical about disclosing the defendant's history to the jury, with intention to avoid subjective and probable inaccurate verdict|Claim",
#  228: 'I strongly support the current laws of Great Britain and Australia, and would not change the regulations on keeping the jury unaware of past actions|MajorClaim',
#  229: 'the Internet will pave way for a more accessible and convenient learning|MajorClaim',
#  230: 'I would like to reiterate the necessity of the Internet in learning process|MajorClaim',
#  231: 'the Internet is an adequate source of academic information, which will potentially fulfill the needs of university pupils|Claim',
#  232: 'Nowadays, not only are lectures available online, it is also applicable to find reference e-books as well as multi-aspect documents on the cyberspace|Premise',
#  233: 'the Internet has grown to become the largest virtual library ever|Premise',
#  234: 'with the use of the Internet, distance and time seem to be no more a hindrance|Premise',
#  235: 'College students can save their time browsing for necessary information through the web instead of spending hours wandering in bookstores or libraries|Premise',
#  236: 'the Internet offers a more effective and practical method of studying|Premise',
#  237: 'While virtual flowcharts and animations may simplify complicated scientific processes, Google and Wikipedia are always accessible for detailed responses to every query|Premise',
#  238: 'the Internet will become an indispensable part in academic training|Claim',
#  239: 'This fairy tale turns out to be true thanks to technical and internet advances|Premise',
#  240: 'Have you ever imagined what it would be like to stay at home and attend a lecture by a famous speaker in Finland simultaneously|Premise',
#  241: 'the Internet have several drawbacks which can affect the education system negatively, for instance internet abuse and black webs|Claim',
#  242: "these problems are mainly triggered by students' wrong approach towards the Internet not the Internet itself|Premise",
#  243: "what we are to do is a change in learners' attitude not an elimination of the Internet from academic study|Premise",
#  244: 'it would generate a sense of discrimination among different age groups and increase the government financial pressure accordingly|MajorClaim',
#  245: 'they have been instilled and imparted the most updated knowledge and skills at universities|Premise',
#  246: 'fresh graduates are likely to bring a number of practical and applicable ideas to meet the current needs of the organisation|Premise',
#  247: 'having a larger proportion of young adults could enhance the working effectiveness and efficiency|Premise',
#  248: 'Compared with aged staffs, younger employees are often physically stronger and energetic which enables them to carry out heavy workload to meet the deadline|Premise',
#  249: 'encouraging the workers to retire at age of fifty-five to release the positions for younger job seekers has some merits|Claim',
#  250: 'the introduction of the early retirement has some benefits|Claim',
#  251: 'From social perspective, massively forcing the early retirement would be one of financial burden to the local government|Premise',
#  252: 'sufficient pension payments and regular medical care should be given and arranged for the senior citizens after they have been imposed to terminate their employment permanently|Premise',
#  253: 'sacrificing the senior members to save the young workers poses several negative influences|Claim',
#  254: 'From personal level, it fosters a sense of unfairness between the older and younger generations|Premise',
#  255: 'every person within the business enterprise has the rights to proceed their work as long as they are capable of doing it, disregard the age and physical capacity|Premise',
#  256: "technology alone can solve the world's environmental problems|MajorClaim",
#  257: 'if humans stop using technology and lead a simple way of life then only we can save the environment|Claim',
#  258: 'it is the luxuries people use which damages the environment|Premise',
#  259: "If people don't use air conditioners, automobiles and other such things that technology has brought us, then naturally there would be less pollution and natural resources like fossil fuels would be saved and all this would save the environment|Premise",
#  260: 'technology alone could save the environment|Claim',
#  261: 'now we have come so far ahead in technology that there is no going back|Premise',
#  262: 'We cannot ask the people of the jet age to go back to the age of the bullock cart|Premise',
#  263: 'There are a lot of advances going on technology which are helping the environment a lot|Claim',
#  264: 'One prime example is finding solutions to water problems in developing countries such as Africa|Premise',
#  265: 'By pressurising sea water to produce vapour jets and filtering them through carbon nano tubes, we can get clean drinking water from sea water - an almost inexhaustible resource|Premise',
#  266: 'Japan is working to build a working space solar power system by 2030|Premise',
#  267: "By drawing on the colossal energy of the sun, it could meet the entire world's electricity requirements indefinitely without nuclear or GHG emissions|Premise",
#  268: 'If successful, the impact on the world would be monumental|Premise',
#  269: 'It would mean energy for schools, hospitals, and homes|Premise',
#  270: 'It would mean another industrial revolution|Premise',
#  271: 'at no time will the unique role of human teachers be replaced|MajorClaim',
#  272: 'Internet can be a useful tool for education|Claim',
#  273: 'the global online network is the inexhaustible source of information, which definitely exceeds the fund of knowledge that any veteran teacher can accumulate|Claim',
#  274: 'Internet and computer also offer a more comprehensive access to knowledge, ranging from visual to aural stimuli, which make learning an ever enjoyable experience, especially for children|Premise',
#  275: 'Much information as the Internet may provide, most of the sources are unjustified by experts|Premise',
#  276: 'information from those sources is subject to question|Claim',
#  277: 'the computer can show whether an answer to a particular question is right or wrong|Premise',
#  278: 'it cannot give as an in-depth explanation as a human teacher can|Claim',
#  279: 'Through face-to-face communication, teachers can also pinpoint the weaknesses of each student and therefore, adjusting and tailoring his or her teaching methodology to meet the levels or the demands of those students|Premise',
#  280: 'This is where the computer proves to be incompetent|Premise',
#  281: "it's much easier to have some casual acquaintances than have some close friends|Claim",
#  282: "it's better to have one or two close friends than to have a large number of casual acquaintances|MajorClaim",
#  283: 'being a friend with someone is different from only being acquaintant|Premise',
#  284: "it's not easy to make friend with anyone|Premise",
#  285: 'friends are people who have great compatibility with each other|Premise',
#  286: 'After two years in college I have found sometimes there is more differences between people than similarities, for we are growing in the different families and was educated in various ways|Premise',
#  287: 'Sometimes acquaintances are just acquaintances|Premise',
#  288: 'We spend time together but we could never be friend|Premise',
#  289: 'close friends can easily understand each others feelings|Claim',
#  290: 'acquaintances probably not able to understand you better than your friends|Premise',
#  291: "they wouldn't even spare time to consider your feelings|Premise",
#  292: 'Everyone play the role of acquaintance and friend at the same time|Premise',
#  293: 'Being friendly is a good way to treat a acquaintance but way not enough for a friend|Premise',
#  294: 'When my friend is sick, I would not only ask if he is okay like an acquaintance but do my best to make him get well as soon as possible|Premise',
#  295: "If my friend is going to the wrong direction in his life trail, I will try my best to pull him back, but not stand and stare like it's not of my business|Premise",
#  296: 'my friend will do the same to me|Premise',
#  297: 'a friend is a person you care about|Claim',
#  298: 'friends are the most important people in my life second to my family|MajorClaim',
#  299: 'I prefer to live in a higher pace condition|MajorClaim',
#  300: 'living in a higher pace is better|MajorClaim',
#  301: 'the advantages of this are qualitatively greater than that of the opposite|Claim',
#  302: 'I prefer to live in high pace|MajorClaim',
#  303: 'we need to save time for accomplishing some important tasks, and a fitting example of which can be found in my experience of missing exam|Premise',
#  304: 'we have to be eager in our lives|Claim',
#  305: 'I just failed to participate in the university entrance exam|Premise',
#  306: 'I thought I had enough time for eating breakfast and transporting to the testing place; while I was stocked in a traffic jam and then missed the first test|Premise',
#  307: 'keeping in high pace condition can prevent me from getting lazy|Premise',
#  308: 'If I can avoid being a sluggish person, I can have a higher probability of fulfilling my dream successfully|Premise',
#  309: 'I had spent more time on practicing playing piano so that I won a piano competition, defeating those spending less time on practicing|Premise',
#  310: 'keeping our pace higher is important|Claim',
#  311: 'with a slower pace can enjoy their lives more|Claim',
#  312: 'it is not necessary for them to notice the time control or acquire the fame of succeed|Premise',
#  313: 'I do not think that those people with slower pace losing the piano competition can be really happy|Premise',
#  314: 'it is really joyful for me that I can immerse in the joy of the victory and accomplishment|Premise',
#  315: 'learners can obtain more useful knowledge from teachers than from other sources|Claim',
#  316: "both alternative sources and traditional teaching methods from educators are equally important in children's acquisition of knowledge|MajorClaim",
#  317: "technologies are vital in students' learning|Claim",
#  318: "the widespread of alternative sources of knowledge has played an important role in students' acquisition of knowledge|Premise",
#  319: 'Computers can be programmed to provide an endless numbers of questions in diverse range of fields, and as the students answer these questions, the facts has been learned and reinforced|Premise',
#  320: 'A case in point is the reading and listening parts of TOEFL iBT exams, as candidates have to answer many questions in a limited period of time|Premise',
#  321: 'when students have some academic problems, they can post those to some websites and receive correct answers from unknown people in faraway places without any costs|Premise',
#  322: 'in the past, conducting a research require long hours of searching in library shelves, now all can be done at a click of a button|Premise',
#  323: 'formal education approaches are also indispensable|Claim',
#  324: 'schools and university are places in which students gather to be educated and learn from each others as well as formal educators|Premise',
#  325: "At schools, students' development has been orchestrated stage by stage, step by step by experienced teachers, and their acquisition of knowledge is guided and backed up in a systematic way|Premise",
#  326: "alternative sources information and traditional education systems are equally important in children's development|MajorClaim",
#  327: 'we should give priority to our own issues|MajorClaim',
#  328: 'more emphasis should be laid on human beings other than animals, and it is better to let nature take its course with regard to species extinction|MajorClaim',
#  329: 'biodiversity is essential to maintain the balance of ecosystem|Premise',
#  330: 'If certain species are absent from this system, such kind of balance is likely to be disrupted and other species, including human beings, will come under threat|Premise',
#  331: 'it is our responsibility to keep as many species on the Earth as possible|Claim',
#  332: 'species extinction is quite natural according to the theory of evolution|Claim',
#  333: 'The environment on the Earth has been transformed many times since the first species came into being|Premise',
#  334: 'A great number of plants and animals died out|Premise',
#  335: 'they were unable to fit into the new environment|Premise',
#  336: 'the process of extinction of some species is irrevocable and we can do nothing about it|Premise',
#  337: 'We should put our own survival and sustainment in order first before considering the conservation of other species|Claim',
#  338: 'human beings nowadays are still faced with many urgent problems such as starvation, disease and wars|Premise',
#  339: 'When these problems are taken into account, extinction of some animals recedes greatly in importance and it is not sensible to devote our limited resources to animals that have been past help|Premise',
#  340: 'the increase in life expectancy has some pressure on the Medicare system|Claim',
#  341: 'the improvement of medical care makes a better life for all people|Claim',
#  342: 'the advanced medical care brings with it more benefits than disadvantages|MajorClaim',
#  343: 'The main advantage of high-tech medical care is that people are better taken care so that they have a good health|Claim',
#  344: 'They can contribute effectively to the development of the economy|Premise',
#  345: 'healthy workers can create more productivity|Premise',
#  346: 'they do not have to spend more time in health checking or treatment|Premise',
#  347: 'this saves an amount of time as well as cost|Premise',
#  348: 'a community with the elderly who have a good health has a major role to play in a sustainable development of a society|Premise',
#  349: 'young people will be happy as their parents, grandparents are healthy|Premise',
#  350: 'the increase in life expectancy puts a high pressure on the economic system|Claim',
#  351: 'more pension have to spend for Medicare instead of investing in other sectors of the economic system|Premise',
#  352: 'the capital that spend on taking care the elderly is contributed by these people during their working time|Premise',
#  353: 'they are worth to have good care|Premise',
#  354: 'They have given their effort to the society so that young people, the governments have a responsibility to improve the Medicare system|Premise',
#  355: 'the development of the health care system helps people have a better life|MajorClaim',
#  356: 'It helps people build a sustainable society where people can live a happy life when they are old|Claim',
#  357: 'one can achieve success more easily with the help from his or her family|MajorClaim',
#  358: 'with the help of our family, we can achieve success quite easily|MajorClaim',
#  359: 'family plays a more important role in helping one to pursuit success|MajorClaim',
#  360: 'when my father had difficulty in solving a problem in his childhood, he had to go to his teacher for help|Premise',
#  361: 'more and more people have the opportunity to receive education from university|Premise',
#  362: 'our parents receive better education than our grandparents did|Premise',
#  363: 'they can provide more advices and helps in our career|Claim',
#  364: 'In the past, seldom people have the chance to attend a collage|Premise',
#  365: 'my grandparents did not get a education even in high school|Premise',
#  366: 'Things have changed a lot|Premise',
#  367: 'I grow up in a better condition than my father did|Premise',
#  368: 'Whenever I have problems, I can always ask my parents for help|Premise',
#  369: 'They can solve the problem quickly|Premise',
#  370: 'they have learned quite a lot|Premise',
#  371: 'family members can help us in many other aspects|Claim',
#  372: 'when I did not know what major to choose when I attend university, my father told a lot about different majors|Premise',
#  373: 'He shared his own experience with me, which helped me quite a lot|Premise',
#  374: 'Parents are quite experienced than their child|Premise',
#  375: 'they can guide them toward the right direction|Premise',
#  376: 'parents can told their children as many as they can|Premise',
#  377: 'What they want is help their child to make a progress|Premise',
#  378: 'our parents and other family members can help us a lot in our life|Claim',
#  379: 'I prefer to live with a roommate|MajorClaim',
#  380: 'it saves me money, enables me to socialize, and allows me to get help|Claim',
#  381: 'I prefer to live with a roommate, and I always will|MajorClaim',
#  382: 'many people decide to live alone for various reasons|Claim',
#  383: 'it offers me many advantages, such as less spending, more socializing, and more help|Claim',
#  384: 'Living with a roommate saves me a lot of money|Claim',
#  385: 'If you have roommates, you can split the rent and utilities among them|Premise',
#  386: 'you can get more for less|Premise',
#  387: 'last year, I shared a room off-campus with my friend, and we decided to split the rent and heating bills into half: I was able to save about fifty dollars for heating, and two hundred dollars for rent monthly|Premise',
#  388: 'I was able to save a lot of money by sharing wasted heating and rooms with my friend and splitting the bills|Premise',
#  389: 'living with a roommate also enables me to socialize more easily|Claim',
#  390: 'It is always easier to socialize when you have a lot of people around you|Premise',
#  391: "You can invite your roommates' friends over to your room and have fun together|Premise",
#  392: 'one night, my roommate, Millan, brought his friends along|Premise',
#  393: 'Even though his friends and I were total strangers to each other, we quickly got to know each other|Premise',
#  394: 'We soon found out that everyone loved playing video games|Premise',
#  395: "We played a video game called 'Halo' together all night, and became good friends|Premise",
#  396: 'Living with a roommate made socializing much easier for me|Premise',
#  397: 'living with a roommate allows me to get help|Claim',
#  398: 'It often is the case that your roommates have the skills or knowledge you need|Premise',
#  399: 'When you run into a problem, you can ask your roommates if they can help|Premise',
#  400: 'Some of them may have something to offer|Premise',
#  401: 'when my computer mysteriously broke down, I dialed up the manufacturer and asked for help|Premise',
#  402: 'They failed to give me any useful solutions|Premise',
#  403: 'To my surprise, one of my roommates noticed my problems and offered to help|Premise',
#  404: 'He was very good with computers, and he managed to fix the problem quickly|Premise',
#  405: 'Government should decide for punishment case by case basis|MajorClaim',
#  406: 'it should taken into consideration the situation and conditions, that forces to a person to be a criminal|MajorClaim',
#  407: 'if there will be a fixed punishment for each type of crime then it will lead to increase the crime|Claim',
#  408: 'the punishment will be clear in the mind of professional criminals and they will not feel fear while committing a crime|Premise',
#  409: 'laws and rules are there for people|Premise',
#  410: 'it is necessary to have a look behind crime|Claim',
#  411: 'The person who committed crime first time and the professional criminals should not be imprisoned at same place|Premise',
#  412: 'fixed punishment will reduce the time taken by judges to give their judgement and it will be effective economically for the Government|Claim',
#  413: 'Everyone should be treated equally|Premise',
#  414: 'sometimes we see that a poor person who do not have much money for hiring a good lawyer they get imprisoned even without committing a crime and when they come back to the society they become a professional criminal|Premise',
#  415: 'fixed punishment will reduce the space between poor and rich people and everyone will understand the importance of each other|Claim',
#  416: 'a women steals feed for her child should be treated same as a women, who steals for her drug addiction|Premise',
#  417: 'I prefer to live in a big city|MajorClaim',
#  418: 'I have always wanted to find a job in a big company which locates in a prosperous city area|Claim',
#  419: 'I will absolutely choose a place to live that is not too far from my workplace|Premise',
#  420: 'I can save plenty of money on transportation if I choose to live in the city|Premise',
#  421: 'life in a big city will not be so dull as in a small town|Claim',
#  422: 'You can enjoy modern life and have more access to the advanced facilities|Premise',
#  423: 'you can visit museums to learn history, and go to a more equipped library to enjoy reading, or you can go to a sports center for exercising|Premise',
#  424: 'a small town may be less developed to satisfy all these kinds of needs|Premise',
#  425: 'living in big cities means more exposure to stimulation, like all kinds of information|Claim',
#  426: 'If one can efficiently acquire the information, then, there might come along more opportunities for him to achieve his goals|Premise',
#  427: 'there are various advertisements here an there, whether on the leaflets or on the big screen showing things of all sorts in commercial zones|Premise',
# ...
#  845: 'there will be a decrease in cars use in the future|MajorClaim',
#  846: 'the car use will definitely decrease in twenty years|MajorClaim',
#  847: 'the public transportation has improved|Premise',
#  848: 'it is much convenience to take a subway or a bus|Claim',
#  849: "I live in a city which always have a jam in the morning and doesn't have enough parking lots for the cars|Premise",
#  850: 'with the stations increased people are willing to take a public transportation than drive on their own|Premise',
#  851: 'with the risen of the aware to the environment, people will think more about whether to drive on their own or not|Claim',
#  852: 'a driving car can make a lot of different pollutions to the world|Premise',
#  853: "instead of driving each one's car, if we put forty people in a bus, it will solve the traffic jam by decrease the cars use and also reduce the air pollution for the city|Premise",
#  854: 'a personal car uses is in need|Claim',
#  855: "a public transportation can't meet every place|Premise",
#  856: 'it may be true when you want to go to some countryside or some other inconvenience places|Premise',
#  857: 'no matter you are going to somewhere for a trip or you just simply live in some suburbs and so on, it always have some other ways that you can do, you can ride a bike, or even walk on your feet|Premise',
#  858: 'It not only helps you to reduce the car use, but also good to your health|Premise',
#  859: "this won't be a problem at all|Premise",
#  860: 'working at home is worse and less efficient than working in the office|MajorClaim',
#  861: 'working in the office is obviously better than working at home in terms of efficiency|MajorClaim',
#  862: 'Think about the big project that a group is working on, if any group member has new idea about the project, he/she can assemble his/her colleges right away and discuss|Premise',
#  863: 'They can either get help from colleges or discuss about the work together|Premise',
#  864: "It's more efficient and straight-forward than talking in the phone|Premise",
#  865: 'if one’s computer or Internet has any breakdown, he/she can call the MIS staff to fix|Premise',
#  866: 'while working in the office, people can interact with their colleges instantly|Claim',
#  867: 'working at home has many disadvantages that will no doubt lower the efficiency of works|Claim',
#  868: 'people are easily distracted while working at home|Premise',
#  869: "It's hard to concentrate on work if people can grab the TV remote or some junk foods right away|Premise",
#  870: 'while people are working at home, there will be no one supervising them, thus raises the chance of loafing|Premise',
#  871: 'people who work at home are more likely to miss the important events happening in the office, like some announcements from the boss|Premise',
#  872: 'It not only has the advantage of working with colleges but also it provides a real working atmosphere that can never be grasped if people choose to work at home|Claim',
#  873: 'both the ability to relate well to people and studying hard in school are important for success in a future job|MajorClaim',
#  874: 'each of them has its own benefits|Claim',
#  875: 'we should notice to both of them|MajorClaim',
#  876: 'studying hard in school is an important factor to succeed in a job|Claim',
#  877: 'If we study them hard, we will have the chance of doing our job better and quicker in the future|Premise',
#  878: 'We need to know and learn about the theoritical basis of our future job|Premise',
#  879: 'In school, we are able to identify skills required for our future job and work on mastering and learning them|Premise',
#  880: 'if someone wants to become a good industrial engineer, he should study his technical courses very well so that he will be able to utilize them well in his future job|Premise',
#  881: 'relating well to people is also another important factor|Claim',
#  882: 'One of the other factors for success in a future job is effective commuincation|Premise',
#  883: 'By relating well to people, we are likely to have a lot of friends|Premise',
#  884: 'we will have a wide network of communication|Premise',
#  885: 'Commuincation can bring many benefits|Premise',
#  886: 'if you need help with getting a job, by commuincating with people offering jobs whom you treat well|Premise',
#  887: 'they respect you as well, you can achieve your goal|Premise',
#  888: 'if you are a salesman in a store or any other place, by relating well to your customers, you will increase the chance of their coming back again and becoming your regular customers|Premise',
#  889: 'This can be done in school|Premise',
#  890: 'the advertising is not the main cause of unhealthy eating habits|MajorClaim',
#  891: 'advertising is not the primary reason of unhealthy eating habits|MajorClaim',
#  892: 'advertising might lead to healthier eating customs due to the growing awareness of living under a better lifestyle|Claim',
#  893: "The key to forming a healthy eating pattern lies in people's concept of wholesome diets and self-control|Premise",
#  894: 'advertising always makes the products so tempting, regardless of whether they might bring negative effects on the human body|Premise',
#  895: 'advertising is not the only information source for people|Premise',
#  896: 'People can still acquire different viewpoints about foods from other sources, like news or magazines|Premise',
#  897: 'As long as people are clear about how to maintain a healthy body and they persistently keep track of their eating habits, they can successfully prevent themselves from those temptations|Premise',
#  898: 'It will be not persuasive if people just blame the advertising sector of a fast-food company for making them so fat and not reassess their own behaviors|Premise',
#  899: 'advertising is not entirely decisive on personal eating habit|Claim',
#  900: 'advertising may even bring healthier eating habits to the people|Claim',
#  901: 'in the era when people are becoming conscious of a healthier lifestyle, some companies are actually aiming at this rising trend and start to promote healthy foods|Premise',
#  902: 'Think about the recently popular organic foods that are claimed to grow in an environment without pesticide and those crude foods in which less salt or less sugar are added|Premise',
#  903: 'These are the main traits that advertising is hitting on and the overall results are good|Premise',
#  904: "the advertising industry bolsters people's awareness of having a healthy lifestyle|Premise",
#  905: 'There are the build-up of the concept about healthy eating habits and self-control that really matter|Claim',
#  906: "learning facts has more subsequent advantages for students' future lives|MajorClaim",
#  907: 'when students learn facts more in school, they would be ready for facing problems in their own life after their graduations|Premise',
#  908: 'more information about facts would make students more familiar with the real life other that only their concepts|Premise',
#  909: 'they would prepare to encounter their life out of school to solve their problems better|Claim',
#  910: 'if they deal more with facts, they can realize social situations effectively and so improve their social communication in everyday life|Premise',
#  911: "it would improve students' social behavior|Claim",
#  912: "If students only rely on concepts and ideas theorically, they would not realize human's mind very well|Premise",
#  913: 'They should understand objects more that concepts to obtain the ability of analyzing matters well|Premise',
#  914: 'It can prevent person to progress and thrive in every position|Premise',
#  915: 'when a student understands a fact and its consequences, he or she can encounter it more confidently|Claim',
#  916: "concerns and anxieties are very destructive in everybody's life|Premise",
#  917: 'these way students are teached to control their fears and concerns in facing facts|Premise',
#  918: 'learning facts is more beneficial for students in both social and individual life|MajorClaim',
#  919: 'Students would improve their social positions and encounter their problems in positive ways and also intend in the more confidence manner and etc|Claim',
#  920: "these activities have the same efficient role in students' lives|MajorClaim",
#  921: 'sports and social activities should obtain analogous concern and money|MajorClaim',
#  922: 'They bring a lot of advantages and benefits for students and also affect their future in a positive way|Claim',
#  923: 'sports are necessary for students to acquire their energy and health|Claim',
#  924: 'I decided to go to gym to recuperate and it responded very well|Premise',
#  925: 'After that exam, I felt depressed and exhausted|Premise',
#  926: 'last month I had very difficult exam that I forced to study for one week back to back|Premise',
#  927: "besides the good body shape, sports have very vital effects on human's healthfulness|Premise",
#  928: 'our body and moral health depend to physical activities directly|Premise',
#  929: 'social activities have same rights to receive monetary support|Claim',
#  930: "besides the academic knowledge, the awareness of social behavior is an important factor for human's life|Premise",
#  931: 'students should be prepared to present in society after their graduation|Premise',
#  932: "social activities can help them to be familiar with other's mind and different environment|Premise",
#  933: 'social groups and classes are significant factors to prepare students to contribute in discussion and encounter real social environment|Premise',
#  934: 'they bring about students to be happier and to have more fun and entertainments|Claim',
#  935: "If we follow just one wing of my life i.e., studying as a student, after some whiles it would be boring and we wouldn't have any motivation|Premise",
#  936: 'Such activities can help us to pick up with other students and have more friends|Premise',
#  937: 'more friends and new experience inspire the feeling of happiness and excitement in me|Premise',
#  938: 'Going to another place to learn language is better choice|MajorClaim',
#  939: 'learning language from foreign country is better than learning language in home country|MajorClaim',
#  940: 'I have to improve myself to communicate with other people|Claim',
#  941: 'in foreign country I could have a chance to speak foreign language with my friends|Claim',
#  942: 'Learning foreign language form another country is better choice for me to study language|MajorClaim',
#  943: 'everyone around me speaks foreign language, and then I have to improve myself to communicate with people|Premise',
#  944: 'If I could not communicate with other people, I could not even buy food to sacrifice my hunger|Premise',
#  945: 'This environment makes me want to develop myself to be able to communicate with people that speak foreign language|Premise',
#  946: 'going to another country to learn language is a good environment to stimulate people to learn language|Claim',
#  947: 'having friend that speaks another language is help people to professional in that language faster|Claim',
#  948: 'English school in outside my home country, there are many people that come from different places and from different languages|Premise',
#  949: 'The only language that I could talk to make friends is English language|Premise',
#  950: 'I could talk with my friend without worrying about speaking wrong|Premise',
#  951: 'This reason makes me have a progress in foreign language faster|Premise',
#  952: 'students should be asked to evaluate their teachers|MajorClaim',
#  953: 'school should ask students to evaluate their teachers|MajorClaim',
#  954: 'teachers could improve their performance|Claim',
#  955: 'there are benefits to ask students to evaluate their teachers|MajorClaim',
#  956: 'schools are also improve their quality|Claim',
#  957: 'they have high performance teachers|Premise',
#  958: 'students are easy to understand their subjects|Premise',
#  959: "evaluating from students could improve teachers' performance|Claim",
#  960: "Evaluating teachers made by students could improve teachers' performance|Premise",
#  961: 'evaluation made by students is similar to feedback from customer that business owners need to know in order to improve their product|Premise',
#  962: 'Students might complain about their teachers spoke too fast that students could not catch up on information|Premise',
#  963: 'teachers could improve themselves by speaking slower to make sure that students could get all information that they want to give|Premise',
#  964: 'school have teachers who are always improve their quality from evaluation made by students|Premise',
#  965: 'in many cooperation such as Microsoft that could produce many great products|Premise',
#  966: 'they have employees whose performance are very high|Premise',
#  967: 'Schools could produce intellectual students|Premise',
#  968: 'Teachers could augment their quality|Premise',
#  969: 'When school gather teachers that have great performance, school are gaining higher quality|Premise',
#  970: "this evaluation from students could improve schools' quality|Claim",
#  971: 'teachers are always adapt the way they teach in order to make students easy to understand their subjects|Premise',
#  972: 'students could comprehend their subject easily|Premise',
#  973: 'students, who study from great schools which have great performance teacher, graduate with great knowledge to survive in next steps of life|Premise',
#  974: 'people who get the most advantage from evaluation is students|Claim',
#  975: 'Students could study in class that have teachers who have experienced and greater performance|Premise',
#  976: 'a person should keep trying for his goals|MajorClaim',
#  977: 'one should not give up|MajorClaim',
#  978: 'Anyone who wants to achieve the goal should acknowledge that his effort and experience from suffering helps him understand his true potential and increase his strength, and ultimately, it will prompt him to be ready for overcoming the greater challenge in his life|Claim',
#  979: 'I realized the true potential of my body and mind as I decided to train myself hard|Premise',
#  980: 'Even if I were not to win this medal, I acknowledged the great amount of my endeavor as I could keep my tired legs running|Premise',
#  981: 'committing to our goal helps creating personal worth|Claim',
#  982: 'I remembered how I was suffered in the first round when I was last person who touched the line|Premise',
#  983: 'I did not give up, and believed that I would be better in the next round|Premise',
#  984: 'I knew how to improve myself|Premise',
#  985: 'I had been a loser for a thousand time before the first winning, and suffering from losing in each competition makes me stronger|Premise',
#  986: 'one who learns the great difficulty will become stronger|Claim',
#  987: 'the responsibility is worthy of carrying|Claim',
#  988: 'When the distance is longer and harder to achieve, a runner who can go beyond his limit will proud of himself|Premise',
#  989: 'He can feel the sweetness of triumph|Premise',
#  990: 'he did not stop pursing his goal|Premise',
#  991: 'we, as an average people, might feel that the responsibility to our goal is too heavy to carry on|Premise',
#  992: 'the true reward is to have the dignity|Claim',
#  993: 'the convenience it brings is more|MajorClaim',
#  994: "technology may make people's life complicated in some aspects|Claim",
#  995: 'With a private car, you can reach the destination in another city just sitting in the vehicle|Premise',
#  996: 'if you would like to have a trip across the ocean, a plane can carry you there in only a few hours, which is hard to imagine in the ancient times|Premise',
#  997: "when it comes to the field of transportation, there is no doubt that the technology in automobile has made people's life simpler|Claim",
#  998: 'In the past, teachers have to write what they want to convey to students on the chalkboard, resulting in a great waste of time and the fatigue of teachers|Premise',
#  999: 'With the advent of iPads in e-learning, paper books become unnecessary, so does the blackboards|Premise',
#  ...}

# %%
df_x = pd.DataFrame.from_dict(args, orient="index")

# %%
df_x
# Out:
#                                                       0
# 0     this industry has affected the cultural attrib...
# 1     the tourism has created threatening pressure o...
# 2     the tourism bring large profit for the destina...
# 3     international tourism can create negative impa...
# 4     tourism has threatened the nature environments...
# ...                                                 ...
# 1261  universities should encourage more girls to ch...
# 1262  this could avoid imbalance of gender in some s...
# 1263  It would affect students' mental health to stu...
# 1264    she is unlikely to focus on her subject|Premise
# 1265  this also can block the girl's future developm...
#
# [1266 rows x 1 columns]

# %%
df_x.columns
# Out:
# RangeIndex(start=0, stop=1, step=1)

# %%
df_split = df_x[df_x.columns[0]].str.split('|', expand=True)

# %%
df_split
# Out:
#                                                       0           1
# 0     this industry has affected the cultural attrib...  MajorClaim
# 1     the tourism has created threatening pressure o...  MajorClaim
# 2     the tourism bring large profit for the destina...       Claim
# 3     international tourism can create negative impa...       Claim
# 4        tourism has threatened the nature environments       Claim
# ...                                                 ...         ...
# 1261  universities should encourage more girls to ch...       Claim
# 1262  this could avoid imbalance of gender in some s...     Premise
# 1263  It would affect students' mental health to stu...     Premise
# 1264            she is unlikely to focus on her subject     Premise
# 1265  this also can block the girl's future developm...     Premise
#
# [1266 rows x 2 columns]

# %%
selected_rows = df_split.loc[c_wrong].reset_index(drop=True)

# %%
selected_rows
# Out:
#                                                     0      1
# 0   the new academic experience that the students ...  Claim
# 1   Advertisement is the most effective way to cre...  Claim
# 2   they will be feeling more cared for and theref...  Claim
# 3   the advertising expenses lead to a higher prod...  Claim
# 4   rigorous exercise can also hone one's will, wh...  Claim
# ..                                                ...    ...
# 56  with some of serious criminals, capital punish...  Claim
# 57  Another point that students may benefit from t...  Claim
# 58  they provide tremendous incentive and horizon ...  Claim
# 59  the classmates themselves creat a competitive ...  Claim
# 60  particular coverage of heinous crimes may furt...  Claim
#
# [61 rows x 2 columns]

# %%
df_z = pd.read_csv("/Utilisateurs/umushtaq/am_reasoning/data_files/pe_dataset.csv", index_col=0)

# %%
df_z
# Out:
#       split                                              title  \
# 0     TRAIN  Should students be taught to compete or to coo...
# 1     TRAIN  Should students be taught to compete or to coo...
# 2     TRAIN  Should students be taught to compete or to coo...
# 3     TRAIN  Should students be taught to compete or to coo...
# 4     TRAIN  Should students be taught to compete or to coo...
# ...     ...                                                ...
# 6084  TRAIN  Children should studying hard or playing sport...
# 6085  TRAIN  Children should studying hard or playing sport...
# 6086  TRAIN  Children should studying hard or playing sport...
# 6087  TRAIN  Children should studying hard or playing sport...
# 6088  TRAIN  Children should studying hard or playing sport...
#
#       argument_bound_1  argument_bound_2  argument_id  \
# 0                  503               575            1
# 1                  591               714            2
# 2                  716               851            3
# 3                  853              1086            4
# 4                 1088              1191            5
# ...                ...               ...          ...
# 6084              1275              1339           11
# 6085              1341              1388           12
# 6086              1393              1436           13
# 6087              1448              1525           14
# 6088              1543              1620           15
#
#                                                      ac       label  \
# 0     we should attach more importance to cooperatio...  MajorClaim
# 1     through cooperation, children can learn about ...       Claim
# 2     What we acquired from team work is not only ho...     Premise
# 3     During the process of cooperation, children ca...     Premise
# 4     All of these skills help them to get on well w...     Premise
# ...                                                 ...         ...
# 6084  indirectly they will learn how to socialize ea...     Premise
# 6085    That will make children getting lots of friends     Premise
# 6086        they can contribute positively to community     Premise
# 6087  playing sport makes children getting healthy a...     Premise
# 6088  both studying hard at school and playing sport...  MajorClaim
#
#                                                   essay
# 0     Should students be taught to compete or to coo...
# 1     Should students be taught to compete or to coo...
# 2     Should students be taught to compete or to coo...
# 3     Should students be taught to compete or to coo...
# 4     Should students be taught to compete or to coo...
# ...                                                 ...
# 6084  Children should studying hard or playing sport...
# 6085  Children should studying hard or playing sport...
# 6086  Children should studying hard or playing sport...
# 6087  Children should studying hard or playing sport...
# 6088  Children should studying hard or playing sport...
#
# [6089 rows x 8 columns]

# %%
df_zz = df_z[df_z.split == "TEST"].reset_index(drop=True)

# %%
df_zz
# Out:
#      split                                              title  \
# 0     TEST  International tourism is now more common than ...
# 1     TEST  International tourism is now more common than ...
# 2     TEST  International tourism is now more common than ...
# 3     TEST  International tourism is now more common than ...
# 4     TEST  International tourism is now more common than ...
# ...    ...                                                ...
# 1261  TEST  We can not forcedly put the same numbers of ma...
# 1262  TEST  We can not forcedly put the same numbers of ma...
# 1263  TEST  We can not forcedly put the same numbers of ma...
# 1264  TEST  We can not forcedly put the same numbers of ma...
# 1265  TEST  We can not forcedly put the same numbers of ma...
#
#       argument_bound_1  argument_bound_2  argument_id  \
# 0                  179               239            1
# 1                  262               376            2
# 2                  417               530            3
# 3                  532               818            4
# 4                  820               924            5
# ...                ...               ...          ...
# 1261              1394              1463           12
# 1262              1484              1589           13
# 1263              1595              1648           14
# 1264              1650              1734           15
# 1265              1751              1951           16
#
#                                                      ac       label  \
# 0     the tourism bring large profit for the destina...       Claim
# 1     this industry has affected the cultural attrib...  MajorClaim
# 2     tourists from different cultures will probably...     Premise
# 3     Take Thailand for example, in the Vietnam War,...     Premise
# 4     This was due to the lack of adequate controls ...     Premise
# ...                                                 ...         ...
# 1261  this also can block the girl's future developm...     Premise
# 1262  universities should encourage more girls to ch...       Claim
# 1263  this could avoid imbalance of gender in some s...     Premise
# 1264  It would affect students' mental health to stu...     Premise
# 1265  it is necessary for universities to respect th...  MajorClaim
#
#                                                   essay
# 0     International tourism is now more common than ...
# 1     International tourism is now more common than ...
# 2     International tourism is now more common than ...
# 3     International tourism is now more common than ...
# 4     International tourism is now more common than ...
# ...                                                 ...
# 1261  We can not forcedly put the same numbers of ma...
# 1262  We can not forcedly put the same numbers of ma...
# 1263  We can not forcedly put the same numbers of ma...
# 1264  We can not forcedly put the same numbers of ma...
# 1265  We can not forcedly put the same numbers of ma...
#
# [1266 rows x 8 columns]

# %%
selected_rows.columns = ["ac", "label"]

# %%
selected_rows
# Out:
#                                                    ac  label
# 0   the new academic experience that the students ...  Claim
# 1   Advertisement is the most effective way to cre...  Claim
# 2   they will be feeling more cared for and theref...  Claim
# 3   the advertising expenses lead to a higher prod...  Claim
# 4   rigorous exercise can also hone one's will, wh...  Claim
# ..                                                ...    ...
# 56  with some of serious criminals, capital punish...  Claim
# 57  Another point that students may benefit from t...  Claim
# 58  they provide tremendous incentive and horizon ...  Claim
# 59  the classmates themselves creat a competitive ...  Claim
# 60  particular coverage of heinous crimes may furt...  Claim
#
# [61 rows x 2 columns]

# %%
merged_df = selected_rows.merge(df_zz, on="ac", how="inner").reset_index(drop=True)

# %%
merged_df
# Out:
#                                                    ac label_x split  \
# 0   the new academic experience that the students ...   Claim  TEST
# 1   Advertisement is the most effective way to cre...   Claim  TEST
# 2   they will be feeling more cared for and theref...   Claim  TEST
# 3   the advertising expenses lead to a higher prod...   Claim  TEST
# 4   rigorous exercise can also hone one's will, wh...   Claim  TEST
# ..                                                ...     ...   ...
# 56  with some of serious criminals, capital punish...   Claim  TEST
# 57  Another point that students may benefit from t...   Claim  TEST
# 58  they provide tremendous incentive and horizon ...   Claim  TEST
# 59  the classmates themselves creat a competitive ...   Claim  TEST
# 60  particular coverage of heinous crimes may furt...   Claim  TEST
#
#                                                 title  argument_bound_1  \
# 0   Studies abroad and the cultural aspect of the ...               779
# 1            Advertisements affects on consumer goods              1097
# 2   Paying more money is the only motivation to ma...              1776
# 3            Should all the advertisements be banned?              1221
# 4               The best way to relax is by exercises              1386
# ..                                                ...               ...
# 56  Capital punishment; 51% countries have polishe...              1607
# 57  Technology helps student learn more informatio...               802
# 58  Classmates' impacts on children's performance ...              1629
# 59  Classmates' impacts on children's performance ...               433
# 60  Detailed description of crimes on newspaper an...              1344
#
#     argument_bound_2  argument_id label_y  \
# 0                892            8   Claim
# 1               1167           12   Claim
# 2               1856           11   Claim
# 3               1382            7   Claim
# 4               1507           11   Claim
# ..               ...          ...     ...
# 56              1676           13   Claim
# 57               892            5   Claim
# 58              1756           10   Claim
# 59               516            2   Claim
# 60              1426            8   Claim
#
#                                                 essay
# 0   Studies abroad and the cultural aspect of the ...
# 1   Advertisements affects on consumer goods\n\nEv...
# 2   Paying more money is the only motivation to ma...
# 3   Should all the advertisements be banned?\n\nNe...
# 4   The best way to relax is by exercises\n\nIn mo...
# ..                                                ...
# 56  Capital punishment; 51% countries have polishe...
# 57  Technology helps student learn more informatio...
# 58  Classmates' impacts on children's performance ...
# 59  Classmates' impacts on children's performance ...
# 60  Detailed description of crimes on newspaper an...
#
# [61 rows x 9 columns]

# %%
len(merged_df.essay.unique().tolist())
# Out:
# 44

# %%
len(merged_df.title.unique().tolist())
# Out:
# 44
