# %%
import os
import re
import pandas as pd
from tqdm import tqdm

# %%
ann_files_directory = "/Utilisateurs/umushtaq/am_reasoning/raw_files/ann_files"
text_files_directory = "/Utilisateurs/umushtaq/am_reasoning/raw_files/txt_files"

# %%
components_data = []
relations_data = []
stances_data = []
essays_data = []

# %%
for filename in tqdm(os.listdir(ann_files_directory), desc="Parsing annotation files for components ..."):
    
    print("processing: " + filename)
    #if filename.endswith(".ann"):  # Process only text files
    file_path = os.path.join(ann_files_directory, filename)
    
    with open(file_path, "r", encoding="utf-8") as file:
        for line in file:
            parts = line.strip().split("\t")
            #print(parts)
            # Process "T" lines (claims/premises)
            if line.startswith("T"):
                t_id = parts[0]  # Extract T ID (e.g., T1)
                t_type = parts[1].split(" ")[0]  # Extract type (e.g., MajorClaim, Claim, Premise)
                t_s_bound = parts[1].split(" ")[1]
                t_e_bound = parts[1].split(" ")[2]
                text = parts[2] #if len(parts) > 3 else ""  # Extract text if available
                components_data.append(["T", filename, t_id, t_type, t_s_bound, t_e_bound, text])
# Out:
# Parsing annotation files for components ...: 100%|██████████| 402/402 [00:00<00:00, 2438.34it/s]
# processing: essay001.ann
# processing: essay002.ann
# processing: essay003.ann
# processing: essay004.ann
# processing: essay005.ann
# processing: essay006.ann
# processing: essay007.ann
# processing: essay008.ann
# processing: essay009.ann
# processing: essay010.ann
# processing: essay011.ann
# processing: essay012.ann
# processing: essay013.ann
# processing: essay014.ann
# processing: essay015.ann
# processing: essay016.ann
# processing: essay017.ann
# processing: essay018.ann
# processing: essay019.ann
# processing: essay020.ann
# processing: essay021.ann
# processing: essay022.ann
# processing: essay023.ann
# processing: essay024.ann
# processing: essay025.ann
# processing: essay026.ann
# processing: essay027.ann
# processing: essay028.ann
# processing: essay029.ann
# processing: essay030.ann
# processing: essay031.ann
# processing: essay032.ann
# processing: essay033.ann
# processing: essay034.ann
# processing: essay035.ann
# processing: essay036.ann
# processing: essay037.ann
# processing: essay038.ann
# processing: essay039.ann
# processing: essay040.ann
# processing: essay041.ann
# processing: essay042.ann
# processing: essay043.ann
# processing: essay044.ann
# processing: essay045.ann
# processing: essay046.ann
# processing: essay047.ann
# processing: essay048.ann
# processing: essay049.ann
# processing: essay050.ann
# processing: essay051.ann
# processing: essay052.ann
# processing: essay053.ann
# processing: essay054.ann
# processing: essay055.ann
# processing: essay056.ann
# processing: essay057.ann
# processing: essay058.ann
# processing: essay059.ann
# processing: essay060.ann
# processing: essay061.ann
# processing: essay062.ann
# processing: essay063.ann
# processing: essay064.ann
# processing: essay065.ann
# processing: essay066.ann
# processing: essay067.ann
# processing: essay068.ann
# processing: essay069.ann
# processing: essay070.ann
# processing: essay071.ann
# processing: essay072.ann
# processing: essay073.ann
# processing: essay074.ann
# processing: essay075.ann
# processing: essay076.ann
# processing: essay077.ann
# processing: essay078.ann
# processing: essay079.ann
# processing: essay080.ann
# processing: essay081.ann
# processing: essay082.ann
# processing: essay083.ann
# processing: essay084.ann
# processing: essay085.ann
# processing: essay086.ann
# processing: essay087.ann
# processing: essay367.ann
# processing: essay368.ann
# processing: essay369.ann
# processing: essay370.ann
# processing: essay371.ann
# processing: essay372.ann
# processing: essay373.ann
# processing: essay374.ann
# processing: essay375.ann
# processing: essay376.ann
# processing: essay377.ann
# processing: essay378.ann
# processing: essay379.ann
# processing: essay380.ann
# processing: essay381.ann
# processing: essay382.ann
# processing: essay383.ann
# processing: essay384.ann
# processing: essay385.ann
# processing: essay386.ann
# processing: essay387.ann
# processing: essay388.ann
# processing: essay389.ann
# processing: essay390.ann
# processing: essay391.ann
# processing: essay392.ann
# processing: essay393.ann
# processing: essay394.ann
# processing: essay395.ann
# processing: essay396.ann
# processing: essay397.ann
# processing: essay398.ann
# processing: essay399.ann
# processing: essay400.ann
# processing: essay401.ann
# processing: essay402.ann

# %%
for filename in tqdm(os.listdir(ann_files_directory), desc="Parsing annotation files for relations ... "):
    
    print("processing: " + filename)
    #if filename.endswith(".ann"):  # Process only text files
    file_path = os.path.join(ann_files_directory, filename)
    
    with open(file_path, "r", encoding="utf-8") as file:
        for line in file:
            parts = line.strip().split("\t")
            #print(parts)
            # Process "T" lines (claims/premises)
            if line.startswith("R"):
                parts = line.strip().split()
                relation_type = parts[1]  # "supports" or "attacks"
                arg1 = parts[2].split(":")[1]  # Extract T value from Arg1
                arg2 = parts[3].split(":")[1]  # Extract T value from Arg2
                relations_data.append(["R", filename, arg1, arg2, relation_type])
# Out:
# Parsing annotation files for relations ... : 100%|██████████| 402/402 [00:00<00:00, 3861.86it/s]
# processing: essay001.ann
# processing: essay002.ann
# processing: essay003.ann
# processing: essay004.ann
# processing: essay005.ann
# processing: essay006.ann
# processing: essay007.ann
# processing: essay008.ann
# processing: essay009.ann
# processing: essay010.ann
# processing: essay011.ann
# processing: essay012.ann
# processing: essay013.ann
# processing: essay014.ann
# processing: essay015.ann
# processing: essay016.ann
# processing: essay017.ann
# processing: essay018.ann
# processing: essay019.ann
# processing: essay020.ann
# processing: essay021.ann
# processing: essay022.ann
# processing: essay023.ann
# processing: essay024.ann
# processing: essay025.ann
# processing: essay026.ann
# processing: essay027.ann
# processing: essay028.ann
# processing: essay029.ann
# processing: essay030.ann
# processing: essay031.ann
# processing: essay032.ann
# processing: essay033.ann
# processing: essay034.ann
# processing: essay035.ann
# processing: essay036.ann
# processing: essay037.ann
# processing: essay038.ann
# processing: essay039.ann
# processing: essay040.ann
# processing: essay041.ann
# processing: essay042.ann
# processing: essay043.ann
# processing: essay044.ann
# processing: essay045.ann
# processing: essay046.ann
# processing: essay047.ann
# processing: essay048.ann
# processing: essay049.ann
# processing: essay050.ann
# processing: essay051.ann
# processing: essay052.ann
# processing: essay053.ann
# processing: essay054.ann
# processing: essay055.ann
# processing: essay056.ann
# processing: essay057.ann
# processing: essay058.ann
# processing: essay059.ann
# processing: essay060.ann
# processing: essay061.ann
# processing: essay062.ann
# processing: essay063.ann
# processing: essay064.ann
# processing: essay065.ann
# processing: essay066.ann
# processing: essay067.ann
# processing: essay068.ann
# processing: essay069.ann
# processing: essay070.ann
# processing: essay350.ann
# processing: essay351.ann
# processing: essay352.ann
# processing: essay353.ann
# processing: essay354.ann
# processing: essay355.ann
# processing: essay356.ann
# processing: essay357.ann
# processing: essay358.ann
# processing: essay359.ann
# processing: essay360.ann
# processing: essay361.ann
# processing: essay362.ann
# processing: essay363.ann
# processing: essay364.ann
# processing: essay365.ann
# processing: essay366.ann
# processing: essay367.ann
# processing: essay368.ann
# processing: essay369.ann
# processing: essay370.ann
# processing: essay371.ann
# processing: essay372.ann
# processing: essay373.ann
# processing: essay374.ann
# processing: essay375.ann
# processing: essay376.ann
# processing: essay377.ann
# processing: essay378.ann
# processing: essay379.ann
# processing: essay380.ann
# processing: essay381.ann
# processing: essay382.ann
# processing: essay383.ann
# processing: essay384.ann
# processing: essay385.ann
# processing: essay386.ann
# processing: essay387.ann
# processing: essay388.ann
# processing: essay389.ann
# processing: essay390.ann
# processing: essay391.ann
# processing: essay392.ann
# processing: essay393.ann
# processing: essay394.ann
# processing: essay395.ann
# processing: essay396.ann
# processing: essay397.ann
# processing: essay398.ann
# processing: essay399.ann
# processing: essay400.ann
# processing: essay401.ann
# processing: essay402.ann

# %%
for filename in tqdm(os.listdir(ann_files_directory), desc="Parsing annotation files for stances ... "):
    
    print("processing: " + filename)
    #if filename.endswith(".ann"):  # Process only text files
    file_path = os.path.join(ann_files_directory, filename)
    
    with open(file_path, "r", encoding="utf-8") as file:
        for line in file:
            parts = line.strip().split("\t")
            #print(parts)
            # Process "T" lines (claims/premises)
            if line.startswith("A"):
                parts = line.strip().split()
                relation_type = parts[-1]  # "supports" or "attacks"
                #arg1 = parts[2].split(":")[1]  # Extract T value from Arg1
                #arg2 = parts[3].split(":")[1]  # Extract T value from Arg2
                stances_data.append(["A", filename, relation_type])
# Out:
# Parsing annotation files for stances ... : 100%|██████████| 402/402 [00:00<00:00, 3482.36it/s]
# processing: essay001.ann
# processing: essay002.ann
# processing: essay003.ann
# processing: essay004.ann
# processing: essay005.ann
# processing: essay006.ann
# processing: essay007.ann
# processing: essay008.ann
# processing: essay009.ann
# processing: essay010.ann
# processing: essay011.ann
# processing: essay012.ann
# processing: essay013.ann
# processing: essay014.ann
# processing: essay015.ann
# processing: essay016.ann
# processing: essay017.ann
# processing: essay018.ann
# processing: essay019.ann
# processing: essay020.ann
# processing: essay021.ann
# processing: essay022.ann
# processing: essay023.ann
# processing: essay024.ann
# processing: essay025.ann
# processing: essay026.ann
# processing: essay027.ann
# processing: essay028.ann
# processing: essay029.ann
# processing: essay030.ann
# processing: essay031.ann
# processing: essay032.ann
# processing: essay033.ann
# processing: essay034.ann
# processing: essay035.ann
# processing: essay036.ann
# processing: essay037.ann
# processing: essay038.ann
# processing: essay039.ann
# processing: essay040.ann
# processing: essay041.ann
# processing: essay042.ann
# processing: essay043.ann
# processing: essay044.ann
# processing: essay045.ann
# processing: essay046.ann
# processing: essay047.ann
# processing: essay048.ann
# processing: essay049.ann
# processing: essay050.ann
# processing: essay051.ann
# processing: essay052.ann
# processing: essay053.ann
# processing: essay333.ann
# processing: essay334.ann
# processing: essay335.ann
# processing: essay336.ann
# processing: essay337.ann
# processing: essay338.ann
# processing: essay339.ann
# processing: essay340.ann
# processing: essay341.ann
# processing: essay342.ann
# processing: essay343.ann
# processing: essay344.ann
# processing: essay345.ann
# processing: essay346.ann
# processing: essay347.ann
# processing: essay348.ann
# processing: essay349.ann
# processing: essay350.ann
# processing: essay351.ann
# processing: essay352.ann
# processing: essay353.ann
# processing: essay354.ann
# processing: essay355.ann
# processing: essay356.ann
# processing: essay357.ann
# processing: essay358.ann
# processing: essay359.ann
# processing: essay360.ann
# processing: essay361.ann
# processing: essay362.ann
# processing: essay363.ann
# processing: essay364.ann
# processing: essay365.ann
# processing: essay366.ann
# processing: essay367.ann
# processing: essay368.ann
# processing: essay369.ann
# processing: essay370.ann
# processing: essay371.ann
# processing: essay372.ann
# processing: essay373.ann
# processing: essay374.ann
# processing: essay375.ann
# processing: essay376.ann
# processing: essay377.ann
# processing: essay378.ann
# processing: essay379.ann
# processing: essay380.ann
# processing: essay381.ann
# processing: essay382.ann
# processing: essay383.ann
# processing: essay384.ann
# processing: essay385.ann
# processing: essay386.ann
# processing: essay387.ann
# processing: essay388.ann
# processing: essay389.ann
# processing: essay390.ann
# processing: essay391.ann
# processing: essay392.ann
# processing: essay393.ann
# processing: essay394.ann
# processing: essay395.ann
# processing: essay396.ann
# processing: essay397.ann
# processing: essay398.ann
# processing: essay399.ann
# processing: essay400.ann
# processing: essay401.ann
# processing: essay402.ann

# %%
for filename in tqdm(os.listdir(text_files_directory), desc="Parsing text files for esssays ... "):
    
    print("processing: " + filename)
    #if filename.endswith(".ann"):  # Process only text files
    file_path = os.path.join(text_files_directory, filename)
    filename_ann = filename.replace(".txt", ".ann")
    
    with open(file_path, "r", encoding="utf-8") as file:
        
        lines = file.readlines()
        essay_title = lines[0].strip()
        essay_text = "".join(lines[1:]).strip()
        
        essays_data.append([filename.replace(".txt", ".ann"), essay_title, essay_text])
# Out:
# Parsing text files for esssays ... : 100%|██████████| 402/402 [00:00<00:00, 3904.13it/s]
# processing: essay001.txt
# processing: essay002.txt
# processing: essay003.txt
# processing: essay004.txt
# processing: essay005.txt
# processing: essay006.txt
# processing: essay007.txt
# processing: essay008.txt
# processing: essay009.txt
# processing: essay010.txt
# processing: essay011.txt
# processing: essay012.txt
# processing: essay013.txt
# processing: essay014.txt
# processing: essay015.txt
# processing: essay016.txt
# processing: essay017.txt
# processing: essay018.txt
# processing: essay019.txt
# processing: essay020.txt
# processing: essay021.txt
# processing: essay022.txt
# processing: essay023.txt
# processing: essay024.txt
# processing: essay025.txt
# processing: essay026.txt
# processing: essay027.txt
# processing: essay028.txt
# processing: essay029.txt
# processing: essay030.txt
# processing: essay031.txt
# processing: essay032.txt
# processing: essay033.txt
# processing: essay034.txt
# processing: essay035.txt
# processing: essay036.txt
# processing: essay037.txt
# processing: essay038.txt
# processing: essay039.txt
# processing: essay040.txt
# processing: essay041.txt
# processing: essay042.txt
# processing: essay043.txt
# processing: essay323.txt
# processing: essay324.txt
# processing: essay325.txt
# processing: essay326.txt
# processing: essay327.txt
# processing: essay328.txt
# processing: essay329.txt
# processing: essay330.txt
# processing: essay331.txt
# processing: essay332.txt
# processing: essay333.txt
# processing: essay334.txt
# processing: essay335.txt
# processing: essay336.txt
# processing: essay337.txt
# processing: essay338.txt
# processing: essay339.txt
# processing: essay340.txt
# processing: essay341.txt
# processing: essay342.txt
# processing: essay343.txt
# processing: essay344.txt
# processing: essay345.txt
# processing: essay346.txt
# processing: essay347.txt
# processing: essay348.txt
# processing: essay349.txt
# processing: essay350.txt
# processing: essay351.txt
# processing: essay352.txt
# processing: essay353.txt
# processing: essay354.txt
# processing: essay355.txt
# processing: essay356.txt
# processing: essay357.txt
# processing: essay358.txt
# processing: essay359.txt
# processing: essay360.txt
# processing: essay361.txt
# processing: essay362.txt
# processing: essay363.txt
# processing: essay364.txt
# processing: essay365.txt
# processing: essay366.txt
# processing: essay367.txt
# processing: essay368.txt
# processing: essay369.txt
# processing: essay370.txt
# processing: essay371.txt
# processing: essay372.txt
# processing: essay373.txt
# processing: essay374.txt
# processing: essay375.txt
# processing: essay376.txt
# processing: essay377.txt
# processing: essay378.txt
# processing: essay379.txt
# processing: essay380.txt
# processing: essay381.txt
# processing: essay382.txt
# processing: essay383.txt
# processing: essay384.txt
# processing: essay385.txt
# processing: essay386.txt
# processing: essay387.txt
# processing: essay388.txt
# processing: essay389.txt
# processing: essay390.txt
# processing: essay391.txt
# processing: essay392.txt
# processing: essay393.txt
# processing: essay394.txt
# processing: essay395.txt
# processing: essay396.txt
# processing: essay397.txt
# processing: essay398.txt
# processing: essay399.txt
# processing: essay400.txt
# processing: essay401.txt
# processing: essay402.txt

# %%
components_df = pd.DataFrame(components_data)
relations_df = pd.DataFrame(relations_data)
stances_df = pd.DataFrame(stances_data)
essays_df = pd.DataFrame(essays_data)

# %%
essays_df
# Out:
#                 0                                                  1  \
# 0    essay001.ann  Should students be taught to compete or to coo...
# 1    essay002.ann  More people are migrating to other countries t...
# 2    essay003.ann  International tourism is now more common than ...
# 3    essay004.ann  International tourism is now more common than ...
# 4    essay005.ann                       Living and studying overseas
# ..            ...                                                ...
# 397  essay398.ann  We can not forcedly put the same numbers of ma...
# 398  essay399.ann                 Drugs, alcohol and messy sex lives
# 399  essay400.ann  A greater proportion of the budget should be a...
# 400  essay401.ann  Fatherhood should be as present as motherhood ...
# 401  essay402.ann  Children should studying hard or playing sport...
#
#                                                      2
# 0    It is always said that competition can effecti...
# 1    The last 50 years have seen an increasing numb...
# 2    The last decade has seen an increasing number ...
# 3    The last 50 years have seen a significant incr...
# 4    It is every student's desire to study at a goo...
# ..                                                 ...
# 397  There is a view that universities and colleges...
# 398  Celebrities, for example movie stars, are usua...
# 399  In today's world, the concept of the welfare s...
# 400  In today's world, having and raising children ...
# 401  Some people believe that studying hard is esse...
#
# [402 rows x 3 columns]

# %%
components_df = components_df.drop(columns=components_df.columns[0])
components_df.columns = ["file_name", "argument_id", "argument_type", "arg_bound_1", "arg_bound2", "argument_component"]

# %%
relations_df = relations_df.drop(columns=relations_df.columns[0])
relations_df.columns = ["file_name", "source_arg", "target_arg", "relation_type"]

# %%
stances_df = stances_df.drop(columns=stances_df.columns[0])
stances_df.columns = ["file_name", "stance_type"]

# %%
essays_df.columns = ["file_name", "essay_title", "essay_text"]

# %% [markdown]
# ### Group and Merge

# %%
comp_grouped_df = components_df.groupby(['file_name'], sort=False).agg({
    'argument_id': list,
    'argument_type': list,
    'arg_bound_1': list,
    'arg_bound2': list,
    'argument_component': list,
}).reset_index()

# %%
rels_grouped_df = relations_df.groupby(['file_name'], sort=False).agg({
    'source_arg': list,
    'target_arg': list,
    'relation_type': list,
}).reset_index()

# %%
stance_grouped_df = stances_df.groupby(['file_name'], sort=False).agg({
    'stance_type': list,
}).reset_index()

# %%
pe_df = comp_grouped_df.merge(rels_grouped_df, on="file_name").merge(stance_grouped_df, on="file_name").merge(essays_df, on="file_name")

# %%
pe_df.columns = ['ann_file_name', 'argument_ids', 'argument_types', 'arg_start_bounds',
       'arg_end_bounds', 'argument_components', 'source_args', 'target_args',
       'relation_types', 'stance_types', 'essay_title', 'essay_text']

# %%
pe_df
# Out:
#     ann_file_name                                       argument_ids  \
# 0    essay001.ann     [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T11]
# 1    essay002.ann  [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T11,...
# 2    essay003.ann          [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10]
# 3    essay004.ann     [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T11]
# 4    essay005.ann  [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T11,...
# ..            ...                                                ...
# 397  essay398.ann  [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T11,...
# 398  essay399.ann          [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10]
# 399  essay400.ann          [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10]
# 400  essay401.ann          [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10]
# 401  essay402.ann  [T1, T2, T3, T5, T6, T7, T8, T4, T9, T10, T11,...
#
#                                         argument_types  \
# 0    [MajorClaim, MajorClaim, Claim, Premise, Premi...
# 1    [MajorClaim, MajorClaim, Premise, Claim, Premi...
# 2    [MajorClaim, MajorClaim, Claim, Premise, Premi...
# 3    [MajorClaim, MajorClaim, Claim, Claim, Claim, ...
# 4    [MajorClaim, MajorClaim, Claim, Claim, Claim, ...
# ..                                                 ...
# 397  [Claim, MajorClaim, Premise, Premise, Premise,...
# 398  [MajorClaim, MajorClaim, Claim, Premise, Premi...
# 399  [MajorClaim, MajorClaim, Claim, Premise, Premi...
# 400  [MajorClaim, MajorClaim, Premise, Premise, Cla...
# 401  [MajorClaim, MajorClaim, Premise, Premise, Pre...
#
#                                       arg_start_bounds  \
# 0    [503, 2154, 591, 716, 853, 1088, 1332, 1212, 1...
# 1    [391, 1936, 500, 1089, 626, 841, 948, 1168, 12...
# 2    [352, 1568, 955, 487, 615, 786, 1024, 1454, 11...
# 3    [262, 1663, 179, 953, 1578, 417, 532, 820, 107...
# 4    [286, 1535, 388, 775, 1330, 566, 885, 993, 109...
# ..                                                 ...
# 397  [254, 1751, 409, 557, 647, 778, 915, 333, 1260...
# 398  [367, 1323, 527, 431, 661, 787, 966, 750, 1086...
# 399  [274, 1619, 736, 541, 805, 389, 1112, 1233, 14...
# 400  [311, 1496, 502, 622, 386, 954, 1103, 818, 128...
# 401  [238, 1543, 379, 544, 725, 827, 329, 1064, 112...
#
#                                         arg_end_bounds  \
# 0    [575, 2231, 714, 851, 1086, 1191, 1376, 1301, ...
# 1    [489, 2077, 624, 1156, 839, 946, 1057, 1204, 1...
# 2    [475, 1701, 1012, 613, 784, 943, 1135, 1526, 1...
# 3    [376, 1758, 239, 1031, 1624, 530, 818, 924, 11...
# 4    [359, 1652, 564, 883, 1425, 765, 988, 1078, 11...
# ..                                                 ...
# 397  [318, 1951, 541, 645, 767, 897, 1035, 407, 134...
# 398  [429, 1390, 645, 525, 737, 951, 1073, 785, 117...
# 399  [387, 1812, 796, 723, 944, 524, 1220, 1388, 16...
# 400  [384, 1667, 607, 815, 488, 1087, 1278, 937, 13...
# 401  [307, 1620, 462, 723, 810, 896, 377, 1112, 123...
#
#                                    argument_components  \
# 0    [we should attach more importance to cooperati...
# 1    [they are able to sustain their cultural ident...
# 2    [it has contributed to the economic developmen...
# 3    [this industry has affected the cultural attri...
# 4    [one who studies overseas will gain many skill...
# ..                                                 ...
# 397  [many different characters exist between male ...
# 398  [this is a worrying tread which has negative i...
# 399  [governments should devote a greater portion o...
# 400  [fatherhood is a as vital part of a healty par...
# 401  [both of studying hard and playing sports are ...
#
#                                            source_args  \
# 0                            [T4, T5, T6, T10, T9, T8]
# 1              [T9, T11, T12, T13, T5, T6, T7, T3, T8]
# 2                            [T10, T9, T6, T5, T4, T7]
# 3                           [T8, T7, T6, T10, T9, T11]
# 4                           [T6, T7, T8, T9, T10, T11]
# ..                                                 ...
# 397  [T3, T4, T5, T6, T7, T13, T14, T11, T9, T15, T16]
# 398                              [T4, T5, T6, T8, T10]
# 399                           [T4, T5, T6, T7, T9, T8]
# 400                          [T3, T7, T10, T4, T9, T6]
# 401  [T5, T3, T6, T11, T12, T4, T13, T9, T10, T14, T7]
#
#                                            target_args  \
# 0                           [T3, T3, T3, T11, T11, T7]
# 1             [T8, T10, T10, T10, T4, T4, T4, T4, T10]
# 2                             [T8, T8, T3, T3, T3, T8]
# 3                            [T4, T4, T4, T11, T5, T5]
# 4                             [T3, T4, T7, T4, T5, T5]
# ..                                                 ...
# 397  [T8, T8, T8, T8, T8, T12, T12, T10, T10, T10, ...
# 398                               [T3, T3, T7, T7, T9]
# 399                          [T3, T3, T3, T8, T8, T10]
# 400                           [T5, T6, T8, T3, T8, T8]
# 401    [T8, T8, T5, T10, T13, T15, T4, T4, T4, T4, T8]
#
#                                         relation_types  \
# 0    [supports, supports, supports, supports, suppo...
# 1    [supports, supports, supports, supports, suppo...
# 2    [supports, supports, supports, supports, suppo...
# 3    [supports, supports, supports, supports, suppo...
# 4    [supports, attacks, attacks, supports, support...
# ..                                                 ...
# 397  [supports, supports, supports, supports, suppo...
# 398  [supports, supports, supports, supports, suppo...
# 399  [supports, supports, supports, supports, suppo...
# 400  [supports, supports, supports, supports, suppo...
# 401  [supports, supports, supports, supports, suppo...
#
#                  stance_types  \
# 0         [For, Against, For]
# 1         [For, For, Against]
# 2                  [For, For]
# 3         [Against, For, For]
# 4    [For, For, For, Against]
# ..                        ...
# 397      [For, For, For, For]
# 398           [For, For, For]
# 399                [For, For]
# 400                [For, For]
# 401                [For, For]
#
#                                            essay_title  \
# 0    Should students be taught to compete or to coo...
# 1    More people are migrating to other countries t...
# 2    International tourism is now more common than ...
# 3    International tourism is now more common than ...
# 4                         Living and studying overseas
# ..                                                 ...
# 397  We can not forcedly put the same numbers of ma...
# 398                 Drugs, alcohol and messy sex lives
# 399  A greater proportion of the budget should be a...
# 400  Fatherhood should be as present as motherhood ...
# 401  Children should studying hard or playing sport...
#
#                                             essay_text
# 0    It is always said that competition can effecti...
# 1    The last 50 years have seen an increasing numb...
# 2    The last decade has seen an increasing number ...
# 3    The last 50 years have seen a significant incr...
# 4    It is every student's desire to study at a goo...
# ..                                                 ...
# 397  There is a view that universities and colleges...
# 398  Celebrities, for example movie stars, are usua...
# 399  In today's world, the concept of the welfare s...
# 400  In today's world, having and raising children ...
# 401  Some people believe that studying hard is esse...
#
# [402 rows x 12 columns]

# %%
def claim_sanity(row):
    
    return 1 if len([elem for elem in row.argument_types if elem == "Claim"]) == len(row.stance_types) else 0

# %%
pe_df['sanity_claims'] = pe_df.apply(lambda row: claim_sanity(row), axis=1)

# %%
pe_df['sanity_claims'].value_counts()
# Out:
# sanity_claims
# 1    402
# Name: count, dtype: int64

# %%
### Sanity Checks

# %%
def is_ordered(row):
    """Checks if the list is in the correct order."""
    extracted_numbers = [int(re.search(r'\d+', item).group()) for item in row.argument_ids] # type: ignore
    return extracted_numbers == sorted(extracted_numbers)

# %%
pe_df['sanity_check_1'] = pe_df.apply(lambda row: is_ordered(row), axis=1)

# %%
pe_df['sanity_check_1'].value_counts()
# Out:
# sanity_check_1
# True     354
# False     48
# Name: count, dtype: int64

# %%
pe_df[pe_df['sanity_check_1'] == False]
# Out:
#     ann_file_name                                       argument_ids  \
# 9    essay010.ann  [T3, T4, T5, T1, T2, T6, T7, T8, T9, T10, T11,...
# 11   essay012.ann  [T3, T4, T5, T6, T7, T1, T2, T8, T9, T10, T11,...
# 13   essay014.ann  [T1, T2, T3, T4, T5, T7, T8, T9, T10, T11, T12...
# 15   essay016.ann  [T1, T2, T3, T5, T4, T6, T7, T8, T9, T10, T11,...
# 22   essay023.ann  [T3, T1, T2, T4, T5, T6, T7, T9, T10, T11, T12...
# 25   essay026.ann  [T3, T4, T5, T6, T7, T8, T9, T10, T1, T2, T11,...
# 29   essay030.ann   [T12, T13, T14, T15, T1, T2, T3, T4, T5, T6, T7]
# 40   essay041.ann               [T2, T3, T4, T5, T6, T1, T7, T8, T9]
# 45   essay046.ann                   [T3, T4, T5, T6, T2, T7, T8, T9]
# 58   essay059.ann  [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T11,...
# 65   essay066.ann  [T1, T3, T4, T5, T6, T7, T2, T8, T9, T10, T11,...
# 68   essay069.ann  [T1, T3, T4, T5, T6, T7, T8, T2, T9, T10, T11,...
# 78   essay079.ann  [T1, T4, T5, T6, T7, T8, T9, T10, T11, T12, T2...
# 87   essay088.ann                       [T1, T2, T3, T4, T6, T5, T7]
# 98   essay099.ann  [T1, T2, T3, T4, T5, T6, T7, T8, T10, T11, T12...
# 124  essay125.ann  [T1, T2, T3, T4, T5, T6, T7, T9, T10, T11, T12...
# 134  essay135.ann  [T1, T2, T3, T5, T6, T7, T8, T4, T9, T10, T11,...
# 161  essay162.ann     [T1, T3, T4, T2, T5, T6, T7, T8, T9, T10, T11]
# 173  essay174.ann  [T1, T3, T4, T5, T6, T7, T8, T9, T10, T11, T12...
# 175  essay176.ann  [T1, T4, T5, T6, T7, T8, T2, T3, T9, T10, T11,...
# 177  essay178.ann  [T1, T3, T4, T5, T6, T7, T8, T9, T10, T11, T2,...
# 179  essay180.ann  [T1, T2, T4, T5, T6, T7, T8, T9, T10, T11, T12...
# 183  essay184.ann  [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T11,...
# 184  essay185.ann  [T1, T2, T3, T4, T5, T6, T8, T9, T7, T10, T11,...
# 192  essay193.ann  [T2, T3, T4, T5, T6, T7, T8, T9, T10, T11, T12...
# 195  essay196.ann  [T1, T2, T4, T3, T5, T6, T7, T8, T9, T10, T11,...
# 202  essay203.ann  [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T11,...
# 203  essay204.ann  [T2, T1, T3, T4, T5, T6, T7, T8, T9, T10, T11,...
# 207  essay208.ann  [T1, T2, T4, T5, T6, T7, T8, T9, T10, T11, T12...
# 213  essay214.ann  [T1, T2, T3, T4, T5, T7, T8, T9, T10, T11, T12...
# 217  essay218.ann  [T1, T3, T4, T5, T6, T7, T2, T8, T9, T10, T11,...
# 226  essay227.ann  [T1, T2, T3, T4, T5, T7, T6, T8, T9, T10, T11,...
# 233  essay234.ann  [T1, T2, T3, T4, T5, T7, T8, T9, T6, T10, T11,...
# 234  essay235.ann  [T1, T2, T3, T4, T6, T7, T8, T9, T11, T5, T10,...
# 238  essay239.ann  [T2, T3, T4, T5, T6, T1, T7, T8, T9, T10, T11,...
# 258  essay259.ann  [T1, T2, T4, T5, T6, T7, T8, T9, T10, T11, T12...
# 259  essay260.ann  [T1, T2, T3, T4, T5, T6, T7, T8, T9, T11, T10,...
# 265  essay266.ann  [T1, T2, T3, T5, T6, T7, T8, T9, T10, T11, T12...
# 268  essay269.ann  [T2, T3, T4, T5, T6, T7, T1, T8, T9, T10, T11,...
# 283  essay284.ann  [T2, T1, T3, T4, T5, T6, T7, T8, T9, T10, T11,...
# 308  essay309.ann  [T1, T3, T2, T4, T5, T6, T7, T8, T9, T10, T11,...
# 317  essay318.ann  [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T12,...
# 321  essay322.ann  [T1, T2, T3, T4, T5, T7, T8, T9, T10, T11, T12...
# 348  essay349.ann  [T1, T4, T5, T6, T7, T8, T9, T10, T11, T12, T1...
# 370  essay371.ann          [T1, T3, T4, T5, T6, T7, T8, T9, T2, T11]
# 382  essay383.ann                   [T2, T1, T3, T4, T5, T6, T7, T8]
# 396  essay397.ann     [T1, T3, T2, T4, T5, T6, T7, T8, T9, T10, T11]
# 401  essay402.ann  [T1, T2, T3, T5, T6, T7, T8, T4, T9, T10, T11,...
#
#                                         argument_types  \
# 9    [MajorClaim, Claim, Premise, Claim, Premise, P...
# 11   [Claim, Premise, Premise, Premise, Premise, Cl...
# 13   [Claim, Premise, Premise, Premise, Premise, Ma...
# 15   [Claim, MajorClaim, MajorClaim, Claim, Premise...
# 22   [MajorClaim, MajorClaim, Claim, Claim, Premise...
# 25   [MajorClaim, Claim, Claim, Premise, Premise, P...
# 29   [Claim, Premise, MajorClaim, Claim, MajorClaim...
# 40   [Claim, Premise, Premise, Premise, Premise, Cl...
# 45   [Claim, Premise, Premise, Premise, MajorClaim,...
# 58   [MajorClaim, MajorClaim, MajorClaim, Claim, Cl...
# 65   [MajorClaim, Claim, Premise, Premise, Premise,...
# 68   [MajorClaim, Claim, Premise, Premise, Premise,...
# 78   [MajorClaim, Premise, Claim, Premise, Premise,...
# 87   [MajorClaim, MajorClaim, Claim, Claim, Premise...
# 98   [MajorClaim, Claim, Premise, Claim, Premise, P...
# 124  [MajorClaim, MajorClaim, Premise, Premise, Pre...
# 134  [MajorClaim, MajorClaim, Claim, Premise, Premi...
# 161  [MajorClaim, Claim, Premise, Premise, Premise,...
# 173  [MajorClaim, Claim, Premise, Premise, Premise,...
# 175  [MajorClaim, Claim, Premise, Premise, Premise,...
# 177  [MajorClaim, Premise, Premise, Premise, Premis...
# 179  [MajorClaim, MajorClaim, Claim, Claim, Premise...
# 183  [MajorClaim, MajorClaim, Claim, Claim, Claim, ...
# 184  [MajorClaim, Claim, Premise, Premise, Premise,...
# 192  [Claim, Premise, Premise, Premise, Claim, Prem...
# 195  [MajorClaim, Claim, Premise, Premise, Premise,...
# 202  [MajorClaim, Claim, Premise, Claim, MajorClaim...
# 203  [MajorClaim, Claim, MajorClaim, Claim, Premise...
# 207  [Claim, MajorClaim, Claim, Premise, Premise, P...
# 213  [Premise, MajorClaim, Claim, MajorClaim, Claim...
# 217  [MajorClaim, Claim, Premise, Premise, Premise,...
# 226  [MajorClaim, MajorClaim, Claim, Premise, Premi...
# 233  [MajorClaim, MajorClaim, Claim, Premise, Claim...
# 234  [MajorClaim, Claim, Premise, Premise, Claim, P...
# 238  [Claim, Premise, Premise, Premise, Premise, Cl...
# 258  [MajorClaim, MajorClaim, Premise, Premise, Pre...
# 259  [MajorClaim, Claim, Premise, Premise, Premise,...
# 265  [MajorClaim, MajorClaim, Claim, Premise, Premi...
# 268  [Claim, Premise, Premise, Premise, Premise, Cl...
# 283  [Premise, MajorClaim, Premise, Claim, Premise,...
# 308  [MajorClaim, MajorClaim, Premise, Claim, Premi...
# 317  [MajorClaim, MajorClaim, Claim, Claim, Premise...
# 321  [Claim, Claim, MajorClaim, Claim, Claim, Claim...
# 348  [MajorClaim, Claim, Premise, Premise, Premise,...
# 370  [MajorClaim, Premise, Premise, Premise, Premis...
# 382  [MajorClaim, Claim, Claim, Premise, Premise, C...
# 396  [MajorClaim, MajorClaim, Premise, Premise, Pre...
# 401  [MajorClaim, MajorClaim, Premise, Premise, Pre...
#
#                                       arg_start_bounds  \
# 9    [328, 484, 399, 1244, 1086, 637, 732, 822, 947...
# 11   [390, 469, 702, 899, 961, 1151, 1845, 1901, 10...
# 13   [419, 522, 611, 733, 811, 1519, 1607, 1137, 12...
# 15   [1530, 1579, 320, 800, 540, 591, 705, 885, 949...
# 22   [216, 1831, 1959, 410, 541, 686, 853, 1002, 10...
# 25   [193, 104, 911, 501, 683, 752, 979, 1137, 1745...
# 29   [1123, 1236, 1342, 1400, 148, 318, 421, 572, 7...
# 40    [388, 649, 508, 791, 882, 1295, 1213, 966, 1396]
# 45        [706, 827, 955, 909, 1683, 1542, 1228, 1315]
# 58   [252, 1667, 1757, 1871, 589, 452, 318, 386, 84...
# 65   [523, 603, 1044, 732, 845, 1227, 1349, 1532, 1...
# 68   [242, 544, 698, 432, 350, 925, 1034, 1755, 118...
# 78   [380, 465, 943, 552, 740, 1087, 1161, 1202, 13...
# 87               [373, 1177, 1247, 459, 646, 810, 995]
# 98   [1557, 1631, 1723, 375, 488, 570, 688, 773, 10...
# 124  [248, 2251, 449, 616, 673, 845, 350, 1042, 115...
# 87   [a defeated person has to try and try until to...
# 98   [I would agree to idea of taking a break befor...
# 124  [the three most reasons are increased knowledg...
# 134  [international aid should be prioritised, peop...
# 161  [cheap flight can make many serious problem, c...
# 173  [I prefer the serious movies which are simple,...
# 175  [a quintessence of any visit to an excellent m...
# 177  [it is a good idea to build a large shopping c...
# 179  [groups or organizations are a vital part for ...
# 183  [it is much more gratifying to stay side by si...
# 184  [new forms of energy cannot soon replace fossi...
# 192  [The use of public transportation is the best ...
# 195  [One of these several ways of learning that I ...
# 202  [it is one's hard work that helps him reach hi...
# 203  [traditional learning still has many benefits ...
# 207  [it will take some time on it, high school stu...
# 213  [It spoils the smoker's reputation and threats...
# 217  [childhood is the happiest time of a person's ...
# 226  [spending the budget for space exploration is ...
# 233  [standardized tests are valuable option for ed...
# 234  [universities should provide free of cost educ...
# 238  [a person with good manner will give others a ...
# 258  [working at home is worse and less efficient t...
# 259  [once you are unique enough, you are already o...
# 265  [the advertising is not the main cause of unhe...
# 268  [Relating well to people can bring plenty of m...
# 283  [if all the story end up in the same way, it w...
# 308  [both choices have their own advantages and di...
# 317  [no additional payment should be charged on th...
# 321  [The historic buildings show the history of ou...
# 348  [I disagree with the idea that unimportant sub...
# 370  [people avoid eating meat mostly for the sake ...
# 382  [technology has a great contribution to our li...
# 396  [the affect of technology on culture is undeni...
# 401  [both of studying hard and playing sports are ...
#
#                                            source_args  \
# 9             [T5, T2, T8, T6, T7, T13, T11, T10, T14]
# 11            [T4, T5, T9, T7, T6, T13, T12, T11, T10]
# 13       [T2, T3, T4, T5, T12, T13, T10, T14, T9, T11]
# 15                 [T6, T4, T7, T11, T9, T8, T13, T12]
# 22                    [T5, T6, T7, T10, T12, T13, T15]
# 25                         [T8, T7, T6, T10, T12, T13]
# 29                                   [T13, T4, T5, T7]
# 40                            [T4, T8, T7, T3, T5, T6]
# 45                                [T6, T9, T4, T5, T8]
# 58   [T6, T8, T7, T10, T11, T12, T16, T14, T18, T19...
# 65                      [T5, T6, T2, T8, T10, T11, T4]
# 68                      [T4, T5, T6, T8, T9, T11, T12]
# 78      [T7, T6, T10, T11, T9, T12, T14, T15, T4, T16]
# 87                                            [T6, T7]
# 98        [T3, T9, T10, T11, T12, T13, T5, T6, T7, T8]
# 124      [T3, T4, T5, T9, T11, T12, T13, T14, T15, T7]
# 134            [T5, T6, T7, T9, T4, T10, T11, T13, T8]
# 161                      [T4, T2, T5, T7, T8, T9, T10]
# 173  [T9, T8, T4, T5, T6, T10, T11, T13, T2, T12, T14]
# 175            [T7, T6, T5, T2, T3, T9, T11, T13, T12]
# 177      [T4, T5, T6, T9, T10, T11, T12, T13, T14, T3]
# 179  [T3, T9, T8, T7, T6, T12, T13, T14, T11, T18, ...
# 183  [T7, T8, T9, T10, T11, T14, T13, T15, T12, T16...
# 184  [T5, T6, T3, T4, T9, T10, T11, T12, T7, T15, T...
# 192       [T3, T4, T5, T7, T8, T9, T10, T11, T13, T14]
# 195  [T4, T3, T9, T10, T11, T12, T14, T15, T6, T7, ...
# 202  [T3, T10, T11, T8, T7, T14, T15, T16, T17, T18...
# 203  [T5, T6, T7, T9, T10, T11, T12, T13, T15, T16,...
# 207                 [T5, T6, T7, T10, T9, T8, T13, T3]
# 213  [T1, T9, T11, T10, T7, T12, T15, T13, T14, T17...
# 217       [T4, T5, T6, T7, T2, T9, T10, T12, T13, T14]
# 226                [T5, T4, T8, T6, T12, T9, T11, T13]
# 233  [T18, T15, T16, T17, T6, T10, T13, T11, T19, T...
# 234                      [T4, T3, T8, T7, T9, T5, T11]
# 238   [T3, T4, T6, T5, T10, T7, T8, T13, T14, T15, T9]
# 258               [T5, T4, T6, T7, T11, T10, T12, T13]
# 259        [T4, T3, T7, T6, T5, T10, T9, T11, T13, T8]
# 265      [T5, T6, T7, T8, T9, T10, T13, T14, T15, T16]
# 268                [T4, T3, T5, T6, T9, T11, T13, T12]
# 283  [T9, T8, T7, T6, T2, T3, T5, T14, T17, T11, T1...
# 308      [T2, T7, T6, T5, T8, T11, T12, T14, T13, T15]
# 317      [T7, T8, T9, T5, T6, T13, T12, T11, T14, T15]
# 321             [T8, T9, T10, T11, T12, T14, T16, T13]
# 348       [T5, T6, T7, T8, T11, T9, T10, T12, T13, T2]
# 370                           [T6, T3, T4, T5, T9, T8]
# 382                                       [T4, T5, T7]
# 396                         [T5, T2, T4, T9, T10, T11]
# 401  [T5, T3, T6, T11, T12, T4, T13, T9, T10, T14, T7]
#
#                                            target_args  \
# 9             [T4, T1, T9, T9, T9, T12, T12, T12, T12]
# 11            [T3, T3, T1, T1, T1, T14, T14, T14, T14]
# 13          [T1, T1, T1, T1, T11, T11, T9, T6, T6, T6]
# 15                [T4, T5, T5, T10, T8, T10, T10, T10]
# 22                     [T4, T4, T4, T9, T11, T11, T14]
# 25                          [T7, T5, T5, T9, T11, T11]
# 29                                   [T12, T3, T6, T6]
# 40                            [T3, T1, T1, T5, T2, T1]
# 45                                [T4, T7, T3, T3, T7]
# 58   [T5, T5, T5, T9, T9, T13, T15, T15, T17, T17, ...
# 65                       [T3, T3, T7, T7, T9, T10, T3]
# 68                      [T3, T3, T3, T7, T7, T10, T10]
# 78        [T5, T5, T11, T8, T8, T8, T13, T13, T5, T13]
# 87                                            [T4, T5]
# 98       [T2, T14, T14, T14, T14, T14, T4, T4, T4, T4]
# 124       [T4, T6, T6, T10, T10, T10, T14, T8, T8, T6]
# 134            [T3, T3, T3, T4, T12, T12, T12, T3, T3]
# 161                       [T3, T3, T3, T6, T6, T6, T6]
# 173   [T7, T7, T3, T3, T3, T3, T3, T15, T15, T15, T15]
# 175            [T4, T4, T4, T8, T8, T8, T12, T10, T10]
# 177           [T7, T7, T7, T8, T8, T8, T2, T2, T2, T7]
# 179  [T5, T4, T4, T4, T4, T11, T11, T11, T10, T20, ...
# 183      [T6, T6, T6, T6, T6, T13, T5, T5, T5, T5, T5]
# 184  [T6, T2, T2, T2, T8, T7, T7, T7, T8, T14, T14,...
# 192         [T2, T2, T2, T6, T6, T6, T6, T6, T12, T12]
# 195  [T2, T2, T8, T8, T8, T8, T16, T16, T2, T2, T2,...
# 202  [T4, T9, T9, T6, T6, T13, T13, T13, T13, T13, ...
# 203  [T6, T4, T4, T8, T8, T8, T8, T8, T14, T14, T14...
# 207               [T4, T4, T4, T11, T8, T11, T12, T12]
# 213  [T3, T8, T10, T8, T8, T8, T14, T6, T6, T18, T2...
# 217       [T3, T3, T4, T3, T3, T8, T11, T11, T12, T12]
# 226               [T4, T7, T7, T7, T10, T10, T10, T10]
# 233  [T17, T14, T14, T14, T10, T13, T12, T12, T5, T...
# 234                     [T3, T2, T6, T6, T6, T10, T10]
# 238    [T2, T2, T2, T2, T9, T1, T1, T12, T12, T12, T1]
# 258                  [T8, T8, T8, T8, T10, T9, T9, T9]
# 259         [T3, T2, T2, T2, T2, T8, T8, T8, T12, T12]
# 265   [T11, T11, T6, T7, T11, T11, T12, T12, T12, T12]
# 268                [T2, T2, T7, T7, T8, T10, T12, T10]
# 283  [T4, T4, T4, T4, T4, T4, T4, T15, T10, T10, T1...
# 308  [T4, T10, T10, T10, T10, T16, T16, T16, T16, T16]
# 317      [T8, T4, T4, T4, T4, T11, T11, T10, T16, T16]
# 321                [T7, T7, T7, T7, T7, T13, T15, T15]
# 348     [T4, T4, T8, T4, T10, T14, T14, T14, T12, T14]
# 370                          [T5, T7, T7, T7, T8, T11]
# 382                                       [T3, T3, T6]
# 396                           [T4, T7, T6, T8, T8, T8]
# 401    [T8, T8, T5, T10, T13, T15, T4, T4, T4, T4, T8]
#
#                                         relation_types  \
# 9    [supports, supports, supports, supports, suppo...
# 11   [supports, supports, supports, supports, suppo...
# 13   [supports, supports, supports, supports, suppo...
# 15   [supports, supports, supports, supports, attac...
# 22   [supports, supports, attacks, supports, suppor...
# 25   [supports, supports, supports, supports, suppo...
# 29            [supports, supports, supports, supports]
# 40   [supports, supports, supports, supports, suppo...
# 45   [supports, supports, supports, supports, suppo...
# 58   [supports, supports, supports, supports, suppo...
# 65   [supports, supports, supports, supports, suppo...
# 68   [supports, supports, supports, supports, suppo...
# 78   [supports, supports, supports, supports, suppo...
# 87                                [supports, supports]
# 98   [supports, supports, supports, supports, suppo...
# 124  [supports, supports, supports, supports, suppo...
# 134  [supports, supports, supports, supports, suppo...
# 161  [supports, supports, supports, supports, suppo...
# 173  [supports, supports, supports, supports, suppo...
# 175  [supports, supports, supports, supports, suppo...
# 177  [supports, supports, supports, supports, suppo...
# 179  [supports, supports, supports, supports, suppo...
# 183  [supports, supports, supports, supports, suppo...
# 184  [supports, supports, supports, supports, attac...
# 192  [supports, supports, supports, supports, suppo...
# 195  [supports, supports, supports, supports, suppo...
# 202  [attacks, supports, supports, supports, suppor...
# 203  [supports, supports, supports, supports, suppo...
# 207  [supports, supports, supports, supports, suppo...
# 213  [supports, supports, supports, supports, suppo...
# 217  [supports, supports, supports, supports, suppo...
# 226  [attacks, attacks, supports, supports, support...
# 233  [supports, supports, supports, supports, suppo...
# 234  [supports, supports, supports, supports, suppo...
# 238  [supports, supports, supports, supports, suppo...
# 184           False
# 192           False
# 195           False
# 202           False
# 203           False
# 207           False
# 213           False
# 217           False
# 226           False
# 233           False
# 234           False
# 238           False
# 258           False
# 259           False
# 265           False
# 268           False
# 283           False
# 308           False
# 317           False
# 321           False
# 348           False
# 370           False
# 382           False
# 396           False
# 401           False

# %%
def get_source_acs(row):
    
    arg_ids = row.argument_ids    
    source_ids = row.source_args
    acs = row.argument_components
    
    source_acs = []
    
    for id in source_ids:
        
        idx = arg_ids.index(id)
        source_acs.append(acs[idx])
        
    return source_acs

# %%
get_source_acs(pe_df.iloc[0])
# Out:
# ['What we acquired from team work is not only how to achieve the same goal with others but more importantly, how to get along with others',
#  'During the process of cooperation, children can learn about how to listen to opinions of others, how to communicate with others, how to think comprehensively, and even how to compromise with other team members when conflicts occurred',
#  'All of these skills help them to get on well with other people and will benefit them for the whole life',
#  'Take Olympic games which is a form of competition for instance, it is hard to imagine how an athlete could win the game without the training of his or her coach, and the help of other professional staffs such as the people who take care of his diet, and those who are in charge of the medical care',
#  'when we consider about the question that how to win the game, we always find that we need the cooperation',
#  'the significance of competition is that how to become more excellence to gain the victory']

# %%
def get_target_acs(row):
    
    arg_ids = row.argument_ids    
    target_ids = row.target_args
    acs = row.argument_components
    
    target_acs = []
    
    for id in target_ids:
        
        idx = arg_ids.index(id)
        target_acs.append(acs[idx])
        
    return target_acs

# %%
get_target_acs(pe_df.iloc[0])
# Out:
# ['through cooperation, children can learn about interpersonal skills which are significant in the future life of all students',
#  'through cooperation, children can learn about interpersonal skills which are significant in the future life of all students',
#  'through cooperation, children can learn about interpersonal skills which are significant in the future life of all students',
#  'without the cooperation, there would be no victory of competition',
#  'without the cooperation, there would be no victory of competition',
#  'competition makes the society more effective']

# %%
pe_df.iloc[0]
# Out:
# ann_file_name                                               essay001.ann
# argument_ids              [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T11]
# argument_types         [MajorClaim, MajorClaim, Claim, Premise, Premi...
# arg_start_bounds       [503, 2154, 591, 716, 853, 1088, 1332, 1212, 1...
# arg_end_bounds         [575, 2231, 714, 851, 1086, 1191, 1376, 1301, ...
# argument_components    [we should attach more importance to cooperati...
# source_args                                    [T4, T5, T6, T10, T9, T8]
# target_args                                   [T3, T3, T3, T11, T11, T7]
# relation_types         [supports, supports, supports, supports, suppo...
# stance_types                                         [For, Against, For]
# essay_title            Should students be taught to compete or to coo...
# essay_text             It is always said that competition can effecti...
# sanity_claims                                                          1
# sanity_check_1                                                      True
# Name: 0, dtype: object

# %%
pe_df.iloc[0]['argument_components']
# Out:
# ['we should attach more importance to cooperation during primary education',
#  "a more cooperative attitudes towards life is more profitable in one's success",
#  'through cooperation, children can learn about interpersonal skills which are significant in the future life of all students',
#  'What we acquired from team work is not only how to achieve the same goal with others but more importantly, how to get along with others',
#  'During the process of cooperation, children can learn about how to listen to opinions of others, how to communicate with others, how to think comprehensively, and even how to compromise with other team members when conflicts occurred',
#  'All of these skills help them to get on well with other people and will benefit them for the whole life',
#  'competition makes the society more effective',
#  'the significance of competition is that how to become more excellence to gain the victory',
#  'when we consider about the question that how to win the game, we always find that we need the cooperation',
#  'Take Olympic games which is a form of competition for instance, it is hard to imagine how an athlete could win the game without the training of his or her coach, and the help of other professional staffs such as the people who take care of his diet, and those who are in charge of the medical care',
#  'without the cooperation, there would be no victory of competition']

# %%
pe_df['source_acs'] = pe_df.apply(lambda row: get_source_acs(row), axis=1)

# %%
pe_df['target_acs'] = pe_df.apply(lambda row: get_target_acs(row), axis=1)

# %%
pe_df
# Out:
#     ann_file_name                                       argument_ids  \
# 0    essay001.ann     [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T11]
# 1    essay002.ann  [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T11,...
# 2    essay003.ann          [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10]
# 3    essay004.ann     [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T11]
# 4    essay005.ann  [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T11,...
# ..            ...                                                ...
# 397  essay398.ann  [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T11,...
# 398  essay399.ann          [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10]
# 399  essay400.ann          [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10]
# 400  essay401.ann          [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10]
# 401  essay402.ann  [T1, T2, T3, T5, T6, T7, T8, T4, T9, T10, T11,...
#
#                                         argument_types  \
# 0    [MajorClaim, MajorClaim, Claim, Premise, Premi...
# 1    [MajorClaim, MajorClaim, Premise, Claim, Premi...
# 2    [MajorClaim, MajorClaim, Claim, Premise, Premi...
# 3    [MajorClaim, MajorClaim, Claim, Claim, Claim, ...
# 4    [MajorClaim, MajorClaim, Claim, Claim, Claim, ...
# ..                                                 ...
# 397  [Claim, MajorClaim, Premise, Premise, Premise,...
# 398  [MajorClaim, MajorClaim, Claim, Premise, Premi...
# 399  [MajorClaim, MajorClaim, Claim, Premise, Premi...
# 400  [MajorClaim, MajorClaim, Premise, Premise, Cla...
# 401  [MajorClaim, MajorClaim, Premise, Premise, Pre...
#
#                                       arg_start_bounds  \
# 0    [503, 2154, 591, 716, 853, 1088, 1332, 1212, 1...
# 1    [391, 1936, 500, 1089, 626, 841, 948, 1168, 12...
# 2    [352, 1568, 955, 487, 615, 786, 1024, 1454, 11...
# 3    [262, 1663, 179, 953, 1578, 417, 532, 820, 107...
# 4    [286, 1535, 388, 775, 1330, 566, 885, 993, 109...
# ..                                                 ...
# 397  [254, 1751, 409, 557, 647, 778, 915, 333, 1260...
# 398  [367, 1323, 527, 431, 661, 787, 966, 750, 1086...
# 399  [274, 1619, 736, 541, 805, 389, 1112, 1233, 14...
# 400  [311, 1496, 502, 622, 386, 954, 1103, 818, 128...
# 401  [238, 1543, 379, 544, 725, 827, 329, 1064, 112...
#
#                                         arg_end_bounds  \
# 0    [575, 2231, 714, 851, 1086, 1191, 1376, 1301, ...
# 1    [489, 2077, 624, 1156, 839, 946, 1057, 1204, 1...
# 2    [475, 1701, 1012, 613, 784, 943, 1135, 1526, 1...
# 3    [376, 1758, 239, 1031, 1624, 530, 818, 924, 11...
# 4    [359, 1652, 564, 883, 1425, 765, 988, 1078, 11...
# ..                                                 ...
# 397  [318, 1951, 541, 645, 767, 897, 1035, 407, 134...
# 398  [429, 1390, 645, 525, 737, 951, 1073, 785, 117...
# 399  [387, 1812, 796, 723, 944, 524, 1220, 1388, 16...
# 400  [384, 1667, 607, 815, 488, 1087, 1278, 937, 13...
# 401  [307, 1620, 462, 723, 810, 896, 377, 1112, 123...
#
#                                    argument_components  \
# 0    [we should attach more importance to cooperati...
# 1    [they are able to sustain their cultural ident...
# 2    [it has contributed to the economic developmen...
# 3    [this industry has affected the cultural attri...
# 4    [one who studies overseas will gain many skill...
# ..                                                 ...
# 397  [many different characters exist between male ...
# 398  [this is a worrying tread which has negative i...
# 399  [governments should devote a greater portion o...
# 400  [fatherhood is a as vital part of a healty par...
# 401  [both of studying hard and playing sports are ...
#
#                                            source_args  \
# 0                            [T4, T5, T6, T10, T9, T8]
# 1              [T9, T11, T12, T13, T5, T6, T7, T3, T8]
# 2                            [T10, T9, T6, T5, T4, T7]
# 3                           [T8, T7, T6, T10, T9, T11]
# 4                           [T6, T7, T8, T9, T10, T11]
# ..                                                 ...
# 397  [T3, T4, T5, T6, T7, T13, T14, T11, T9, T15, T16]
# 398                              [T4, T5, T6, T8, T10]
# 399                           [T4, T5, T6, T7, T9, T8]
# 400                          [T3, T7, T10, T4, T9, T6]
# 401  [T5, T3, T6, T11, T12, T4, T13, T9, T10, T14, T7]
#
#                                            target_args  \
# 0                           [T3, T3, T3, T11, T11, T7]
# 1             [T8, T10, T10, T10, T4, T4, T4, T4, T10]
# 2                             [T8, T8, T3, T3, T3, T8]
# 3                            [T4, T4, T4, T11, T5, T5]
# 4                             [T3, T4, T7, T4, T5, T5]
# ..                                                 ...
# 397  [T8, T8, T8, T8, T8, T12, T12, T10, T10, T10, ...
# 398                               [T3, T3, T7, T7, T9]
# 399                          [T3, T3, T3, T8, T8, T10]
# 400                           [T5, T6, T8, T3, T8, T8]
# 401    [T8, T8, T5, T10, T13, T15, T4, T4, T4, T4, T8]
#
#                                         relation_types  \
# 0    [supports, supports, supports, supports, suppo...
# 1    [supports, supports, supports, supports, suppo...
# 2    [supports, supports, supports, supports, suppo...
# 3    [supports, supports, supports, supports, suppo...
# 4    [supports, attacks, attacks, supports, support...
# ..                                                 ...
# 397  [supports, supports, supports, supports, suppo...
# 398  [supports, supports, supports, supports, suppo...
# 399  [supports, supports, supports, supports, suppo...
# 400  [supports, supports, supports, supports, suppo...
# 401  [supports, supports, supports, supports, suppo...
#
#                  stance_types  \
# 0         [For, Against, For]
# 1         [For, For, Against]
# 2                  [For, For]
# 3         [Against, For, For]
# 4    [For, For, For, Against]
# ..                        ...
# 397      [For, For, For, For]
# 398           [For, For, For]
# 399                [For, For]
# 400                [For, For]
# 401                [For, For]
#
#                                            essay_title  \
# 0    Should students be taught to compete or to coo...
# 1    More people are migrating to other countries t...
# 2    International tourism is now more common than ...
# 3    International tourism is now more common than ...
# 4                         Living and studying overseas
# ..                                                 ...
# 397  We can not forcedly put the same numbers of ma...
# 398                 Drugs, alcohol and messy sex lives
# 399  A greater proportion of the budget should be a...
# 400  Fatherhood should be as present as motherhood ...
# 401  Children should studying hard or playing sport...
#
#                                             essay_text  sanity_claims  \
# 0    It is always said that competition can effecti...              1
# 1    The last 50 years have seen an increasing numb...              1
# 2    The last decade has seen an increasing number ...              1
# 3    The last 50 years have seen a significant incr...              1
# 4    It is every student's desire to study at a goo...              1
# ..                                                 ...            ...
# 397  There is a view that universities and colleges...              1
# 398  Celebrities, for example movie stars, are usua...              1
# 399  In today's world, the concept of the welfare s...              1
# 400  In today's world, having and raising children ...              1
# 401  Some people believe that studying hard is esse...              1
#
#      sanity_check_1                                         source_acs  \
# 0              True  [What we acquired from team work is not only h...
# 1              True  [they need a connection back to their country ...
# 2              True  [Without this support and profit from tourism,...
# 3              True  [This was due to the lack of adequate controls...
# 4              True  [Compared to the peers studying in the home co...
# ..              ...                                                ...
# 397            True  [Most of male students tend to use their left ...
# 398            True  [The first impression of the celebrities seems...
# 399            True  [decreasing the number of patients in the heal...
# 400            True  [the role models within a family play a signif...
# 401           False  [children who always studying hard and getting...
#
#                                             target_acs
# 0    [through cooperation, children can learn about...
# 1    [it is crucial to keep one’s identity, keeping...
# 2    [tourism has survived many non-tangible cultur...
# 3    [international tourism can create negative imp...
# 4    [studying at an overseas university gives indi...
# ..                                                 ...
# 397  [boys and girls have the diversity in psycholo...
# 398  [This gives children the idea that it is not n...
# 399  [society should be educated and became aware o...
# 400  [The first reason why the father's role should...
# 401  [studying hard will give children a better fut...
#
# [402 rows x 16 columns]

# %%
def build_pairs(row):
    
    source_acs = row.source_acs
    target_acs = row.target_acs
    essay_acs_l = row.argument_components
    stances_l = row.relation_types
    
    pairs = []
    
    for s_ac, t_ac, stance in zip(source_acs, target_acs, stances_l):
        
        pairs.append((essay_acs_l.index(s_ac)+1, essay_acs_l.index(t_ac)+1, stance))
        
    return pairs

# %%
build_pairs(pe_df.iloc[370])
# Out:
# [(5, 4, 'attacks'),
#  (2, 6, 'supports'),
#  (3, 6, 'supports'),
#  (4, 6, 'attacks'),
#  (8, 7, 'supports'),
#  (7, 10, 'supports')]

# %%
pe_df['relation_pairs'] = pe_df.apply(lambda row: build_pairs(row), axis=1)

# %%
sum(pe_df.relation_pairs.apply(len))
# Out:
# 3832

# %%
sum(pe_df.relation_types.apply(len))
# Out:
# 3832

# %%
sum(pe_df.stance_types.apply(len))
# Out:
# 1506

# %%
pe_df
# Out:
#     ann_file_name                                       argument_ids  \
# 0    essay001.ann     [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T11]
# 1    essay002.ann  [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T11,...
# 2    essay003.ann          [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10]
# 3    essay004.ann     [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T11]
# 4    essay005.ann  [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T11,...
# ..            ...                                                ...
# 397  essay398.ann  [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T11,...
# 398  essay399.ann          [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10]
# 399  essay400.ann          [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10]
# 400  essay401.ann          [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10]
# 401  essay402.ann  [T1, T2, T3, T5, T6, T7, T8, T4, T9, T10, T11,...
#
#                                         argument_types  \
# 0    [MajorClaim, MajorClaim, Claim, Premise, Premi...
# 1    [MajorClaim, MajorClaim, Premise, Claim, Premi...
# 2    [MajorClaim, MajorClaim, Claim, Premise, Premi...
# 3    [MajorClaim, MajorClaim, Claim, Claim, Claim, ...
# 4    [MajorClaim, MajorClaim, Claim, Claim, Claim, ...
# ..                                                 ...
# 397  [Claim, MajorClaim, Premise, Premise, Premise,...
# 398  [MajorClaim, MajorClaim, Claim, Premise, Premi...
# 399  [MajorClaim, MajorClaim, Claim, Premise, Premi...
# 400  [MajorClaim, MajorClaim, Premise, Premise, Cla...
# 401  [MajorClaim, MajorClaim, Premise, Premise, Pre...
#
#                                       arg_start_bounds  \
# 0    [503, 2154, 591, 716, 853, 1088, 1332, 1212, 1...
# 1    [391, 1936, 500, 1089, 626, 841, 948, 1168, 12...
# 2    [352, 1568, 955, 487, 615, 786, 1024, 1454, 11...
# 3    [262, 1663, 179, 953, 1578, 417, 532, 820, 107...
# 4    [286, 1535, 388, 775, 1330, 566, 885, 993, 109...
# ..                                                 ...
# 397  [254, 1751, 409, 557, 647, 778, 915, 333, 1260...
# 398  [367, 1323, 527, 431, 661, 787, 966, 750, 1086...
# 399  [274, 1619, 736, 541, 805, 389, 1112, 1233, 14...
# 400  [311, 1496, 502, 622, 386, 954, 1103, 818, 128...
# 401  [238, 1543, 379, 544, 725, 827, 329, 1064, 112...
#
#                                         arg_end_bounds  \
# 0    [575, 2231, 714, 851, 1086, 1191, 1376, 1301, ...
# 1    [489, 2077, 624, 1156, 839, 946, 1057, 1204, 1...
# 2    [475, 1701, 1012, 613, 784, 943, 1135, 1526, 1...
# 3    [376, 1758, 239, 1031, 1624, 530, 818, 924, 11...
# 4    [359, 1652, 564, 883, 1425, 765, 988, 1078, 11...
# ..                                                 ...
# 397  [318, 1951, 541, 645, 767, 897, 1035, 407, 134...
# 398  [429, 1390, 645, 525, 737, 951, 1073, 785, 117...
# 399  [387, 1812, 796, 723, 944, 524, 1220, 1388, 16...
# 400  [384, 1667, 607, 815, 488, 1087, 1278, 937, 13...
# 401  [307, 1620, 462, 723, 810, 896, 377, 1112, 123...
#
#                                    argument_components  \
# 0    [we should attach more importance to cooperati...
# 1    [they are able to sustain their cultural ident...
# 2    [it has contributed to the economic developmen...
# 3    [this industry has affected the cultural attri...
# 4    [one who studies overseas will gain many skill...
# ..                                                 ...
# 397  [many different characters exist between male ...
# 398  [this is a worrying tread which has negative i...
# 399  [governments should devote a greater portion o...
# 400  [fatherhood is a as vital part of a healty par...
# 401  [both of studying hard and playing sports are ...
#
#                                            source_args  \
# 0                            [T4, T5, T6, T10, T9, T8]
# 1              [T9, T11, T12, T13, T5, T6, T7, T3, T8]
# 2                            [T10, T9, T6, T5, T4, T7]
# 3                           [T8, T7, T6, T10, T9, T11]
# 4                           [T6, T7, T8, T9, T10, T11]
# ..                                                 ...
# 397  [T3, T4, T5, T6, T7, T13, T14, T11, T9, T15, T16]
# 398                              [T4, T5, T6, T8, T10]
# 399                           [T4, T5, T6, T7, T9, T8]
# 400                          [T3, T7, T10, T4, T9, T6]
# 401  [T5, T3, T6, T11, T12, T4, T13, T9, T10, T14, T7]
#
#                                            target_args  \
# 0                           [T3, T3, T3, T11, T11, T7]
# 1             [T8, T10, T10, T10, T4, T4, T4, T4, T10]
# 2                             [T8, T8, T3, T3, T3, T8]
# 3                            [T4, T4, T4, T11, T5, T5]
# 4                             [T3, T4, T7, T4, T5, T5]
# ..                                                 ...
# 397  [T8, T8, T8, T8, T8, T12, T12, T10, T10, T10, ...
# 398                               [T3, T3, T7, T7, T9]
# 399                          [T3, T3, T3, T8, T8, T10]
# 400                           [T5, T6, T8, T3, T8, T8]
# 401    [T8, T8, T5, T10, T13, T15, T4, T4, T4, T4, T8]
#
#                                         relation_types  \
# 0    [supports, supports, supports, supports, suppo...
# 1    [supports, supports, supports, supports, suppo...
# 2    [supports, supports, supports, supports, suppo...
# 3    [supports, supports, supports, supports, suppo...
# 4    [supports, attacks, attacks, supports, support...
# ..                                                 ...
# 397  [supports, supports, supports, supports, suppo...
# 398  [supports, supports, supports, supports, suppo...
# 399  [supports, supports, supports, supports, suppo...
# 400  [supports, supports, supports, supports, suppo...
# 401  [supports, supports, supports, supports, suppo...
#
#                  stance_types  \
# 0         [For, Against, For]
# 1         [For, For, Against]
# 2                  [For, For]
# 3         [Against, For, For]
# 4    [For, For, For, Against]
# ..                        ...
# 397      [For, For, For, For]
# 398           [For, For, For]
# 399                [For, For]
# 400                [For, For]
# 401                [For, For]
#
#                                            essay_title  \
# 0    Should students be taught to compete or to coo...
# 1    More people are migrating to other countries t...
# 2    International tourism is now more common than ...
# 3    International tourism is now more common than ...
# 4                         Living and studying overseas
# ..                                                 ...
# 397  We can not forcedly put the same numbers of ma...
# 398                 Drugs, alcohol and messy sex lives
# 399  A greater proportion of the budget should be a...
# 400  Fatherhood should be as present as motherhood ...
# 401  Children should studying hard or playing sport...
#
#                                             essay_text  sanity_claims  \
# 0    It is always said that competition can effecti...              1
# 1    The last 50 years have seen an increasing numb...              1
# 2    The last decade has seen an increasing number ...              1
# 3    The last 50 years have seen a significant incr...              1
# 4    It is every student's desire to study at a goo...              1
# ..                                                 ...            ...
# 397  There is a view that universities and colleges...              1
# 398  Celebrities, for example movie stars, are usua...              1
# 399  In today's world, the concept of the welfare s...              1
# 400  In today's world, having and raising children ...              1
# 401  Some people believe that studying hard is esse...              1
#
#      sanity_check_1                                         source_acs  \
# 0              True  [What we acquired from team work is not only h...
# 1              True  [they need a connection back to their country ...
# 2              True  [Without this support and profit from tourism,...
# 3              True  [This was due to the lack of adequate controls...
# 4              True  [Compared to the peers studying in the home co...
# ..              ...                                                ...
# 397            True  [Most of male students tend to use their left ...
# 398            True  [The first impression of the celebrities seems...
# 399            True  [decreasing the number of patients in the heal...
# 400            True  [the role models within a family play a signif...
# 401           False  [children who always studying hard and getting...
#
#                                             target_acs  \
# 0    [through cooperation, children can learn about...
# 1    [it is crucial to keep one’s identity, keeping...
# 2    [tourism has survived many non-tangible cultur...
# 3    [international tourism can create negative imp...
# 4    [studying at an overseas university gives indi...
# ..                                                 ...
# 397  [boys and girls have the diversity in psycholo...
# 398  [This gives children the idea that it is not n...
# 399  [society should be educated and became aware o...
# 400  [The first reason why the father's role should...
# 401  [studying hard will give children a better fut...
#
#                                         relation_pairs
# 0    [(4, 3, supports), (5, 3, supports), (6, 3, su...
# 1    [(9, 8, supports), (11, 10, supports), (12, 10...
# 2    [(10, 8, supports), (9, 8, supports), (6, 3, s...
# 3    [(8, 4, supports), (7, 4, supports), (6, 4, su...
# 4    [(6, 3, supports), (7, 4, attacks), (8, 7, att...
# ..                                                 ...
# 397  [(3, 8, supports), (4, 8, supports), (5, 8, su...
# 398  [(4, 3, supports), (5, 3, supports), (6, 7, su...
# 399  [(4, 3, supports), (5, 3, supports), (6, 3, su...
# 400  [(3, 5, supports), (7, 6, supports), (10, 8, s...
# 401  [(4, 7, supports), (3, 7, supports), (5, 4, su...
#
# [402 rows x 17 columns]

# %%
def c_mc_pairs(row):
    
    arg_types = row.argument_types
    stances = row.stance_types
    
    pairs = [(i+1, j+1) for i, _ in enumerate(arg_types) for j, _ in enumerate(arg_types) if (arg_types[i] == "Claim" and arg_types[j] == "MajorClaim")]
    
    triplets = []
    i = 0
    
    stance = stances[i]
    source = pairs[0][0]
    
    for pair in pairs:
        
        new_source = pair[0]
        if new_source != source:
            i+=1
            stance = stances[i]
        
        #print((pair, stance))
        triplets.append((pair[0], pair[1], stance))
        source = new_source
    
    return triplets
    #triplets = [(pair, stance) for pair in pairs for idx, stance in enumerate(stances) if [elem for elem in arg_types if elem == "Claim"][idx]]

# %%
c_mc_pairs(pe_df.iloc[0])
# Out:
# [(3, 1, 'For'),
#  (3, 2, 'For'),
#  (7, 1, 'Against'),
#  (7, 2, 'Against'),
#  (11, 1, 'For'),
#  (11, 2, 'For')]

# %%
pe_df.iloc[0]
# Out:
# ann_file_name                                               essay001.ann
# argument_ids              [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T11]
# argument_types         [MajorClaim, MajorClaim, Claim, Premise, Premi...
# arg_start_bounds       [503, 2154, 591, 716, 853, 1088, 1332, 1212, 1...
# arg_end_bounds         [575, 2231, 714, 851, 1086, 1191, 1376, 1301, ...
# argument_components    [we should attach more importance to cooperati...
# source_args                                    [T4, T5, T6, T10, T9, T8]
# target_args                                   [T3, T3, T3, T11, T11, T7]
# relation_types         [supports, supports, supports, supports, suppo...
# stance_types                                         [For, Against, For]
# essay_title            Should students be taught to compete or to coo...
# essay_text             It is always said that competition can effecti...
# sanity_claims                                                          1
# sanity_check_1                                                      True
# source_acs             [What we acquired from team work is not only h...
# target_acs             [through cooperation, children can learn about...
# relation_pairs         [(4, 3, supports), (5, 3, supports), (6, 3, su...
# Name: 0, dtype: object

# %%
pe_df['stance_pairs'] = pe_df.apply(lambda row: c_mc_pairs(row), axis=1)

# %%
pe_df
# Out:
#     ann_file_name                                       argument_ids  \
# 0    essay001.ann     [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T11]
# 1    essay002.ann  [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T11,...
# 2    essay003.ann          [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10]
# 3    essay004.ann     [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T11]
# 4    essay005.ann  [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T11,...
# ..            ...                                                ...
# 397  essay398.ann  [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T11,...
# 398  essay399.ann          [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10]
# 399  essay400.ann          [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10]
# 400  essay401.ann          [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10]
# 401  essay402.ann  [T1, T2, T3, T5, T6, T7, T8, T4, T9, T10, T11,...
#
#                                         argument_types  \
# 0    [MajorClaim, MajorClaim, Claim, Premise, Premi...
# 1    [MajorClaim, MajorClaim, Premise, Claim, Premi...
# 2    [MajorClaim, MajorClaim, Claim, Premise, Premi...
# 3    [MajorClaim, MajorClaim, Claim, Claim, Claim, ...
# 4    [MajorClaim, MajorClaim, Claim, Claim, Claim, ...
# ..                                                 ...
# 397  [Claim, MajorClaim, Premise, Premise, Premise,...
# 398  [MajorClaim, MajorClaim, Claim, Premise, Premi...
# 399  [MajorClaim, MajorClaim, Claim, Premise, Premi...
# 400  [MajorClaim, MajorClaim, Premise, Premise, Cla...
# 401  [MajorClaim, MajorClaim, Premise, Premise, Pre...
#
#                                       arg_start_bounds  \
# 0    [503, 2154, 591, 716, 853, 1088, 1332, 1212, 1...
# 1    [391, 1936, 500, 1089, 626, 841, 948, 1168, 12...
# 2    [352, 1568, 955, 487, 615, 786, 1024, 1454, 11...
# 3    [262, 1663, 179, 953, 1578, 417, 532, 820, 107...
# 4    [286, 1535, 388, 775, 1330, 566, 885, 993, 109...
# ..                                                 ...
# 397  [254, 1751, 409, 557, 647, 778, 915, 333, 1260...
# 398  [367, 1323, 527, 431, 661, 787, 966, 750, 1086...
# 399  [274, 1619, 736, 541, 805, 389, 1112, 1233, 14...
# 400  [311, 1496, 502, 622, 386, 954, 1103, 818, 128...
# 401  [238, 1543, 379, 544, 725, 827, 329, 1064, 112...
#
#                                         arg_end_bounds  \
# 0    [575, 2231, 714, 851, 1086, 1191, 1376, 1301, ...
# 1    [489, 2077, 624, 1156, 839, 946, 1057, 1204, 1...
# 2    [475, 1701, 1012, 613, 784, 943, 1135, 1526, 1...
# 3    [376, 1758, 239, 1031, 1624, 530, 818, 924, 11...
# 4    [359, 1652, 564, 883, 1425, 765, 988, 1078, 11...
# ..                                                 ...
# 397  [318, 1951, 541, 645, 767, 897, 1035, 407, 134...
# 398  [429, 1390, 645, 525, 737, 951, 1073, 785, 117...
# 399  [387, 1812, 796, 723, 944, 524, 1220, 1388, 16...
# 400  [384, 1667, 607, 815, 488, 1087, 1278, 937, 13...
# 401  [307, 1620, 462, 723, 810, 896, 377, 1112, 123...
#
#                                    argument_components  \
# 0    [we should attach more importance to cooperati...
# 1    [they are able to sustain their cultural ident...
# 2    [it has contributed to the economic developmen...
# 3    [this industry has affected the cultural attri...
# 4    [one who studies overseas will gain many skill...
# ..                                                 ...
# 397  [many different characters exist between male ...
# 398  [this is a worrying tread which has negative i...
# 399  [governments should devote a greater portion o...
# 400  [fatherhood is a as vital part of a healty par...
# 401  [both of studying hard and playing sports are ...
#
#                                            source_args  \
# 0                            [T4, T5, T6, T10, T9, T8]
# 1              [T9, T11, T12, T13, T5, T6, T7, T3, T8]
# 2                            [T10, T9, T6, T5, T4, T7]
# 3                           [T8, T7, T6, T10, T9, T11]
# 4                           [T6, T7, T8, T9, T10, T11]
# ..                                                 ...
# 397  [T3, T4, T5, T6, T7, T13, T14, T11, T9, T15, T16]
# 398                              [T4, T5, T6, T8, T10]
# 399                           [T4, T5, T6, T7, T9, T8]
# 400                          [T3, T7, T10, T4, T9, T6]
# 401  [T5, T3, T6, T11, T12, T4, T13, T9, T10, T14, T7]
#
#                                            target_args  \
# 0                           [T3, T3, T3, T11, T11, T7]
# 1             [T8, T10, T10, T10, T4, T4, T4, T4, T10]
# 2                             [T8, T8, T3, T3, T3, T8]
# 3                            [T4, T4, T4, T11, T5, T5]
# 4                             [T3, T4, T7, T4, T5, T5]
# ..                                                 ...
# 397  [T8, T8, T8, T8, T8, T12, T12, T10, T10, T10, ...
# 398                               [T3, T3, T7, T7, T9]
# 399                          [T3, T3, T3, T8, T8, T10]
# 400                           [T5, T6, T8, T3, T8, T8]
# 401    [T8, T8, T5, T10, T13, T15, T4, T4, T4, T4, T8]
#
#                                         relation_types  \
# 0    [supports, supports, supports, supports, suppo...
# 1    [supports, supports, supports, supports, suppo...
# 2    [supports, supports, supports, supports, suppo...
# 3    [supports, supports, supports, supports, suppo...
# 4    [supports, attacks, attacks, supports, support...
# ..                                                 ...
# 397  [supports, supports, supports, supports, suppo...
# 398  [supports, supports, supports, supports, suppo...
# 399  [supports, supports, supports, supports, suppo...
# 400  [supports, supports, supports, supports, suppo...
# 401  [supports, supports, supports, supports, suppo...
#
#                  stance_types  \
# 0         [For, Against, For]
# 1         [For, For, Against]
# 2                  [For, For]
# 3         [Against, For, For]
# 4    [For, For, For, Against]
# ..                        ...
# 397      [For, For, For, For]
# 398           [For, For, For]
# 399                [For, For]
# 400                [For, For]
# 401                [For, For]
#
#                                            essay_title  \
# 0    Should students be taught to compete or to coo...
# 1    More people are migrating to other countries t...
# 2    International tourism is now more common than ...
# 3    International tourism is now more common than ...
# 4                         Living and studying overseas
# ..                                                 ...
# 397  We can not forcedly put the same numbers of ma...
# 398                 Drugs, alcohol and messy sex lives
# 399  A greater proportion of the budget should be a...
# 400  Fatherhood should be as present as motherhood ...
# 401  Children should studying hard or playing sport...
#
#                                             essay_text  sanity_claims  \
# 0    It is always said that competition can effecti...              1
# 1    The last 50 years have seen an increasing numb...              1
# 2    The last decade has seen an increasing number ...              1
# 3    The last 50 years have seen a significant incr...              1
# 4    It is every student's desire to study at a goo...              1
# ..                                                 ...            ...
# 397  There is a view that universities and colleges...              1
# 398  Celebrities, for example movie stars, are usua...              1
# 399  In today's world, the concept of the welfare s...              1
# 400  In today's world, having and raising children ...              1
# 401  Some people believe that studying hard is esse...              1
#
#      sanity_check_1                                         source_acs  \
# 0              True  [What we acquired from team work is not only h...
# 1              True  [they need a connection back to their country ...
# 2              True  [Without this support and profit from tourism,...
# 3              True  [This was due to the lack of adequate controls...
# 4              True  [Compared to the peers studying in the home co...
# ..              ...                                                ...
# 397            True  [Most of male students tend to use their left ...
# 398            True  [The first impression of the celebrities seems...
# 399            True  [decreasing the number of patients in the heal...
# 400            True  [the role models within a family play a signif...
# 401           False  [children who always studying hard and getting...
#
#                                             target_acs  \
# 0    [through cooperation, children can learn about...
# 1    [it is crucial to keep one’s identity, keeping...
# 2    [tourism has survived many non-tangible cultur...
# 3    [international tourism can create negative imp...
# 4    [studying at an overseas university gives indi...
# ..                                                 ...
# 397  [boys and girls have the diversity in psycholo...
# 398  [This gives children the idea that it is not n...
# 399  [society should be educated and became aware o...
# 400  [The first reason why the father's role should...
# 401  [studying hard will give children a better fut...
#
#                                         relation_pairs  \
# 0    [(4, 3, supports), (5, 3, supports), (6, 3, su...
# 1    [(9, 8, supports), (11, 10, supports), (12, 10...
# 2    [(10, 8, supports), (9, 8, supports), (6, 3, s...
# 3    [(8, 4, supports), (7, 4, supports), (6, 4, su...
# 4    [(6, 3, supports), (7, 4, attacks), (8, 7, att...
# ..                                                 ...
# 397  [(3, 8, supports), (4, 8, supports), (5, 8, su...
# 398  [(4, 3, supports), (5, 3, supports), (6, 7, su...
# 399  [(4, 3, supports), (5, 3, supports), (6, 3, su...
# 400  [(3, 5, supports), (7, 6, supports), (10, 8, s...
# 401  [(4, 7, supports), (3, 7, supports), (5, 4, su...
#
#                                           stance_pairs
# 0    [(3, 1, For), (3, 2, For), (7, 1, Against), (7...
# 1    [(4, 1, For), (4, 2, For), (10, 1, For), (10, ...
# 2    [(3, 1, For), (3, 2, For), (8, 1, For), (8, 2,...
# 3    [(3, 1, Against), (3, 2, Against), (4, 1, For)...
# 4    [(3, 1, For), (3, 2, For), (4, 1, For), (4, 2,...
# ..                                                 ...
# 397  [(1, 2, For), (8, 2, For), (10, 2, For), (12, ...
# 398  [(3, 1, For), (3, 2, For), (7, 1, For), (7, 2,...
# 399  [(3, 1, For), (3, 2, For), (10, 1, For), (10, ...
# 400  [(5, 1, For), (5, 2, For), (8, 1, For), (8, 2,...
# 401  [(7, 1, For), (7, 2, For), (15, 1, For), (15, ...
#
# [402 rows x 18 columns]

# %%
pe_df.columns
# Out:
# Index(['ann_file_name', 'argument_ids', 'argument_types', 'arg_start_bounds',
#        'arg_end_bounds', 'argument_components', 'source_args', 'target_args',
#        'relation_types', 'stance_types', 'essay_title', 'essay_text',
#        'sanity_claims', 'sanity_check_1', 'source_acs', 'target_acs',
#        'relation_pairs', 'stance_pairs'],
#       dtype='object')

# %%
pe_df['argument_ids'] = pe_df['argument_ids'].apply(lambda x: x[0] if isinstance(x, list) else x)

# %%
pe_df['sort_key'] = pe_df['argument_ids'].apply(lambda x: int(x[1:]))

# %%
sorted_pe_df = pe_df.sort_values(by='sort_key').reset_index(drop=True)

# %%
pe_df.columns
# Out:
# Index(['ann_file_name', 'argument_ids', 'argument_types', 'arg_start_bounds',
#        'arg_end_bounds', 'argument_components', 'source_args', 'target_args',
#        'relation_types', 'essay_title', 'essay_text', 'sanity_check_1',
#        'source_acs', 'target_acs', 'sort_key'],
#       dtype='object')

# %%
columns_to_sort = ['argument_types', 'arg_start_bounds',
       'arg_end_bounds', 'argument_components']

# %%
for col in pe_df.columns:
    if col not in columns_to_sort:
        sorted_pe_df[col] = pe_df[col]

# %%
sorted_pe_df = sorted_pe_df.drop(columns=['sort_key'])

# %%
sorted_pe_df
# Out:
#     ann_file_name argument_ids  \
# 0    essay001.ann           T1
# 1    essay002.ann           T1
# 2    essay003.ann           T1
# 3    essay004.ann           T1
# 4    essay005.ann           T1
# ..            ...          ...
# 397  essay398.ann           T1
# 398  essay399.ann           T1
# 399  essay400.ann           T1
# 400  essay401.ann           T1
# 401  essay402.ann           T1
#
#                                         argument_types  \
# 0    [MajorClaim, MajorClaim, Claim, Premise, Premi...
# 1    [Claim, Claim, Premise, MajorClaim, Claim, Pre...
# 2    [MajorClaim, Claim, Premise, Premise, Premise,...
# 3    [MajorClaim, Claim, Premise, Premise, Claim, P...
# 4    [Claim, MajorClaim, Claim, Premise, Premise, P...
# ..                                                 ...
# 397  [Claim, Premise, Premise, Premise, MajorClaim,...
# 398  [MajorClaim, MajorClaim, Claim, Claim, Premise...
# 399  [MajorClaim, Claim, Claim, Premise, Premise, P...
# 400  [MajorClaim, Claim, Premise, Claim, Premise, P...
# 401  [Claim, Premise, MajorClaim, Claim, MajorClaim...
#
#                                       arg_start_bounds  \
# 0    [503, 2154, 591, 716, 853, 1088, 1332, 1212, 1...
# 1    [87, 163, 242, 24, 445, 324, 838, 926, 988, 10...
# 2    [217, 137, 500, 599, 838, 733, 908, 406, 971, ...
# 3    [530, 618, 826, 891, 1084, 1163, 1275, 1551, 1...
# 4    [284, 183, 410, 508, 686, 899, 1030, 1202, 133...
# ..                                                 ...
# 397       [706, 827, 955, 909, 1683, 1542, 1228, 1315]
# 398  [216, 1831, 1959, 410, 541, 686, 853, 1002, 10...
# 399  [193, 104, 911, 501, 683, 752, 979, 1137, 1745...
# 400  [328, 484, 399, 1244, 1086, 637, 732, 822, 947...
# 401  [1123, 1236, 1342, 1400, 148, 318, 421, 572, 7...
#
#                                         arg_end_bounds  \
# 0    [575, 2231, 714, 851, 1086, 1191, 1376, 1301, ...
# 1    [161, 232, 322, 85, 698, 443, 924, 983, 1082, ...
# 2    [338, 215, 597, 690, 906, 822, 961, 498, 1071,...
# 3    [575, 818, 880, 1007, 1156, 1273, 1464, 1672, ...
# 4    [350, 277, 506, 684, 897, 1009, 1184, 1337, 14...
# ..                                                 ...
# 397      [795, 904, 1207, 953, 1778, 1666, 1313, 1488]
# 398  [302, 1948, 2014, 497, 669, 837, 967, 1047, 12...
# 399  [383, 183, 977, 676, 736, 903, 1041, 1295, 185...
# 400  [397, 578, 473, 1353, 1231, 713, 820, 945, 107...
# 401  [1232, 1301, 1391, 1558, 316, 400, 570, 720, 8...
#
#                                    argument_components  \
# 0    [we should attach more importance to cooperati...
# 1    [The big cities have lots of advantages and fa...
# 2    [I personally disagree with this notion that t...
# 3    [being present at classes seems a wiser option...
# 4    [it can improve the efficiency and reduce the ...
# ..                                                 ...
# 397  [A university, in common sense, is a medium fo...
# 398  [I do not think these disadvantages will outwe...
# 399  [it is obvious that prepared food can bring ab...
# 400  [governments spend more money on buses, trains...
# 401  [this will encourage all the parents to think ...
#
#                                            source_args  \
# 0                            [T4, T5, T6, T10, T9, T8]
# 1              [T9, T11, T12, T13, T5, T6, T7, T3, T8]
# 2                            [T10, T9, T6, T5, T4, T7]
# 3                           [T8, T7, T6, T10, T9, T11]
# 4                           [T6, T7, T8, T9, T10, T11]
# ..                                                 ...
# 397  [T3, T4, T5, T6, T7, T13, T14, T11, T9, T15, T16]
# 398                              [T4, T5, T6, T8, T10]
# 399                           [T4, T5, T6, T7, T9, T8]
# 400                          [T3, T7, T10, T4, T9, T6]
# 401  [T5, T3, T6, T11, T12, T4, T13, T9, T10, T14, T7]
#
#                                            target_args  \
# 0                           [T3, T3, T3, T11, T11, T7]
# 1             [T8, T10, T10, T10, T4, T4, T4, T4, T10]
# 2                             [T8, T8, T3, T3, T3, T8]
# 3                            [T4, T4, T4, T11, T5, T5]
# 4                             [T3, T4, T7, T4, T5, T5]
# ..                                                 ...
# 397  [T8, T8, T8, T8, T8, T12, T12, T10, T10, T10, ...
# 398                               [T3, T3, T7, T7, T9]
# 399                          [T3, T3, T3, T8, T8, T10]
# 400                           [T5, T6, T8, T3, T8, T8]
# 401    [T8, T8, T5, T10, T13, T15, T4, T4, T4, T4, T8]
#
#                                         relation_types  \
# 0    [supports, supports, supports, supports, suppo...
# 1    [supports, supports, supports, supports, suppo...
# 2    [supports, supports, supports, supports, suppo...
# 3    [supports, supports, supports, supports, suppo...
# 4    [supports, attacks, attacks, supports, support...
# ..                                                 ...
# 397  [supports, supports, supports, supports, suppo...
# 398  [supports, supports, supports, supports, suppo...
# 399  [supports, supports, supports, supports, suppo...
# 400  [supports, supports, supports, supports, suppo...
# 401  [supports, supports, supports, supports, suppo...
#
#                                            essay_title  \
# 0    Should students be taught to compete or to coo...
# 1    More people are migrating to other countries t...
# 2    International tourism is now more common than ...
# 3    International tourism is now more common than ...
# 4                         Living and studying overseas
# ..                                                 ...
# 397  We can not forcedly put the same numbers of ma...
# 398                 Drugs, alcohol and messy sex lives
# 399  A greater proportion of the budget should be a...
# 400  Fatherhood should be as present as motherhood ...
# 401  Children should studying hard or playing sport...
#
#                                             essay_text  sanity_check_1  \
# 0    It is always said that competition can effecti...            True
# 1    The last 50 years have seen an increasing numb...            True
# 2    The last decade has seen an increasing number ...            True
# 3    The last 50 years have seen a significant incr...            True
# 4    It is every student's desire to study at a goo...            True
# ..                                                 ...             ...
# 397  There is a view that universities and colleges...            True
# 398  Celebrities, for example movie stars, are usua...            True
# 399  In today's world, the concept of the welfare s...            True
# 400  In today's world, having and raising children ...            True
# 401  Some people believe that studying hard is esse...           False
#
#                                             source_acs  \
# 0    [What we acquired from team work is not only h...
# 1    [they need a connection back to their country ...
# 2    [Without this support and profit from tourism,...
# 3    [This was due to the lack of adequate controls...
# 4    [Compared to the peers studying in the home co...
# ..                                                 ...
# 397  [Most of male students tend to use their left ...
# 398  [The first impression of the celebrities seems...
# 399  [decreasing the number of patients in the heal...
# 400  [the role models within a family play a signif...
# 401  [children who always studying hard and getting...
#
#                                             target_acs
# 0    [through cooperation, children can learn about...
# 1    [it is crucial to keep one’s identity, keeping...
# 2    [tourism has survived many non-tangible cultur...
# 3    [international tourism can create negative imp...
# 4    [studying at an overseas university gives indi...
# ..                                                 ...
# 397  [boys and girls have the diversity in psycholo...
# 398  [This gives children the idea that it is not n...
# 399  [society should be educated and became aware o...
# 400  [The first reason why the father's role should...
# 401  [studying hard will give children a better fut...
#
# [402 rows x 14 columns]

# %%
def sort_arg_ids(row):
    
    sorted_indices = sorted(range(len(row.argument_ids)), key=lambda i: int(row.argument_ids[i][1:]))

# %%
### Sanity Check 2

# %%
def sanity_check(row):
    
    #check1 = True if len(row.argument_ids) == len(row.argument_components) else False
    check2 = True if int(re.match(r"([A-Za-z]+)(\d+)", row.argument_ids[-1]).groups()[1]) == len(row.argument_components) else False # type: ignore
    
    #return check1
    return check2

# %%
pe_df['sanity_check'] = pe_df.apply(lambda row: sanity_check(row), axis=1)

# %%
pe_df[pe_df['sanity_check'] == False]
# Out:
#     ann_file_name                                       argument_ids  \
# 22   essay023.ann  [T3, T1, T2, T4, T5, T6, T7, T9, T10, T11, T12...
# 29   essay030.ann   [T12, T13, T14, T15, T1, T2, T3, T4, T5, T6, T7]
# 45   essay046.ann                   [T3, T4, T5, T6, T2, T7, T8, T9]
# 183  essay184.ann  [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T11,...
# 192  essay193.ann  [T2, T3, T4, T5, T6, T7, T8, T9, T10, T11, T12...
# 258  essay259.ann  [T1, T2, T4, T5, T6, T7, T8, T9, T10, T11, T12...
# 265  essay266.ann  [T1, T2, T3, T5, T6, T7, T8, T9, T10, T11, T12...
# 296  essay297.ann  [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T11,...
# 321  essay322.ann  [T1, T2, T3, T4, T5, T7, T8, T9, T10, T11, T12...
# 357  essay358.ann  [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T11,...
# 370  essay371.ann          [T1, T3, T4, T5, T6, T7, T8, T9, T2, T11]
#
#                                         argument_types  \
# 22   [MajorClaim, MajorClaim, Claim, Claim, Premise...
# 29   [Claim, Premise, MajorClaim, Claim, MajorClaim...
# 45   [Claim, Premise, Premise, Premise, MajorClaim,...
# 183  [MajorClaim, MajorClaim, Claim, Claim, Claim, ...
# 192  [Claim, Premise, Premise, Premise, Claim, Prem...
# 258  [MajorClaim, MajorClaim, Premise, Premise, Pre...
# 265  [MajorClaim, MajorClaim, Claim, Premise, Premi...
# 296  [MajorClaim, MajorClaim, Premise, Premise, Pre...
# 321  [Claim, Claim, MajorClaim, Claim, Claim, Claim...
# 357  [MajorClaim, Premise, Premise, Premise, Premis...
# 370  [MajorClaim, Premise, Premise, Premise, Premis...
#
#                                       arg_start_bounds  \
# 22   [216, 1831, 1959, 410, 541, 686, 853, 1002, 10...
# 29   [1123, 1236, 1342, 1400, 148, 318, 421, 572, 7...
# 45        [706, 827, 955, 909, 1683, 1542, 1228, 1315]
# 183  [301, 1668, 1595, 1726, 1101, 453, 505, 661, 7...
# 192  [370, 468, 509, 602, 787, 857, 940, 988, 1055,...
# 258  [407, 1531, 648, 573, 817, 906, 493, 1001, 110...
# 265  [480, 2018, 2196, 623, 745, 880, 939, 1041, 12...
# 296  [277, 2063, 462, 535, 667, 868, 377, 969, 906,...
# 321  [222, 293, 1414, 1465, 1539, 354, 513, 594, 66...
# 357  [1630, 560, 635, 706, 773, 835, 998, 921, 467,...
# 370  [459, 631, 767, 837, 895, 551, 1156, 1059, 144...
#
#                                         arg_end_bounds  \
# 22   [302, 1948, 2014, 497, 669, 837, 967, 1047, 12...
# 29   [1232, 1301, 1391, 1558, 316, 400, 570, 720, 8...
# 45       [795, 904, 1207, 953, 1778, 1666, 1313, 1488]
# 183  [444, 1724, 1662, 1770, 1159, 503, 645, 739, 9...
# 192  [466, 507, 600, 785, 855, 938, 986, 1053, 1149...
# 258  [477, 1616, 815, 646, 883, 991, 571, 1088, 115...
# 265  [544, 2082, 2310, 727, 869, 937, 1039, 1226, 1...
# 296  [331, 2140, 525, 652, 858, 896, 460, 1015, 967...
# 321  [278, 351, 1463, 1527, 1639, 511, 592, 663, 72...
# 357  [1724, 613, 704, 771, 833, 919, 1076, 990, 549...
# 370  [540, 736, 810, 893, 991, 629, 1227, 1151, 155...
#
#                                    argument_components  \
# 22   [I do not think these disadvantages will outwe...
# 29   [this will encourage all the parents to think ...
# 45   [A university, in common sense, is a medium fo...
# 183  [it is much more gratifying to stay side by si...
# 192  [The use of public transportation is the best ...
# 258  [working at home is worse and less efficient t...
# 265  [the advertising is not the main cause of unhe...
# 296  [online classes should never replace classroom...
# 321  [The historic buildings show the history of ou...
# 357  [the option of working or studying from home i...
# 370  [people avoid eating meat mostly for the sake ...
#
#                                            source_args  \
# 22                    [T5, T6, T7, T10, T12, T13, T15]
# 29                                   [T13, T4, T5, T7]
# 45                                [T6, T9, T4, T5, T8]
# 183  [T7, T8, T9, T10, T11, T14, T13, T15, T12, T16...
# 192       [T3, T4, T5, T7, T8, T9, T10, T11, T13, T14]
# 258               [T5, T4, T6, T7, T11, T10, T12, T13]
# 265      [T5, T6, T7, T8, T9, T10, T13, T14, T15, T16]
# 296  [T4, T3, T5, T6, T11, T10, T9, T14, T13, T15, ...
# 321             [T8, T9, T10, T11, T12, T14, T16, T13]
# 357        [T6, T8, T3, T2, T4, T5, T12, T11, T10, T9]
# 370                           [T6, T3, T4, T5, T9, T8]
#
#                                           target_args  \
# 22                    [T4, T4, T4, T9, T11, T11, T14]
# 29                                  [T12, T3, T6, T6]
# 45                               [T4, T7, T3, T3, T7]
# 183     [T6, T6, T6, T6, T6, T13, T5, T5, T5, T5, T5]
# 192        [T2, T2, T2, T6, T6, T6, T6, T6, T12, T12]
# 258                 [T8, T8, T8, T8, T10, T9, T9, T9]
# 265  [T11, T11, T6, T7, T11, T11, T12, T12, T12, T12]
# 296  [T3, T7, T7, T7, T8, T8, T8, T12, T12, T12, T16]
# 321               [T7, T7, T7, T7, T7, T13, T15, T15]
# 357       [T5, T5, T2, T7, T7, T7, T14, T14, T14, T7]
# 370                         [T5, T7, T7, T7, T8, T11]
#
#                                         relation_types  \
# 22   [supports, supports, attacks, supports, suppor...
# 29            [supports, supports, supports, supports]
# 45   [supports, supports, supports, supports, suppo...
# 183  [supports, supports, supports, supports, suppo...
# 192  [supports, supports, supports, supports, suppo...
# 258  [supports, supports, supports, supports, suppo...
# 265  [supports, attacks, supports, supports, suppor...
# 296  [supports, supports, supports, supports, suppo...
# 321  [supports, supports, supports, supports, suppo...
# 357  [supports, supports, supports, supports, suppo...
# 370  [attacks, supports, supports, attacks, support...
#
#                                            essay_title  \
# 22                            Effects of mobile phones
# 29                            Government and education
# 45                       True function of a university
# 183                    Live football game at a stadium
# 192  Public transportation keeps society from the d...
# 258            Working at home vs Working in a company
# 265  The advertising is the main cause of unhealthy...
# 296              Classroom learnng vs online education
# 321  Replacing old buildings is important for any c...
# 357  The option to work or study from home is advan...
# 370  Vegetarianism - why some people are choosing t...
#
#                                             essay_text  sanity_check
# 22   Nowadays, the popularity of mobile phones has ...         False
# 29   Primary and secondary education provide a basi...         False
# 45   Universities have quickly become the places to...         False
# 183  Have you ever traveled along to support your h...         False
# 192  The development of public transportation is th...         False
# 258  Due to the convenience of current technology, ...         False
# 265  Advertising is becoming part of our modern soc...         False
# 296  There are some people who believe that distanc...         False
# 321  It is important for any city to replace old bu...         False
# 357  Undoubtedly this is an era of internet which i...         False
# 370  Since the dawn of time, human has considered m...         False

# %%
pe_df.iloc[29]
# Out:
# ann_file_name                                               essay030.ann
# argument_ids            [T12, T13, T14, T15, T1, T2, T3, T4, T5, T6, T7]
# argument_types         [Claim, Premise, MajorClaim, Claim, MajorClaim...
# arg_start_bounds       [1123, 1236, 1342, 1400, 148, 318, 421, 572, 7...
# arg_end_bounds         [1232, 1301, 1391, 1558, 316, 400, 570, 720, 8...
# argument_components    [this will encourage all the parents to think ...
# source_args                                            [T13, T4, T5, T7]
# target_args                                            [T12, T3, T6, T6]
# relation_types                  [supports, supports, supports, supports]
# essay_title                                     Government and education
# essay_text             Primary and secondary education provide a basi...
# sanity_check                                                       False
# Name: 29, dtype: object

# %%
split_df = pd.read_csv("/Utilisateurs/umushtaq/am_reasoning/data_files/train-test-split.csv", delimiter=";")

# %%
split_df
# Out:
#            ID    SET
# 0    essay001  TRAIN
# 1    essay002  TRAIN
# 2    essay003  TRAIN
# 3    essay004   TEST
# 4    essay005   TEST
# ..        ...    ...
# 397  essay398   TEST
# 398  essay399  TRAIN
# 399  essay400  TRAIN
# 400  essay401  TRAIN
# 401  essay402  TRAIN
#
# [402 rows x 2 columns]

# %%
pe_df['split'] = split_df.SET

# %%
pe_df.to_csv("/Utilisateurs/umushtaq/am_reasoning/data_files/pe_dataset_new.csv")

# %%
components_df
# Out:
#          file_name argument_id argument_type arg_bound_1 arg_bound2  \
# 0     essay001.ann          T1    MajorClaim         503        575
# 1     essay001.ann          T2    MajorClaim        2154       2231
# 2     essay001.ann          T3         Claim         591        714
# 3     essay001.ann          T4       Premise         716        851
# 4     essay001.ann          T5       Premise         853       1086
# ...            ...         ...           ...         ...        ...
# 6084  essay402.ann         T11       Premise        1275       1339
# 6085  essay402.ann         T12       Premise        1341       1388
# 6086  essay402.ann         T13       Premise        1393       1436
# 6087  essay402.ann         T14       Premise        1448       1525
# 6088  essay402.ann         T15         Claim         916        965
#
#                                      argument_component
# 0     we should attach more importance to cooperatio...
# 1     a more cooperative attitudes towards life is m...
# 2     through cooperation, children can learn about ...
# 3     What we acquired from team work is not only ho...
# 4     During the process of cooperation, children ca...
# ...                                                 ...
# 6084  indirectly they will learn how to socialize ea...
# 6085    That will make children getting lots of friends
# 6086        they can contribute positively to community
# 6087  playing sport makes children getting healthy a...
# 6088  playing sports will give good effects on children
#
# [6089 rows x 6 columns]

# %%
components_df = components_df.drop(columns=components_df.columns[0])

# %%
# Out:
# Parsing annotation files: 100%|██████████| 402/402 [00:00<00:00, 2360.83it/s]
# processing: essay001.ann
# processing: essay002.ann
# processing: essay003.ann
# processing: essay004.ann
# processing: essay005.ann
# processing: essay006.ann
# processing: essay007.ann
# processing: essay008.ann
# processing: essay009.ann
# processing: essay010.ann
# processing: essay011.ann
# processing: essay012.ann
# processing: essay013.ann
# processing: essay014.ann
# processing: essay015.ann
# processing: essay016.ann
# processing: essay017.ann
# processing: essay018.ann
# processing: essay019.ann
# processing: essay020.ann
# processing: essay021.ann
# processing: essay022.ann
# processing: essay023.ann
# processing: essay024.ann
# processing: essay025.ann
# processing: essay026.ann
# processing: essay027.ann
# processing: essay028.ann
# processing: essay029.ann
# processing: essay030.ann
# processing: essay031.ann
# processing: essay032.ann
# processing: essay033.ann
# processing: essay034.ann
# processing: essay035.ann
# processing: essay036.ann
# processing: essay037.ann
# processing: essay038.ann
# processing: essay039.ann
# processing: essay040.ann
# processing: essay041.ann
# processing: essay042.ann
# processing: essay043.ann
# processing: essay044.ann
# processing: essay045.ann
# processing: essay046.ann
# processing: essay047.ann
# processing: essay048.ann
# processing: essay049.ann
# processing: essay050.ann
# processing: essay051.ann
# processing: essay052.ann
# processing: essay053.ann
# processing: essay054.ann
# processing: essay055.ann
# processing: essay056.ann
# processing: essay336.ann
# processing: essay337.ann
# processing: essay338.ann
# processing: essay339.ann
# processing: essay340.ann
# processing: essay341.ann
# processing: essay342.ann
# processing: essay343.ann
# processing: essay344.ann
# processing: essay345.ann
# processing: essay346.ann
# processing: essay347.ann
# processing: essay348.ann
# processing: essay349.ann
# processing: essay350.ann
# processing: essay351.ann
# processing: essay352.ann
# processing: essay353.ann
# processing: essay354.ann
# processing: essay355.ann
# processing: essay356.ann
# processing: essay357.ann
# processing: essay358.ann
# processing: essay359.ann
# processing: essay360.ann
# processing: essay361.ann
# processing: essay362.ann
# processing: essay363.ann
# processing: essay364.ann
# processing: essay365.ann
# processing: essay366.ann
# processing: essay367.ann
# processing: essay368.ann
# processing: essay369.ann
# processing: essay370.ann
# processing: essay371.ann
# processing: essay372.ann
# processing: essay373.ann
# processing: essay374.ann
# processing: essay375.ann
# processing: essay376.ann
# processing: essay377.ann
# processing: essay378.ann
# processing: essay379.ann
# processing: essay380.ann
# processing: essay381.ann
# processing: essay382.ann
# processing: essay383.ann
# processing: essay384.ann
# processing: essay385.ann
# processing: essay386.ann
# processing: essay387.ann
# processing: essay388.ann
# processing: essay389.ann
# processing: essay390.ann
# processing: essay391.ann
# processing: essay392.ann
# processing: essay393.ann
# processing: essay394.ann
# processing: essay395.ann
# processing: essay396.ann
# processing: essay397.ann
# processing: essay398.ann
# processing: essay399.ann
# processing: essay400.ann
# processing: essay401.ann
# processing: essay402.ann

# %%
relations_df
# Out:
#          file_name source_arg target_arg relation_type
# 0     essay001.ann         T4         T3      supports
# 1     essay001.ann         T5         T3      supports
# 2     essay001.ann         T6         T3      supports
# 3     essay001.ann        T10        T11      supports
# 4     essay001.ann         T9        T11      supports
# ...            ...        ...        ...           ...
# 3827  essay402.ann        T13         T4      supports
# 3828  essay402.ann         T9         T4      supports
# 3829  essay402.ann        T10         T4      supports
# 3830  essay402.ann        T14         T4      supports
# 3831  essay402.ann         T7         T8      supports
#
# [3832 rows x 4 columns]

# %%
relations_df = relations_df.drop(columns=relations_df.columns[0])

# %%
relations_df.columns = ["file_name", "source_arg", "target_arg", "relation_type"]

# %%
for filename in tqdm(os.listdir(text_files_directory), desc="Parsing text files"):
    
    print("processing: " + filename)
    #if filename.endswith(".ann"):  # Process only text files
    file_path = os.path.join(text_files_directory, filename)
    filename_ann = filename.replace(".txt", ".ann")
    
    with open(file_path, "r", encoding="utf-8") as file:
        
        lines = file.readlines()
        essay_title = lines[0].strip()
        essay_text = "".join(lines[1:]).strip()
        
        essays_data.append([filename.replace(".txt", ".ann"), essay_title, essay_text])
# Out:
# Parsing text files: 100%|██████████| 402/402 [00:00<00:00, 6202.45it/s]
# processing: essay001.txt
# processing: essay002.txt
# processing: essay003.txt
# processing: essay004.txt
# processing: essay005.txt
# processing: essay006.txt
# processing: essay007.txt
# processing: essay008.txt
# processing: essay009.txt
# processing: essay010.txt
# processing: essay011.txt
# processing: essay012.txt
# processing: essay013.txt
# processing: essay014.txt
# processing: essay015.txt
# processing: essay016.txt
# processing: essay296.txt
# processing: essay297.txt
# processing: essay298.txt
# processing: essay299.txt
# processing: essay300.txt
# processing: essay301.txt
# processing: essay302.txt
# processing: essay303.txt
# processing: essay304.txt
# processing: essay305.txt
# processing: essay306.txt
# processing: essay307.txt
# processing: essay308.txt
# processing: essay309.txt
# processing: essay310.txt
# processing: essay311.txt
# processing: essay312.txt
# processing: essay313.txt
# processing: essay314.txt
# processing: essay315.txt
# processing: essay316.txt
# processing: essay317.txt
# processing: essay318.txt
# processing: essay319.txt
# processing: essay320.txt
# processing: essay321.txt
# processing: essay322.txt
# processing: essay323.txt
# processing: essay324.txt
# processing: essay325.txt
# processing: essay326.txt
# processing: essay327.txt
# processing: essay328.txt
# processing: essay329.txt
# processing: essay330.txt
# processing: essay331.txt
# processing: essay332.txt
# processing: essay333.txt
# processing: essay334.txt
# processing: essay335.txt
# processing: essay336.txt
# processing: essay337.txt
# processing: essay338.txt
# processing: essay339.txt
# processing: essay340.txt
# processing: essay341.txt
# processing: essay342.txt
# processing: essay343.txt
# processing: essay344.txt
# processing: essay345.txt
# processing: essay346.txt
# processing: essay347.txt
# processing: essay348.txt
# processing: essay349.txt
# processing: essay350.txt
# processing: essay351.txt
# processing: essay352.txt
# processing: essay353.txt
# processing: essay354.txt
# processing: essay355.txt
# processing: essay356.txt
# processing: essay357.txt
# processing: essay358.txt
# processing: essay359.txt
# processing: essay360.txt
# processing: essay361.txt
# processing: essay362.txt
# processing: essay363.txt
# processing: essay364.txt
# processing: essay365.txt
# processing: essay366.txt
# processing: essay367.txt
# processing: essay368.txt
# processing: essay369.txt
# processing: essay370.txt
# processing: essay371.txt
# processing: essay372.txt
# processing: essay373.txt
# processing: essay374.txt
# processing: essay375.txt
# processing: essay376.txt
# processing: essay377.txt
# processing: essay378.txt
# processing: essay379.txt
# processing: essay380.txt
# processing: essay381.txt
# processing: essay382.txt
# processing: essay383.txt
# processing: essay384.txt
# processing: essay385.txt
# processing: essay386.txt
# processing: essay387.txt
# processing: essay388.txt
# processing: essay389.txt
# processing: essay390.txt
# processing: essay391.txt
# processing: essay392.txt
# processing: essay393.txt
# processing: essay394.txt
# processing: essay395.txt
# processing: essay396.txt
# processing: essay397.txt
# processing: essay398.txt
# processing: essay399.txt
# processing: essay400.txt
# processing: essay401.txt
# processing: essay402.txt

# %%
essays_df = pd.DataFrame(essays_data)

# %%
essays_df
# Out:
#                 0                                                  1  \
# 0    essay001.ann  Should students be taught to compete or to coo...
# 1    essay002.ann  More people are migrating to other countries t...
# 2    essay003.ann  International tourism is now more common than ...
# 3    essay004.ann  International tourism is now more common than ...
# 4    essay005.ann                       Living and studying overseas
# ..            ...                                                ...
# 397  essay398.ann  We can not forcedly put the same numbers of ma...
# 398  essay399.ann                 Drugs, alcohol and messy sex lives
# 399  essay400.ann  A greater proportion of the budget should be a...
# 400  essay401.ann  Fatherhood should be as present as motherhood ...
# 401  essay402.ann  Children should studying hard or playing sport...
#
#                                                      2
# 0    It is always said that competition can effecti...
# 1    The last 50 years have seen an increasing numb...
# 2    The last decade has seen an increasing number ...
# 3    The last 50 years have seen a significant incr...
# 4    It is every student's desire to study at a goo...
# ..                                                 ...
# 397  There is a view that universities and colleges...
# 398  Celebrities, for example movie stars, are usua...
# 399  In today's world, the concept of the welfare s...
# 400  In today's world, having and raising children ...
# 401  Some people believe that studying hard is esse...
#
# [402 rows x 3 columns]

# %%
essays_df.columns = ["file_name", "essay_title", "essay_text"]

# %%
essays_df
# Out:
#         file_name                                        essay_title  \
# 0    essay001.ann  Should students be taught to compete or to coo...
# 1    essay002.ann  More people are migrating to other countries t...
# 2    essay003.ann  International tourism is now more common than ...
# 3    essay004.ann  International tourism is now more common than ...
# 4    essay005.ann                       Living and studying overseas
# ..            ...                                                ...
# 397  essay398.ann  We can not forcedly put the same numbers of ma...
# 398  essay399.ann                 Drugs, alcohol and messy sex lives
# 399  essay400.ann  A greater proportion of the budget should be a...
# 400  essay401.ann  Fatherhood should be as present as motherhood ...
# 401  essay402.ann  Children should studying hard or playing sport...
#
#                                             essay_text
# 0    It is always said that competition can effecti...
# 1    The last 50 years have seen an increasing numb...
# 2    The last decade has seen an increasing number ...
# 3    The last 50 years have seen a significant incr...
# 4    It is every student's desire to study at a goo...
# ..                                                 ...
# 397  There is a view that universities and colleges...
# 398  Celebrities, for example movie stars, are usua...
# 399  In today's world, the concept of the welfare s...
# 400  In today's world, having and raising children ...
# 401  Some people believe that studying hard is esse...
#
# [402 rows x 3 columns]

# %% [markdown]
# ### Group dfs and then merge

# %%
# "file_name", "argument_id", "argument_type", "arg_bound_1", "arg_bound2", "argument_component"

# %%
comp_grouped_df = components_df.groupby(['file_name'], sort=False).agg({
    'argument_id': list,
    'argument_type': list,
    'arg_bound_1': list,
    'arg_bound2': list,
    'argument_component': list,
}).reset_index()

# %%
comp_grouped_df
# Out:
#         file_name                                        argument_id  \
# 0    essay001.ann     [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T11]
# 1    essay002.ann  [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T11,...
# 2    essay003.ann          [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10]
# 3    essay004.ann     [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T11]
# 4    essay005.ann  [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T11,...
# ..            ...                                                ...
# 397  essay398.ann  [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T11,...
# 398  essay399.ann          [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10]
# 399  essay400.ann          [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10]
# 400  essay401.ann          [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10]
# 401  essay402.ann  [T1, T2, T3, T5, T6, T7, T8, T4, T9, T10, T11,...
#
#                                          argument_type  \
# 0    [MajorClaim, MajorClaim, Claim, Premise, Premi...
# 1    [MajorClaim, MajorClaim, Premise, Claim, Premi...
# 2    [MajorClaim, MajorClaim, Claim, Premise, Premi...
# 3    [MajorClaim, MajorClaim, Claim, Claim, Claim, ...
# 4    [MajorClaim, MajorClaim, Claim, Claim, Claim, ...
# ..                                                 ...
# 397  [Claim, MajorClaim, Premise, Premise, Premise,...
# 398  [MajorClaim, MajorClaim, Claim, Premise, Premi...
# 399  [MajorClaim, MajorClaim, Claim, Premise, Premi...
# 400  [MajorClaim, MajorClaim, Premise, Premise, Cla...
# 401  [MajorClaim, MajorClaim, Premise, Premise, Pre...
#
#                                            arg_bound_1  \
# 0    [503, 2154, 591, 716, 853, 1088, 1332, 1212, 1...
# 1    [391, 1936, 500, 1089, 626, 841, 948, 1168, 12...
# 2    [352, 1568, 955, 487, 615, 786, 1024, 1454, 11...
# 3    [262, 1663, 179, 953, 1578, 417, 532, 820, 107...
# 4    [286, 1535, 388, 775, 1330, 566, 885, 993, 109...
# ..                                                 ...
# 397  [254, 1751, 409, 557, 647, 778, 915, 333, 1260...
# 398  [367, 1323, 527, 431, 661, 787, 966, 750, 1086...
# 399  [274, 1619, 736, 541, 805, 389, 1112, 1233, 14...
# 400  [311, 1496, 502, 622, 386, 954, 1103, 818, 128...
# 401  [238, 1543, 379, 544, 725, 827, 329, 1064, 112...
#
#                                             arg_bound2  \
# 0    [575, 2231, 714, 851, 1086, 1191, 1376, 1301, ...
# 1    [489, 2077, 624, 1156, 839, 946, 1057, 1204, 1...
# 2    [475, 1701, 1012, 613, 784, 943, 1135, 1526, 1...
# 3    [376, 1758, 239, 1031, 1624, 530, 818, 924, 11...
# 4    [359, 1652, 564, 883, 1425, 765, 988, 1078, 11...
# ..                                                 ...
# 397  [318, 1951, 541, 645, 767, 897, 1035, 407, 134...
# 398  [429, 1390, 645, 525, 737, 951, 1073, 785, 117...
# 399  [387, 1812, 796, 723, 944, 524, 1220, 1388, 16...
# 400  [384, 1667, 607, 815, 488, 1087, 1278, 937, 13...
# 401  [307, 1620, 462, 723, 810, 896, 377, 1112, 123...
#
#                                     argument_component
# 0    [we should attach more importance to cooperati...
# 1    [they are able to sustain their cultural ident...
# 2    [it has contributed to the economic developmen...
# 3    [this industry has affected the cultural attri...
# 4    [one who studies overseas will gain many skill...
# ..                                                 ...
# 397  [many different characters exist between male ...
# 398  [this is a worrying tread which has negative i...
# 399  [governments should devote a greater portion o...
# 400  [fatherhood is a as vital part of a healty par...
# 401  [both of studying hard and playing sports are ...
#
# [402 rows x 6 columns]

# %%
rels_grouped_df = relations_df.groupby(['file_name'], sort=False).agg({
    'source_arg': list,
    'target_arg': list,
    'relation_type': list,
}).reset_index()

# source_arg	target_arg	relation_type

# %%
rels_grouped_df
# Out:
#         file_name                                         source_arg  \
# 0    essay001.ann                          [T4, T5, T6, T10, T9, T8]
# 1    essay002.ann            [T9, T11, T12, T13, T5, T6, T7, T3, T8]
# 2    essay003.ann                          [T10, T9, T6, T5, T4, T7]
# 3    essay004.ann                         [T8, T7, T6, T10, T9, T11]
# 4    essay005.ann                         [T6, T7, T8, T9, T10, T11]
# ..            ...                                                ...
# 397  essay398.ann  [T3, T4, T5, T6, T7, T13, T14, T11, T9, T15, T16]
# 398  essay399.ann                              [T4, T5, T6, T8, T10]
# 399  essay400.ann                           [T4, T5, T6, T7, T9, T8]
# 400  essay401.ann                          [T3, T7, T10, T4, T9, T6]
# 401  essay402.ann  [T5, T3, T6, T11, T12, T4, T13, T9, T10, T14, T7]
#
#                                             target_arg  \
# 0                           [T3, T3, T3, T11, T11, T7]
# 1             [T8, T10, T10, T10, T4, T4, T4, T4, T10]
# 2                             [T8, T8, T3, T3, T3, T8]
# 3                            [T4, T4, T4, T11, T5, T5]
# 4                             [T3, T4, T7, T4, T5, T5]
# ..                                                 ...
# 397  [T8, T8, T8, T8, T8, T12, T12, T10, T10, T10, ...
# 398                               [T3, T3, T7, T7, T9]
# 399                          [T3, T3, T3, T8, T8, T10]
# 400                           [T5, T6, T8, T3, T8, T8]
# 401    [T8, T8, T5, T10, T13, T15, T4, T4, T4, T4, T8]
#
#                                          relation_type
# 0    [supports, supports, supports, supports, suppo...
# 1    [supports, supports, supports, supports, suppo...
# 2    [supports, supports, supports, supports, suppo...
# 3    [supports, supports, supports, supports, suppo...
# 4    [supports, attacks, attacks, supports, support...
# ..                                                 ...
# 397  [supports, supports, supports, supports, suppo...
# 398  [supports, supports, supports, supports, suppo...
# 399  [supports, supports, supports, supports, suppo...
# 400  [supports, supports, supports, supports, suppo...
# 401  [supports, supports, supports, supports, suppo...
#
# [402 rows x 4 columns]

# %% [markdown]
# ### MERGE

# %%
merged_df = comp_grouped_df.merge(rels_grouped_df, on="file_name").merge(essays_df, on="file_name")

# %%
merged_df
# Out:
#         file_name                                        argument_id  \
# 0    essay001.ann     [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T11]
# 1    essay002.ann  [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T11,...
# 2    essay003.ann          [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10]
# 3    essay004.ann     [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T11]
# 4    essay005.ann  [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T11,...
# ..            ...                                                ...
# 397  essay398.ann  [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T11,...
# 398  essay399.ann          [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10]
# 399  essay400.ann          [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10]
# 400  essay401.ann          [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10]
# 401  essay402.ann  [T1, T2, T3, T5, T6, T7, T8, T4, T9, T10, T11,...
#
#                                          argument_type  \
# 0    [MajorClaim, MajorClaim, Claim, Premise, Premi...
# 1    [MajorClaim, MajorClaim, Premise, Claim, Premi...
# 2    [MajorClaim, MajorClaim, Claim, Premise, Premi...
# 3    [MajorClaim, MajorClaim, Claim, Claim, Claim, ...
# 4    [MajorClaim, MajorClaim, Claim, Claim, Claim, ...
# ..                                                 ...
# 397  [Claim, MajorClaim, Premise, Premise, Premise,...
# 398  [MajorClaim, MajorClaim, Claim, Premise, Premi...
# 399  [MajorClaim, MajorClaim, Claim, Premise, Premi...
# 400  [MajorClaim, MajorClaim, Premise, Premise, Cla...
# 401  [MajorClaim, MajorClaim, Premise, Premise, Pre...
#
#                                            arg_bound_1  \
# 0    [503, 2154, 591, 716, 853, 1088, 1332, 1212, 1...
# 1    [391, 1936, 500, 1089, 626, 841, 948, 1168, 12...
# 2    [352, 1568, 955, 487, 615, 786, 1024, 1454, 11...
# 3    [262, 1663, 179, 953, 1578, 417, 532, 820, 107...
# 4    [286, 1535, 388, 775, 1330, 566, 885, 993, 109...
# ..                                                 ...
# 397  [254, 1751, 409, 557, 647, 778, 915, 333, 1260...
# 398  [367, 1323, 527, 431, 661, 787, 966, 750, 1086...
# 399  [274, 1619, 736, 541, 805, 389, 1112, 1233, 14...
# 400  [311, 1496, 502, 622, 386, 954, 1103, 818, 128...
# 401  [238, 1543, 379, 544, 725, 827, 329, 1064, 112...
#
#                                             arg_bound2  \
# 0    [575, 2231, 714, 851, 1086, 1191, 1376, 1301, ...
# 1    [489, 2077, 624, 1156, 839, 946, 1057, 1204, 1...
# 2    [475, 1701, 1012, 613, 784, 943, 1135, 1526, 1...
# 3    [376, 1758, 239, 1031, 1624, 530, 818, 924, 11...
# 4    [359, 1652, 564, 883, 1425, 765, 988, 1078, 11...
# ..                                                 ...
# 397  [318, 1951, 541, 645, 767, 897, 1035, 407, 134...
# 398  [429, 1390, 645, 525, 737, 951, 1073, 785, 117...
# 399  [387, 1812, 796, 723, 944, 524, 1220, 1388, 16...
# 400  [384, 1667, 607, 815, 488, 1087, 1278, 937, 13...
# 401  [307, 1620, 462, 723, 810, 896, 377, 1112, 123...
#
#                                     argument_component  \
# 0    [we should attach more importance to cooperati...
# 1    [they are able to sustain their cultural ident...
# 2    [it has contributed to the economic developmen...
# 3    [this industry has affected the cultural attri...
# 4    [one who studies overseas will gain many skill...
# ..                                                 ...
# 397  [many different characters exist between male ...
# 398  [this is a worrying tread which has negative i...
# 399  [governments should devote a greater portion o...
# 400  [fatherhood is a as vital part of a healty par...
# 401  [both of studying hard and playing sports are ...
#
#                                             source_arg  \
# 0                            [T4, T5, T6, T10, T9, T8]
# 1              [T9, T11, T12, T13, T5, T6, T7, T3, T8]
# 2                            [T10, T9, T6, T5, T4, T7]
# 3                           [T8, T7, T6, T10, T9, T11]
# 4                           [T6, T7, T8, T9, T10, T11]
# ..                                                 ...
# 397  [T3, T4, T5, T6, T7, T13, T14, T11, T9, T15, T16]
# 398                              [T4, T5, T6, T8, T10]
# 399                           [T4, T5, T6, T7, T9, T8]
# 400                          [T3, T7, T10, T4, T9, T6]
# 401  [T5, T3, T6, T11, T12, T4, T13, T9, T10, T14, T7]
#
#                                             target_arg  \
# 0                           [T3, T3, T3, T11, T11, T7]
# 1             [T8, T10, T10, T10, T4, T4, T4, T4, T10]
# 2                             [T8, T8, T3, T3, T3, T8]
# 3                            [T4, T4, T4, T11, T5, T5]
# 4                             [T3, T4, T7, T4, T5, T5]
# ..                                                 ...
# 397  [T8, T8, T8, T8, T8, T12, T12, T10, T10, T10, ...
# 398                               [T3, T3, T7, T7, T9]
# 399                          [T3, T3, T3, T8, T8, T10]
# 400                           [T5, T6, T8, T3, T8, T8]
# 401    [T8, T8, T5, T10, T13, T15, T4, T4, T4, T4, T8]
#
#                                          relation_type  \
# 0    [supports, supports, supports, supports, suppo...
# 1    [supports, supports, supports, supports, suppo...
# 2    [supports, supports, supports, supports, suppo...
# 3    [supports, supports, supports, supports, suppo...
# 4    [supports, attacks, attacks, supports, support...
# ..                                                 ...
# 397  [supports, supports, supports, supports, suppo...
# 398  [supports, supports, supports, supports, suppo...
# 399  [supports, supports, supports, supports, suppo...
# 400  [supports, supports, supports, supports, suppo...
# 401  [supports, supports, supports, supports, suppo...
#
#                                            essay_title  \
# 0    Should students be taught to compete or to coo...
# 1    More people are migrating to other countries t...
# 2    International tourism is now more common than ...
# 3    International tourism is now more common than ...
# 4                         Living and studying overseas
# ..                                                 ...
# 397  We can not forcedly put the same numbers of ma...
# 398                 Drugs, alcohol and messy sex lives
# 399  A greater proportion of the budget should be a...
# 400  Fatherhood should be as present as motherhood ...
# 401  Children should studying hard or playing sport...
#
#                                             essay_text
# 0    It is always said that competition can effecti...
# 1    The last 50 years have seen an increasing numb...
# 2    The last decade has seen an increasing number ...
# 3    The last 50 years have seen a significant incr...
# 4    It is every student's desire to study at a goo...
# ..                                                 ...
# 397  There is a view that universities and colleges...
# 398  Celebrities, for example movie stars, are usua...
# 399  In today's world, the concept of the welfare s...
# 400  In today's world, having and raising children ...
# 401  Some people believe that studying hard is esse...
#
# [402 rows x 11 columns]

# %%
merged_df.columns
# Out:
# Index(['file_name', 'argument_id', 'argument_type', 'arg_bound_1',
#        'arg_bound2', 'argument_component', 'source_arg', 'target_arg',
#        'relation_type', 'essay_title', 'essay_text'],
#       dtype='object')

# %%
merged_df.columns = ['ann_file_name', 'argument_ids', 'argument_types', 'arg_start_bounds',
       'arg_end_bounds', 'argument_components', 'source_args', 'target_args',
       'relation_types', 'essay_title', 'essay_text']

# %%
merged_df
# Out:
#     ann_file_name                                       argument_ids  \
# 0    essay001.ann     [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T11]
# 1    essay002.ann  [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T11,...
# 2    essay003.ann          [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10]
# 3    essay004.ann     [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T11]
# 4    essay005.ann  [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T11,...
# ..            ...                                                ...
# 397  essay398.ann  [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10, T11,...
# 398  essay399.ann          [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10]
# 399  essay400.ann          [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10]
# 400  essay401.ann          [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10]
# 401  essay402.ann  [T1, T2, T3, T5, T6, T7, T8, T4, T9, T10, T11,...
#
#                                         argument_types  \
# 0    [MajorClaim, MajorClaim, Claim, Premise, Premi...
# 1    [MajorClaim, MajorClaim, Premise, Claim, Premi...
# 2    [MajorClaim, MajorClaim, Claim, Premise, Premi...
# 3    [MajorClaim, MajorClaim, Claim, Claim, Claim, ...
# 4    [MajorClaim, MajorClaim, Claim, Claim, Claim, ...
# ..                                                 ...
# 397  [Claim, MajorClaim, Premise, Premise, Premise,...
# 398  [MajorClaim, MajorClaim, Claim, Premise, Premi...
# 399  [MajorClaim, MajorClaim, Claim, Premise, Premi...
# 400  [MajorClaim, MajorClaim, Premise, Premise, Cla...
# 401  [MajorClaim, MajorClaim, Premise, Premise, Pre...
#
#                                       arg_start_bounds  \
# 0    [503, 2154, 591, 716, 853, 1088, 1332, 1212, 1...
# 1    [391, 1936, 500, 1089, 626, 841, 948, 1168, 12...
# 2    [352, 1568, 955, 487, 615, 786, 1024, 1454, 11...
# 3    [262, 1663, 179, 953, 1578, 417, 532, 820, 107...
# 4    [286, 1535, 388, 775, 1330, 566, 885, 993, 109...
# ..                                                 ...
# 397  [254, 1751, 409, 557, 647, 778, 915, 333, 1260...
# 398  [367, 1323, 527, 431, 661, 787, 966, 750, 1086...
# 399  [274, 1619, 736, 541, 805, 389, 1112, 1233, 14...
# 400  [311, 1496, 502, 622, 386, 954, 1103, 818, 128...
# 401  [238, 1543, 379, 544, 725, 827, 329, 1064, 112...
#
#                                         arg_end_bounds  \
# 0    [575, 2231, 714, 851, 1086, 1191, 1376, 1301, ...
# 1    [489, 2077, 624, 1156, 839, 946, 1057, 1204, 1...
# 2    [475, 1701, 1012, 613, 784, 943, 1135, 1526, 1...
# 3    [376, 1758, 239, 1031, 1624, 530, 818, 924, 11...
# 4    [359, 1652, 564, 883, 1425, 765, 988, 1078, 11...
# ..                                                 ...
# 397  [318, 1951, 541, 645, 767, 897, 1035, 407, 134...
# 398  [429, 1390, 645, 525, 737, 951, 1073, 785, 117...
# 399  [387, 1812, 796, 723, 944, 524, 1220, 1388, 16...
# 400  [384, 1667, 607, 815, 488, 1087, 1278, 937, 13...
# 401  [307, 1620, 462, 723, 810, 896, 377, 1112, 123...
#
#                                    argument_components  \
# 0    [we should attach more importance to cooperati...
# 1    [they are able to sustain their cultural ident...
# 2    [it has contributed to the economic developmen...
# 3    [this industry has affected the cultural attri...
# 4    [one who studies overseas will gain many skill...
# ..                                                 ...
# 397  [many different characters exist between male ...
# 398  [this is a worrying tread which has negative i...
# 399  [governments should devote a greater portion o...
# 400  [fatherhood is a as vital part of a healty par...
# 401  [both of studying hard and playing sports are ...
#
#                                            source_args  \
# 0                            [T4, T5, T6, T10, T9, T8]
# 1              [T9, T11, T12, T13, T5, T6, T7, T3, T8]
# 2                            [T10, T9, T6, T5, T4, T7]
# 3                           [T8, T7, T6, T10, T9, T11]
# 4                           [T6, T7, T8, T9, T10, T11]
# ..                                                 ...
# 397  [T3, T4, T5, T6, T7, T13, T14, T11, T9, T15, T16]
# 398                              [T4, T5, T6, T8, T10]
# 399                           [T4, T5, T6, T7, T9, T8]
# 400                          [T3, T7, T10, T4, T9, T6]
# 401  [T5, T3, T6, T11, T12, T4, T13, T9, T10, T14, T7]
#
#                                            target_args  \
# 0                           [T3, T3, T3, T11, T11, T7]
# 1             [T8, T10, T10, T10, T4, T4, T4, T4, T10]
# 2                             [T8, T8, T3, T3, T3, T8]
# 3                            [T4, T4, T4, T11, T5, T5]
# 4                             [T3, T4, T7, T4, T5, T5]
# ..                                                 ...
# 397  [T8, T8, T8, T8, T8, T12, T12, T10, T10, T10, ...
# 398                               [T3, T3, T7, T7, T9]
# 399                          [T3, T3, T3, T8, T8, T10]
# 400                           [T5, T6, T8, T3, T8, T8]
# 401    [T8, T8, T5, T10, T13, T15, T4, T4, T4, T4, T8]
#
#                                         relation_types  \
# 0    [supports, supports, supports, supports, suppo...
# 1    [supports, supports, supports, supports, suppo...
# 2    [supports, supports, supports, supports, suppo...
# 3    [supports, supports, supports, supports, suppo...
# 4    [supports, attacks, attacks, supports, support...
# ..                                                 ...
# 397  [supports, supports, supports, supports, suppo...
# 398  [supports, supports, supports, supports, suppo...
# 399  [supports, supports, supports, supports, suppo...
# 400  [supports, supports, supports, supports, suppo...
# 401  [supports, supports, supports, supports, suppo...
#
#                                            essay_title  \
# 0    Should students be taught to compete or to coo...
# 1    More people are migrating to other countries t...
# 2    International tourism is now more common than ...
# 3    International tourism is now more common than ...
# 4                         Living and studying overseas
# ..                                                 ...
# 397  We can not forcedly put the same numbers of ma...
# 398                 Drugs, alcohol and messy sex lives
# 399  A greater proportion of the budget should be a...
# 400  Fatherhood should be as present as motherhood ...
# 401  Children should studying hard or playing sport...
#
#                                             essay_text
# 0    It is always said that competition can effecti...
# 1    The last 50 years have seen an increasing numb...
# 2    The last decade has seen an increasing number ...
# 3    The last 50 years have seen a significant incr...
# 4    It is every student's desire to study at a goo...
# ..                                                 ...
# 397  There is a view that universities and colleges...
# 398  Celebrities, for example movie stars, are usua...
# 399  In today's world, the concept of the welfare s...
# 400  In today's world, having and raising children ...
# 401  Some people believe that studying hard is esse...
#
# [402 rows x 11 columns]

# %% [markdown]
# #### sanity checks

# %%
def egal_1(row):
    
    return 1 if (len(row.argument_ids) == len(row.argument_types) == len(row.arg_start_bounds) == len(row.arg_end_bounds) == len(row.argument_components)) else 0

# %%
merged_df['egal_1'] = merged_df.apply(lambda row: egal_1(row), axis=1)

# %%
merged_df['egal_1'].value_counts()
# Out:
# egal_1
# 1    402
# Name: count, dtype: int64

# %%
def egal_2(row):
    
    return 1 if (len(row.source_args) == len(row.target_args) == len(row.relation_types)) else 0

# %%
merged_df['egal_2'] = merged_df.apply(lambda row: egal_2(row), axis=1)

# %%
merged_df['egal_2'].value_counts()
# Out:
# egal_2
# 1    402
# Name: count, dtype: int64
